# %%
from fenics import *
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size
set_log_level(30)
import random
from dolfin import interpolate, Expression, FunctionSpace, Constant, UserExpression
from dotenv import load_dotenv
import os
load_dotenv()
import numpy as np
import math

# %%
nueva_ruta = '/media/erick/TOSHIBA EXT/results_06032025/strong_allee/mu_1'

# %%
save_images = os.getenv('SAVE_IMAGES')

# Define constants alpha and beta
D_c = float(os.getenv('D_c'))
D_s = float(os.getenv('D_s'))
D_i = float(os.getenv('D_i'))

rc = float(os.getenv('rc'))
rs = float(os.getenv('rs'))
rd = float(os.getenv('rd'))

alpha = float(os.getenv('alpha'))
delta = float(os.getenv('delta'))
beta = float(os.getenv('beta'))
alle = float(os.getenv('alle'))
gamma = float(os.getenv('gamma'))
eta = float(os.getenv('eta'))
mu = float(os.getenv('mu'))

# Define time parameters
T = float(os.getenv('T'))
dt = float(os.getenv('dt'))
nb = int(os.getenv('nb'))

# Define mesh and space
nodes_in_xaxis = int(os.getenv('nodes_in_xaxis'))
nodes_in_yaxis = int(os.getenv('nodes_in_yaxis'))
space_size = int(os.getenv('space_size'))


# Condición inicial en donde el cancer se origina en puntos
centers = [(5, 5), (15, 15)]  # Coordenadas donde el cáncer se origina
radius = 1.0  # Radio alrededor de los centros
value_outside = 0.0  # Valor fuera de los radios
value_inside = 0.01  # Valor dentro de los radios

# Cambiar al nuevo directorio
os.chdir(nueva_ruta)

# %%
# Condición inicial aleatoria
class RandomExpression(UserExpression):
    def __init__(self, min_val, max_val, **kwargs):
        super().__init__(**kwargs)
        self.min_val = min_val
        self.max_val = max_val

    def eval(self, value, x):
        value[0] = random.uniform(self.min_val, self.max_val)

# %%
# Definir condiciones iniciales
class CancerInitialCondition(UserExpression):
    def __init__(self, centers, radius, value_outside, value_inside, **kwargs):
        super().__init__(**kwargs)
        self.centers = centers
        self.radius = radius
        self.value_outside = value_outside
        self.value_inside = value_inside

    def eval(self, value, x):
        value[0] = self.value_outside
        for center in self.centers:
            distance = math.sqrt((x[0] - center[0])**2 + (x[1] - center[1])**2)
            if distance <= self.radius:
                value[0] = self.value_inside
                break

# %%
def NonlinearSolver(F, field):
    J = derivative(F, field)
    problem = NonlinearVariationalProblem(F, field, bcs=[], J=J)
    solver = NonlinearVariationalSolver(problem)

    # Configuración base del solver
    prm = solver.parameters["snes_solver"]
    prm["method"] = "vinewtonrsls"
    prm["maximum_iterations"] = 10000
    prm["relative_tolerance"] = 1e-6
    prm["absolute_tolerance"] = 1e-8
    prm["report"] = True
    prm["error_on_nonconvergence"] = False

    # Lista de métodos a probar
    linear_solver_options = ["mumps", "superlu", "gmres", "bicgstab", "cg"]
    preconditioner_options = ["none", "amg", "ilu", "icc"]

    # Intenta con la mejor opción primero
    try:
        prm["linear_solver"] = "mumps"
        prm["preconditioner"] = "none"
        solver.solve()
        return solver
    except RuntimeError as e:
        print(f"⚠️ Error con mumps: {e}. Probando otras opciones...")

    # Si falla, probar combinaciones de métodos y precondicionadores
    for linear_solver in linear_solver_options:
        for preconditioner in preconditioner_options:
            try:
                prm["linear_solver"] = linear_solver
                prm["preconditioner"] = preconditioner
                print(f"🔄 Probando con solver={linear_solver}, precondicionador={preconditioner}...")
                solver.solve()
                print(f"✅ Convergió con solver={linear_solver}, precondicionador={preconditioner}")
                return solver
            except (RuntimeError, ConvergenceError) as e:
                print(f"❌ Falló con solver={linear_solver}, precondicionador={preconditioner}: {e}")
                continue

    # Si no converge con ninguna combinación
    raise RuntimeError("No se pudo resolver el sistema no lineal con ninguno de los métodos probados.")

# %%
# Función para convertir campos de FEniCS a numpy
def field_to_numpy_array(fenics_field, space_size, step, field_name, nb, sample_rate=0.1): 
    sample_points = np.arange(0, space_size + sample_rate, sample_rate)
    field_array = np.empty((len(sample_points), len(sample_points)), dtype=float)

    for i, val_x in enumerate(sample_points):
        for j, val_y in enumerate(sample_points):
            try:
                valor = fenics_field(val_x, val_y)
            except:
                valor = 0  
            field_array[i, j] = valor

    filename = f"matrix_{field_name}_{step}_nb_{nb}.txt"
    np.savetxt(filename, field_array, delimiter="\t")
    return None

# %%
def plot_fields(field_1, field_2, field_3, block):
    plt.figure(figsize=(15, 8))

    plt.subplot(1, 3, 1)
    p1 = plot(field_1)
    p1.set_cmap("seismic")
    plt.title(f'Solution for c at time {t:.3f}')
    aspect = 20
    pad_fraction = 0.5
    ax = plt.gca()
    divider = make_axes_locatable(ax)
    width = axes_size.AxesY(ax, aspect=1./aspect)
    pad = axes_size.Fraction(pad_fraction, width)
    cax = divider.append_axes("right", size=width, pad=pad)
    plt.colorbar(p1, cax=cax)


    plt.subplot(1, 3, 2)
    p2 = plot(field_2)
    p2.set_cmap("gray")
    plt.title(f'Solution for s at time {t:.3f}')
    aspect = 20
    pad_fraction = 0.5
    ax = plt.gca()
    divider = make_axes_locatable(ax)
    width = axes_size.AxesY(ax, aspect=1./aspect)
    pad = axes_size.Fraction(pad_fraction, width)
    cax = divider.append_axes("right", size=width, pad=pad)
    plt.colorbar(p2, cax=cax)
    
    plt.subplot(1, 3, 3)
    p3 = plot(field_3)
    p3.set_cmap("viridis")
    plt.title(f'Solution for i at time {t:.3f}')
    aspect = 20
    pad_fraction = 0.5
    ax = plt.gca()
    divider = make_axes_locatable(ax)
    width = axes_size.AxesY(ax, aspect=1./aspect)
    pad = axes_size.Fraction(pad_fraction, width)
    cax = divider.append_axes("right", size=width, pad=pad)
    plt.colorbar(p3, cax=cax)

    plt.tight_layout(pad=4)
    if save_images == 'Y':
        plt.savefig(f'fields_block_{block}._step_{t:.3f}.png')
        plt.show()
        pass
    else:
        plt.show()

# %%
# Espacio de funciones
def create_space_function(space_size, nodes_in_xaxis, nodes_in_yaxis):
    p0 = Point(0.0, 0.0)
    p1 = Point(space_size, space_size)
    mesh = RectangleMesh(p0, p1, nodes_in_xaxis, nodes_in_yaxis, "right/left")
    V = FunctionSpace(mesh, 'P', 1)
    return V

# %%
# Función de inicialización con valores más estables
class StableInitialCondition(UserExpression):
    def __init__(self, min_val, max_val, **kwargs):
        super().__init__(**kwargs)
        self.min_val = min_val
        self.max_val = max_val

    def eval(self, value, x):
        value[0] = 0.5 * (self.min_val + self.max_val)  # Valor estable

# %%
def solve_dynamics():

    # Define functions for c, s, and i
    V = create_space_function(space_size, nodes_in_xaxis, nodes_in_yaxis)

    c = Function(V)
    s = Function(V)
    i = Function(V)

    phi_c = TestFunction(V)
    phi_s = TestFunction(V)
    phi_i = TestFunction(V)

    # # Define the weak forms for the equations with time dependence

    # Condición inicial aleatoria   
    c_n = interpolate(RandomExpression(min_val=0, max_val=0.02, degree=2), V)
    # Condición inicial con concentración definida 
    # c_n = interpolate(CancerInitialCondition(centers, radius, value_outside, value_inside, degree=2), V)
    s_n = interpolate(RandomExpression(min_val=0, max_val=0.2, degree=2), V)
    i_n = interpolate(RandomExpression(min_val=0, max_val=0.2, degree=2), V)
    
    if mu == 0:
        F_c = ((c - c_n) / dt) * phi_c * dx + D_c * dot(grad(c), grad(phi_c)) * dx + rc * c * (1 - c) * ((c - alle) / (1 - alle)) * phi_c * dx - c*(alpha*s**2 + beta*i**2) * phi_c * dx
        F_s = ((s - s_n) / dt) * phi_s * dx + D_s * dot(grad(s), grad(phi_s)) * dx + rs * s * (1 - s) * phi_s * dx - gamma * c**2 * s * phi_s * dx + delta * i**2 * s * phi_s * dx
        F_i = ((i - i_n) / dt) * phi_i * dx + D_i * dot(grad(i), grad(phi_i)) * dx + rd * i * (1 - i) * phi_i * dx + delta * i * s**2 * phi_i * dx - c**2 * i * eta * phi_i * dx
    else:
        F_c = ((c - c_n) / dt) * phi_c * dx + D_c * dot(grad(c), grad(phi_c)) * dx + rc * c * (1 - c) * ((c - alle) / (1 - alle)) * phi_c * dx - c*(alpha*s**2 + beta*i**2) * phi_c * dx - mu * c*(gamma * s**2 + eta*i**2) * phi_c * dx
        F_s = ((s - s_n) / dt) * phi_s * dx + D_s * dot(grad(s), grad(phi_s)) * dx + rs * s * (1 - s) * phi_s * dx - gamma * c**2 * s * phi_s * dx + delta * i**2 * s * phi_s * dx - ((s*c**2*alpha*mu)/2) * phi_s * dx
        F_i = ((i - i_n) / dt) * phi_i * dx + D_i * dot(grad(i), grad(phi_i)) * dx + rd * i * (1 - i) * phi_i * dx + delta * i * s**2 * phi_i * dx - c**2 * i * eta * phi_i * dx - ((i*c**2*beta*mu)/2) * phi_i * dx

    
    solver_c = NonlinearSolver(F_c, c)
    solver_s = NonlinearSolver(F_s, s)
    solver_i = NonlinearSolver(F_i, i)

    return solver_c, solver_s, solver_i, c, s, i, c_n, s_n, i_n, dx

# %%
# Iteración en bloques
for block in range(1, nb + 1):
    t = 0
    solver_c, solver_s, solver_i, c, s, i, c_n, s_n, i_n, dx = solve_dynamics()
    while t < T:
        print(f'Bloque {block}, Tiempo {t:.3f}')

        # Resolver el sistema
        try:
            solver_c.solve()
            solver_s.solve()
            solver_i.solve()
        except RuntimeError as e:
            print(f"Error en bloque {block} en t={t:.3f}: {e}")
            break

        # Actualizar solución previa
        c_n.assign(c)
        s_n.assign(s)
        i_n.assign(i)

        field_to_numpy_array(c, space_size, "{:.3f}".format(t), "c", block)
        field_to_numpy_array(s, space_size, "{:.3f}".format(t), "s", block)
        field_to_numpy_array(i, space_size, "{:.3f}".format(t), "i", block)
        if block == 1:
            # plot_fields(c_n, s_n, i_n, block)
            t += dt
        else:
            t += dt
# Out:
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# Bloque 1, Tiempo 0.000
# Bloque 1, Tiempo 0.005
# Bloque 1, Tiempo 0.010
# Bloque 1, Tiempo 0.015
# Bloque 1, Tiempo 0.020
# Bloque 1, Tiempo 0.025
# Bloque 1, Tiempo 0.030
# Bloque 1, Tiempo 0.035
# Bloque 1, Tiempo 0.040
# Bloque 1, Tiempo 0.045
# Bloque 1, Tiempo 0.050
# Bloque 1, Tiempo 0.055
# Bloque 1, Tiempo 0.060
# Bloque 1, Tiempo 0.065
# Bloque 1, Tiempo 0.070
# Bloque 1, Tiempo 0.075
# Bloque 1, Tiempo 0.080
# Bloque 1, Tiempo 0.085
# Bloque 1, Tiempo 0.090
# Bloque 1, Tiempo 0.095
# Bloque 1, Tiempo 0.100
# Bloque 1, Tiempo 0.105
# Bloque 1, Tiempo 0.110
# Bloque 1, Tiempo 0.115
# Bloque 1, Tiempo 0.120
# Bloque 1, Tiempo 0.125
# Bloque 1, Tiempo 0.130
# Bloque 1, Tiempo 0.135
# Bloque 1, Tiempo 0.140
# Bloque 1, Tiempo 0.145
# Bloque 1, Tiempo 0.150
# Bloque 1, Tiempo 0.155
# Bloque 1, Tiempo 0.160
# Bloque 1, Tiempo 0.165
# Bloque 1, Tiempo 0.170
# Bloque 1, Tiempo 0.175
# Bloque 1, Tiempo 0.180
# Bloque 1, Tiempo 0.185
# Bloque 1, Tiempo 0.190
# Bloque 1, Tiempo 0.195
# Bloque 1, Tiempo 0.200
# Bloque 1, Tiempo 0.205
# Bloque 1, Tiempo 0.210
# Bloque 1, Tiempo 0.215
# Bloque 1, Tiempo 0.220
# Bloque 1, Tiempo 0.225
# Bloque 1, Tiempo 0.230
# Bloque 1, Tiempo 0.235
# Bloque 1, Tiempo 0.240
# Bloque 1, Tiempo 0.245
# Bloque 1, Tiempo 0.250
# Bloque 1, Tiempo 0.255
# Bloque 1, Tiempo 0.260
# Bloque 1, Tiempo 0.265
# Bloque 1, Tiempo 0.270
# Bloque 1, Tiempo 0.275
# Bloque 1, Tiempo 0.280
# Bloque 1, Tiempo 0.285
# Bloque 1, Tiempo 0.290
# Bloque 1, Tiempo 0.295
# Bloque 1, Tiempo 0.300
# Bloque 1, Tiempo 0.305
# Bloque 1, Tiempo 0.310
# Bloque 1, Tiempo 0.315
# Bloque 1, Tiempo 0.320
# Bloque 1, Tiempo 0.325
# Bloque 1, Tiempo 0.330
# Bloque 1, Tiempo 0.335
# Bloque 1, Tiempo 0.340
# Bloque 1, Tiempo 0.345
# Bloque 1, Tiempo 0.350
# Bloque 1, Tiempo 0.355
# Bloque 1, Tiempo 0.360
# Bloque 1, Tiempo 0.365
# Bloque 1, Tiempo 0.370
# Bloque 1, Tiempo 0.375
# Bloque 1, Tiempo 0.380
# Bloque 1, Tiempo 0.385
# Bloque 1, Tiempo 0.390
# Bloque 1, Tiempo 0.395
# Bloque 1, Tiempo 0.400
# Bloque 1, Tiempo 0.405
# Bloque 1, Tiempo 0.410
# Bloque 1, Tiempo 0.415
# Bloque 1, Tiempo 0.420
# Bloque 1, Tiempo 0.425
# Bloque 1, Tiempo 0.430
# Bloque 1, Tiempo 0.435
# Bloque 1, Tiempo 0.440
# Bloque 1, Tiempo 0.445
# Bloque 1, Tiempo 0.450
# Bloque 1, Tiempo 0.455
# Bloque 1, Tiempo 0.460
# Bloque 1, Tiempo 0.465
# Bloque 1, Tiempo 0.470
# Bloque 1, Tiempo 0.475
# Bloque 1, Tiempo 0.480
# Bloque 1, Tiempo 0.485
# Bloque 1, Tiempo 0.490
# Bloque 1, Tiempo 0.495
# Bloque 1, Tiempo 0.500
# Bloque 1, Tiempo 0.505
# Bloque 1, Tiempo 0.510
# Bloque 1, Tiempo 0.515
# Bloque 1, Tiempo 0.520
# Bloque 1, Tiempo 0.525
# Bloque 1, Tiempo 0.530
# Bloque 1, Tiempo 0.535
# Bloque 1, Tiempo 0.540
# Bloque 1, Tiempo 0.545
# Bloque 1, Tiempo 0.550
# Bloque 1, Tiempo 0.555
# Bloque 1, Tiempo 0.560
# Bloque 1, Tiempo 0.565
# Bloque 1, Tiempo 0.570
# Bloque 1, Tiempo 0.575
# Bloque 1, Tiempo 0.580
# Bloque 1, Tiempo 0.585
# Bloque 1, Tiempo 0.590
# Bloque 1, Tiempo 0.595
# Bloque 1, Tiempo 0.600
# Bloque 1, Tiempo 0.605
# Bloque 1, Tiempo 0.610
# Bloque 1, Tiempo 0.615
# Bloque 1, Tiempo 0.620
# Bloque 1, Tiempo 0.625
# Bloque 1, Tiempo 0.630
# Bloque 1, Tiempo 0.635
# Bloque 1, Tiempo 0.640
# Bloque 1, Tiempo 0.645
# Bloque 1, Tiempo 0.650
# Bloque 1, Tiempo 0.655
# Bloque 1, Tiempo 0.660
# Bloque 1, Tiempo 0.665
# Bloque 1, Tiempo 0.670
# Bloque 1, Tiempo 0.675
# Bloque 1, Tiempo 0.680
# Bloque 1, Tiempo 0.685
# Bloque 1, Tiempo 0.690
# Bloque 1, Tiempo 0.695
# Bloque 1, Tiempo 0.700
# Bloque 1, Tiempo 0.705
# Bloque 1, Tiempo 0.710
# Bloque 1, Tiempo 0.715
# Bloque 1, Tiempo 0.720
# Bloque 1, Tiempo 0.725
# Bloque 1, Tiempo 0.730
# Bloque 1, Tiempo 0.735
# Bloque 1, Tiempo 0.740
# Bloque 1, Tiempo 0.745
# Bloque 1, Tiempo 0.750
# Bloque 1, Tiempo 0.755
# Bloque 1, Tiempo 0.760
# Bloque 1, Tiempo 0.765
# Bloque 1, Tiempo 0.770
# Bloque 1, Tiempo 0.775
# Bloque 1, Tiempo 0.780
# Bloque 1, Tiempo 0.785
# Bloque 1, Tiempo 0.790
# Bloque 1, Tiempo 0.795
# Bloque 1, Tiempo 0.800
# Bloque 1, Tiempo 0.805
# Bloque 1, Tiempo 0.810
# Bloque 1, Tiempo 0.815
# Bloque 1, Tiempo 0.820
# Bloque 1, Tiempo 0.825
# Bloque 1, Tiempo 0.830
# Bloque 1, Tiempo 0.835
# Bloque 1, Tiempo 0.840
# Bloque 1, Tiempo 0.845
# Bloque 1, Tiempo 0.850
# Bloque 1, Tiempo 0.855
# Bloque 1, Tiempo 0.860
# Bloque 1, Tiempo 0.865
# Bloque 1, Tiempo 0.870
# Bloque 1, Tiempo 0.875
# Bloque 1, Tiempo 0.880
# Bloque 1, Tiempo 0.885
# Bloque 1, Tiempo 0.890
# Bloque 1, Tiempo 0.895
# Bloque 1, Tiempo 0.900
# Bloque 1, Tiempo 0.905
# Bloque 1, Tiempo 0.910
# Bloque 1, Tiempo 0.915
# Bloque 1, Tiempo 0.920
# Bloque 1, Tiempo 0.925
# Bloque 1, Tiempo 0.930
# Bloque 1, Tiempo 0.935
# Bloque 1, Tiempo 0.940
# Bloque 1, Tiempo 0.945
# Bloque 1, Tiempo 0.950
# Bloque 1, Tiempo 0.955
# Bloque 1, Tiempo 0.960
# Bloque 1, Tiempo 0.965
# Bloque 1, Tiempo 0.970
# Bloque 1, Tiempo 0.975
# Bloque 1, Tiempo 0.980
# Bloque 1, Tiempo 0.985
# Bloque 1, Tiempo 0.990
# Bloque 1, Tiempo 0.995
# Bloque 1, Tiempo 1.000
# Bloque 1, Tiempo 1.005
# Bloque 1, Tiempo 1.010
# Bloque 1, Tiempo 1.015
# Bloque 1, Tiempo 1.020
# Bloque 1, Tiempo 1.025
# Bloque 1, Tiempo 1.030
# Bloque 1, Tiempo 1.035
# Bloque 1, Tiempo 1.040
# Bloque 1, Tiempo 1.045
# Bloque 1, Tiempo 1.050
# Bloque 1, Tiempo 1.055
# Bloque 1, Tiempo 1.060
# Bloque 1, Tiempo 1.065
# Bloque 1, Tiempo 1.070
# Bloque 1, Tiempo 1.075
# Bloque 1, Tiempo 1.080
# Bloque 1, Tiempo 1.085
# Bloque 1, Tiempo 1.090
# Bloque 1, Tiempo 1.095
# Bloque 1, Tiempo 1.100
# Bloque 1, Tiempo 1.105
# Bloque 1, Tiempo 1.110
# Bloque 1, Tiempo 1.115
# Bloque 1, Tiempo 1.120
# Bloque 1, Tiempo 1.125
# Bloque 1, Tiempo 1.130
# Bloque 1, Tiempo 1.135
# Bloque 1, Tiempo 1.140
# Bloque 1, Tiempo 1.145
# Bloque 1, Tiempo 1.150
# Bloque 1, Tiempo 1.155
# Bloque 1, Tiempo 1.160
# Bloque 1, Tiempo 1.165
# Bloque 1, Tiempo 1.170
# Bloque 1, Tiempo 1.175
# Bloque 1, Tiempo 1.180
# Bloque 1, Tiempo 1.185
# Bloque 1, Tiempo 1.190
# Bloque 1, Tiempo 1.195
# Bloque 1, Tiempo 1.200
# Bloque 1, Tiempo 1.205
# Bloque 1, Tiempo 1.210
# Bloque 1, Tiempo 1.215
# Bloque 1, Tiempo 1.220
# Bloque 1, Tiempo 1.225
# Bloque 1, Tiempo 1.230
# Bloque 1, Tiempo 1.235
# Bloque 1, Tiempo 1.240
# Bloque 1, Tiempo 1.245
# Bloque 1, Tiempo 1.250
# Bloque 1, Tiempo 1.255
# Bloque 1, Tiempo 1.260
# Bloque 1, Tiempo 1.265
# Bloque 1, Tiempo 1.270
# Bloque 1, Tiempo 1.275
# Bloque 1, Tiempo 1.280
# Bloque 1, Tiempo 1.285
# Bloque 1, Tiempo 1.290
# Bloque 1, Tiempo 1.295
# Bloque 1, Tiempo 1.300
# Bloque 1, Tiempo 1.305
# Bloque 1, Tiempo 1.310
# Bloque 1, Tiempo 1.315
# Bloque 1, Tiempo 1.320
# Bloque 1, Tiempo 1.325
# Bloque 1, Tiempo 1.330
# Bloque 1, Tiempo 1.335
# Bloque 1, Tiempo 1.340
# Bloque 1, Tiempo 1.345
# Bloque 1, Tiempo 1.350
# Bloque 1, Tiempo 1.355
# Bloque 1, Tiempo 1.360
# Bloque 1, Tiempo 1.365
# Bloque 1, Tiempo 1.370
# Bloque 1, Tiempo 1.375
# Bloque 1, Tiempo 1.380
# Bloque 1, Tiempo 1.385
# Bloque 1, Tiempo 1.390
# Bloque 1, Tiempo 1.395
# Bloque 1, Tiempo 1.400
# Bloque 1, Tiempo 1.405
# Bloque 1, Tiempo 1.410
# Bloque 1, Tiempo 1.415
# Bloque 1, Tiempo 1.420
# Bloque 1, Tiempo 1.425
# Bloque 1, Tiempo 1.430
# Bloque 1, Tiempo 1.435
# Bloque 1, Tiempo 1.440
# Bloque 1, Tiempo 1.445
# Bloque 1, Tiempo 1.450
# Bloque 1, Tiempo 1.455
# Bloque 1, Tiempo 1.460
# Bloque 1, Tiempo 1.465
# Bloque 1, Tiempo 1.470
# Bloque 1, Tiempo 1.475
# Bloque 1, Tiempo 1.480
# Bloque 1, Tiempo 1.485
# Bloque 1, Tiempo 1.490
# Bloque 1, Tiempo 1.495
# Bloque 1, Tiempo 1.500
# Bloque 1, Tiempo 1.505
# Bloque 1, Tiempo 1.510
# Bloque 1, Tiempo 1.515
# Bloque 1, Tiempo 1.520
# Bloque 1, Tiempo 1.525
# Bloque 1, Tiempo 1.530
# Bloque 1, Tiempo 1.535
# Bloque 1, Tiempo 1.540
# Bloque 1, Tiempo 1.545
# Bloque 1, Tiempo 1.550
# Bloque 1, Tiempo 1.555
# Bloque 1, Tiempo 1.560
# Bloque 1, Tiempo 1.565
# Bloque 1, Tiempo 1.570
# Bloque 1, Tiempo 1.575
# Bloque 1, Tiempo 1.580
# Bloque 1, Tiempo 1.585
# Bloque 1, Tiempo 1.590
# Bloque 1, Tiempo 1.595
# Bloque 1, Tiempo 1.600
# Bloque 1, Tiempo 1.605
# Bloque 1, Tiempo 1.610
# Bloque 1, Tiempo 1.615
# Bloque 1, Tiempo 1.620
# Bloque 1, Tiempo 1.625
# Bloque 1, Tiempo 1.630
# Bloque 1, Tiempo 1.635
# Bloque 1, Tiempo 1.640
# Bloque 1, Tiempo 1.645
# Bloque 1, Tiempo 1.650
# Bloque 1, Tiempo 1.655
# Bloque 1, Tiempo 1.660
# Bloque 1, Tiempo 1.665
# Bloque 1, Tiempo 1.670
# Bloque 1, Tiempo 1.675
# Bloque 1, Tiempo 1.680
# Bloque 1, Tiempo 1.685
# Bloque 1, Tiempo 1.690
# Bloque 1, Tiempo 1.695
# Bloque 1, Tiempo 1.700
# Bloque 1, Tiempo 1.705
# Bloque 1, Tiempo 1.710
# Bloque 1, Tiempo 1.715
# Bloque 1, Tiempo 1.720
# Bloque 1, Tiempo 1.725
# Bloque 1, Tiempo 1.730
# Bloque 1, Tiempo 1.735
# Bloque 1, Tiempo 1.740
# Bloque 1, Tiempo 1.745
# Bloque 1, Tiempo 1.750
# Bloque 1, Tiempo 1.755
# Bloque 1, Tiempo 1.760
# Bloque 1, Tiempo 1.765
# Bloque 1, Tiempo 1.770
# Bloque 1, Tiempo 1.775
# Bloque 1, Tiempo 1.780
# Bloque 1, Tiempo 1.785
# Bloque 1, Tiempo 1.790
# Bloque 1, Tiempo 1.795
# Bloque 1, Tiempo 1.800
# Bloque 1, Tiempo 1.805
# Bloque 1, Tiempo 1.810
# Bloque 1, Tiempo 1.815
# Bloque 1, Tiempo 1.820
# Bloque 1, Tiempo 1.825
# Bloque 1, Tiempo 1.830
# Bloque 1, Tiempo 1.835
# Bloque 1, Tiempo 1.840
# Bloque 1, Tiempo 1.845
# Bloque 1, Tiempo 1.850
# Bloque 1, Tiempo 1.855
# Bloque 1, Tiempo 1.860
# Bloque 1, Tiempo 1.865
# Bloque 1, Tiempo 1.870
# Bloque 1, Tiempo 1.875
# Bloque 1, Tiempo 1.880
# Bloque 1, Tiempo 1.885
# Bloque 1, Tiempo 1.890
# Bloque 1, Tiempo 1.895
# Bloque 1, Tiempo 1.900
# Bloque 1, Tiempo 1.905
# Bloque 1, Tiempo 1.910
# Bloque 1, Tiempo 1.915
# Bloque 1, Tiempo 1.920
# Bloque 1, Tiempo 1.925
# Bloque 1, Tiempo 1.930
# Bloque 1, Tiempo 1.935
# Bloque 1, Tiempo 1.940
# Bloque 1, Tiempo 1.945
# Bloque 1, Tiempo 1.950
# Bloque 1, Tiempo 1.955
# Bloque 1, Tiempo 1.960
# Bloque 1, Tiempo 1.965
# Bloque 1, Tiempo 1.970
# Bloque 1, Tiempo 1.975
# Bloque 1, Tiempo 1.980
# Bloque 1, Tiempo 1.985
# Bloque 1, Tiempo 1.990
# Bloque 1, Tiempo 1.995
# Bloque 1, Tiempo 2.000
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# Bloque 2, Tiempo 0.000
# Bloque 2, Tiempo 0.005
# Bloque 2, Tiempo 0.010
# Bloque 2, Tiempo 0.015
# Bloque 2, Tiempo 0.020
# Bloque 2, Tiempo 0.025
# Bloque 2, Tiempo 0.030
# Bloque 2, Tiempo 0.035
# Bloque 2, Tiempo 0.040
# Bloque 2, Tiempo 0.045
# Bloque 2, Tiempo 0.050
# Bloque 2, Tiempo 0.055
# Bloque 2, Tiempo 0.060
# Bloque 2, Tiempo 0.065
# Bloque 2, Tiempo 0.070
# Bloque 2, Tiempo 0.075
# Bloque 2, Tiempo 0.080
# Bloque 2, Tiempo 0.085
# Bloque 2, Tiempo 0.090
# Bloque 2, Tiempo 0.095
# Bloque 2, Tiempo 0.100
# Bloque 2, Tiempo 0.105
# Bloque 2, Tiempo 0.110
# Bloque 2, Tiempo 0.115
# Bloque 2, Tiempo 0.120
# Bloque 2, Tiempo 0.125
# Bloque 2, Tiempo 0.130
# Bloque 2, Tiempo 0.135
# Bloque 2, Tiempo 0.140
# Bloque 2, Tiempo 0.145
# Bloque 2, Tiempo 0.150
# Bloque 2, Tiempo 0.155
# Bloque 2, Tiempo 0.160
# Bloque 2, Tiempo 0.165
# Bloque 2, Tiempo 0.170
# Bloque 2, Tiempo 0.175
# Bloque 2, Tiempo 0.180
# Bloque 2, Tiempo 0.185
# Bloque 2, Tiempo 0.190
# Bloque 2, Tiempo 0.195
# Bloque 2, Tiempo 0.200
# Bloque 2, Tiempo 0.205
# Bloque 2, Tiempo 0.210
# Bloque 2, Tiempo 0.215
# Bloque 2, Tiempo 0.220
# Bloque 2, Tiempo 0.225
# Bloque 2, Tiempo 0.230
# Bloque 2, Tiempo 0.235
# Bloque 2, Tiempo 0.240
# Bloque 2, Tiempo 0.245
# Bloque 2, Tiempo 0.250
# Bloque 2, Tiempo 0.255
# Bloque 2, Tiempo 0.260
# Bloque 2, Tiempo 0.265
# Bloque 2, Tiempo 0.270
# Bloque 2, Tiempo 0.275
# Bloque 2, Tiempo 0.280
# Bloque 2, Tiempo 0.285
# Bloque 2, Tiempo 0.290
# Bloque 2, Tiempo 0.295
# Bloque 2, Tiempo 0.300
# Bloque 2, Tiempo 0.305
# Bloque 2, Tiempo 0.310
# Bloque 2, Tiempo 0.315
# Bloque 2, Tiempo 0.320
# Bloque 2, Tiempo 0.325
# Bloque 2, Tiempo 0.330
# Bloque 2, Tiempo 0.335
# Bloque 2, Tiempo 0.340
# Bloque 2, Tiempo 0.345
# Bloque 2, Tiempo 0.350
# Bloque 2, Tiempo 0.355
# Bloque 2, Tiempo 0.360
# Bloque 2, Tiempo 0.365
# Bloque 2, Tiempo 0.370
# Bloque 2, Tiempo 0.375
# Bloque 2, Tiempo 0.380
# Bloque 2, Tiempo 0.385
# Bloque 2, Tiempo 0.390
# Bloque 2, Tiempo 0.395
# Bloque 2, Tiempo 0.400
# Bloque 2, Tiempo 0.405
# Bloque 2, Tiempo 0.410
# Bloque 2, Tiempo 0.415
# Bloque 2, Tiempo 0.420
# Bloque 2, Tiempo 0.425
# Bloque 2, Tiempo 0.430
# Bloque 2, Tiempo 0.435
# Bloque 2, Tiempo 0.440
# Bloque 2, Tiempo 0.445
# Bloque 2, Tiempo 0.450
# Bloque 2, Tiempo 0.455
# Bloque 2, Tiempo 0.460
# Bloque 2, Tiempo 0.465
# Bloque 2, Tiempo 0.470
# Bloque 2, Tiempo 0.475
# Bloque 2, Tiempo 0.480
# Bloque 2, Tiempo 0.485
# Bloque 2, Tiempo 0.490
# Bloque 2, Tiempo 0.495
# Bloque 2, Tiempo 0.500
# Bloque 2, Tiempo 0.505
# Bloque 2, Tiempo 0.510
# Bloque 2, Tiempo 0.515
# Bloque 2, Tiempo 0.520
# Bloque 2, Tiempo 0.525
# Bloque 2, Tiempo 0.530
# Bloque 2, Tiempo 0.535
# Bloque 2, Tiempo 0.540
# Bloque 2, Tiempo 0.545
# Bloque 2, Tiempo 0.550
# Bloque 2, Tiempo 0.555
# Bloque 2, Tiempo 0.560
# Bloque 2, Tiempo 0.565
# Bloque 2, Tiempo 0.570
# Bloque 2, Tiempo 0.575
# Bloque 2, Tiempo 0.580
# Bloque 2, Tiempo 0.585
# Bloque 2, Tiempo 0.590
# Bloque 2, Tiempo 0.595
# Bloque 2, Tiempo 0.600
# Bloque 2, Tiempo 0.605
# Bloque 2, Tiempo 0.610
# Bloque 2, Tiempo 0.615
# Bloque 2, Tiempo 0.620
# Bloque 2, Tiempo 0.625
# Bloque 2, Tiempo 0.630
# Bloque 2, Tiempo 0.635
# Bloque 2, Tiempo 0.640
# Bloque 2, Tiempo 0.645
# Bloque 2, Tiempo 0.650
# Bloque 2, Tiempo 0.655
# Bloque 2, Tiempo 0.660
# Bloque 2, Tiempo 0.665
# Bloque 2, Tiempo 0.670
# Bloque 2, Tiempo 0.675
# Bloque 2, Tiempo 0.680
# Bloque 2, Tiempo 0.685
# Bloque 2, Tiempo 0.690
# Bloque 2, Tiempo 0.695
# Bloque 2, Tiempo 0.700
# Bloque 2, Tiempo 0.705
# Bloque 2, Tiempo 0.710
# Bloque 2, Tiempo 0.715
# Bloque 2, Tiempo 0.720
# Bloque 2, Tiempo 0.725
# Bloque 2, Tiempo 0.730
# Bloque 2, Tiempo 0.735
# Bloque 2, Tiempo 0.740
# Bloque 2, Tiempo 0.745
# Bloque 2, Tiempo 0.750
# Bloque 2, Tiempo 0.755
# Bloque 2, Tiempo 0.760
# Bloque 2, Tiempo 0.765
# Bloque 2, Tiempo 0.770
# Bloque 2, Tiempo 0.775
# Bloque 2, Tiempo 0.780
# Bloque 2, Tiempo 0.785
# Bloque 2, Tiempo 0.790
# Bloque 2, Tiempo 0.795
# Bloque 2, Tiempo 0.800
# Bloque 2, Tiempo 0.805
# Bloque 2, Tiempo 0.810
# Bloque 2, Tiempo 0.815
# Bloque 2, Tiempo 0.820
# Bloque 2, Tiempo 0.825
# Bloque 2, Tiempo 0.830
# Bloque 2, Tiempo 0.835
# Bloque 2, Tiempo 0.840
# Bloque 2, Tiempo 0.845
# Bloque 2, Tiempo 0.850
# Bloque 2, Tiempo 0.855
# Bloque 2, Tiempo 0.860
# Bloque 2, Tiempo 0.865
# Bloque 2, Tiempo 0.870
# Bloque 2, Tiempo 0.875
# Bloque 2, Tiempo 0.880
# Bloque 2, Tiempo 0.885
# Bloque 2, Tiempo 0.890
# Bloque 2, Tiempo 0.895
# Bloque 2, Tiempo 0.900
# Bloque 2, Tiempo 0.905
# Bloque 2, Tiempo 0.910
# Bloque 2, Tiempo 0.915
# Bloque 2, Tiempo 0.920
# Bloque 2, Tiempo 0.925
# Bloque 2, Tiempo 0.930
# Bloque 2, Tiempo 0.935
# Bloque 2, Tiempo 0.940
# Bloque 2, Tiempo 0.945
# Bloque 2, Tiempo 0.950
# Bloque 2, Tiempo 0.955
# Bloque 2, Tiempo 0.960
# Bloque 2, Tiempo 0.965
# Bloque 2, Tiempo 0.970
# Bloque 2, Tiempo 0.975
# Bloque 2, Tiempo 0.980
# Bloque 2, Tiempo 0.985
# Bloque 2, Tiempo 0.990
# Bloque 2, Tiempo 0.995
# Bloque 2, Tiempo 1.000
# Bloque 2, Tiempo 1.005
# Bloque 2, Tiempo 1.010
# Bloque 2, Tiempo 1.015
# Bloque 2, Tiempo 1.020
# Bloque 2, Tiempo 1.025
# Bloque 2, Tiempo 1.030
# Bloque 2, Tiempo 1.035
# Bloque 2, Tiempo 1.040
# Bloque 2, Tiempo 1.045
# Bloque 2, Tiempo 1.050
# Bloque 2, Tiempo 1.055
# Bloque 2, Tiempo 1.060
# Bloque 2, Tiempo 1.065
# Bloque 2, Tiempo 1.070
# Bloque 2, Tiempo 1.075
# Bloque 2, Tiempo 1.080
# Bloque 2, Tiempo 1.085
# Bloque 2, Tiempo 1.090
# Bloque 2, Tiempo 1.095
# Bloque 2, Tiempo 1.100
# Bloque 2, Tiempo 1.105
# Bloque 2, Tiempo 1.110
# Bloque 2, Tiempo 1.115
# Bloque 2, Tiempo 1.120
# Bloque 2, Tiempo 1.125
# Bloque 2, Tiempo 1.130
# Bloque 2, Tiempo 1.135
# Bloque 2, Tiempo 1.140
# Bloque 2, Tiempo 1.145
# Bloque 2, Tiempo 1.150
# Bloque 2, Tiempo 1.155
# Bloque 2, Tiempo 1.160
# Bloque 2, Tiempo 1.165
# Bloque 2, Tiempo 1.170
# Bloque 2, Tiempo 1.175
# Bloque 2, Tiempo 1.180
# Bloque 2, Tiempo 1.185
# Bloque 2, Tiempo 1.190
# Bloque 2, Tiempo 1.195
# Bloque 2, Tiempo 1.200
# Bloque 2, Tiempo 1.205
# Bloque 2, Tiempo 1.210
# Bloque 2, Tiempo 1.215
# Bloque 2, Tiempo 1.220
# Bloque 2, Tiempo 1.225
# Bloque 2, Tiempo 1.230
# Bloque 2, Tiempo 1.235
# Bloque 2, Tiempo 1.240
# Bloque 2, Tiempo 1.245
# Bloque 2, Tiempo 1.250
# Bloque 2, Tiempo 1.255
# Bloque 2, Tiempo 1.260
# Bloque 2, Tiempo 1.265
# Bloque 2, Tiempo 1.270
# Bloque 2, Tiempo 1.275
# Bloque 2, Tiempo 1.280
# Bloque 2, Tiempo 1.285
# Bloque 2, Tiempo 1.290
# Bloque 2, Tiempo 1.295
# Bloque 2, Tiempo 1.300
# Bloque 2, Tiempo 1.305
# Bloque 2, Tiempo 1.310
# Bloque 2, Tiempo 1.315
# Bloque 2, Tiempo 1.320
# Bloque 2, Tiempo 1.325
# Bloque 2, Tiempo 1.330
# Bloque 2, Tiempo 1.335
# Bloque 2, Tiempo 1.340
# Bloque 2, Tiempo 1.345
# Bloque 2, Tiempo 1.350
# Bloque 2, Tiempo 1.355
# Bloque 2, Tiempo 1.360
# Bloque 2, Tiempo 1.365
# Bloque 2, Tiempo 1.370
# Bloque 2, Tiempo 1.375
# Bloque 2, Tiempo 1.380
# Bloque 2, Tiempo 1.385
# Bloque 2, Tiempo 1.390
# Bloque 2, Tiempo 1.395
# Bloque 2, Tiempo 1.400
# Bloque 2, Tiempo 1.405
# Bloque 2, Tiempo 1.410
# Bloque 2, Tiempo 1.415
# Bloque 2, Tiempo 1.420
# Bloque 2, Tiempo 1.425
# Bloque 2, Tiempo 1.430
# Bloque 2, Tiempo 1.435
# Bloque 2, Tiempo 1.440
# Bloque 2, Tiempo 1.445
# Bloque 2, Tiempo 1.450
# Bloque 2, Tiempo 1.455
# Bloque 2, Tiempo 1.460
# Bloque 2, Tiempo 1.465
# Bloque 2, Tiempo 1.470
# Bloque 2, Tiempo 1.475
# Bloque 2, Tiempo 1.480
# Bloque 2, Tiempo 1.485
# Bloque 2, Tiempo 1.490
# Bloque 2, Tiempo 1.495
# Bloque 2, Tiempo 1.500
# Bloque 2, Tiempo 1.505
# Bloque 2, Tiempo 1.510
# Bloque 2, Tiempo 1.515
# Bloque 2, Tiempo 1.520
# Bloque 2, Tiempo 1.525
# Bloque 2, Tiempo 1.530
# Bloque 2, Tiempo 1.535
# Bloque 2, Tiempo 1.540
# Bloque 2, Tiempo 1.545
# Bloque 2, Tiempo 1.550
# Bloque 2, Tiempo 1.555
# Bloque 2, Tiempo 1.560
# Bloque 2, Tiempo 1.565
# Bloque 2, Tiempo 1.570
# Bloque 2, Tiempo 1.575
# Bloque 2, Tiempo 1.580
# Bloque 2, Tiempo 1.585
# Bloque 2, Tiempo 1.590
# Bloque 2, Tiempo 1.595
# Bloque 2, Tiempo 1.600
# Bloque 2, Tiempo 1.605
# Bloque 2, Tiempo 1.610
# Bloque 2, Tiempo 1.615
# Bloque 2, Tiempo 1.620
# Bloque 2, Tiempo 1.625
# Bloque 2, Tiempo 1.630
# Bloque 2, Tiempo 1.635
# Bloque 2, Tiempo 1.640
# Bloque 2, Tiempo 1.645
# Bloque 2, Tiempo 1.650
# Bloque 2, Tiempo 1.655
# Bloque 2, Tiempo 1.660
# Bloque 2, Tiempo 1.665
# Bloque 2, Tiempo 1.670
# Bloque 2, Tiempo 1.675
# Bloque 2, Tiempo 1.680
# Bloque 2, Tiempo 1.685
# Bloque 2, Tiempo 1.690
# Bloque 2, Tiempo 1.695
# Bloque 2, Tiempo 1.700
# Bloque 2, Tiempo 1.705
# Bloque 2, Tiempo 1.710
# Bloque 2, Tiempo 1.715
# Bloque 2, Tiempo 1.720
# Bloque 2, Tiempo 1.725
# Bloque 2, Tiempo 1.730
# Bloque 2, Tiempo 1.735
# Bloque 2, Tiempo 1.740
# Bloque 2, Tiempo 1.745
# Bloque 2, Tiempo 1.750
# Bloque 2, Tiempo 1.755
# Bloque 2, Tiempo 1.760
# Bloque 2, Tiempo 1.765
# Bloque 2, Tiempo 1.770
# Bloque 2, Tiempo 1.775
# Bloque 2, Tiempo 1.780
# Bloque 2, Tiempo 1.785
# Bloque 2, Tiempo 1.790
# Bloque 2, Tiempo 1.795
# Bloque 2, Tiempo 1.800
# Bloque 2, Tiempo 1.805
# Bloque 2, Tiempo 1.810
# Bloque 2, Tiempo 1.815
# Bloque 2, Tiempo 1.820
# Bloque 2, Tiempo 1.825
# Bloque 2, Tiempo 1.830
# Bloque 2, Tiempo 1.835
# Bloque 2, Tiempo 1.840
# Bloque 2, Tiempo 1.845
# Bloque 2, Tiempo 1.850
# Bloque 2, Tiempo 1.855
# Bloque 2, Tiempo 1.860
# Bloque 2, Tiempo 1.865
# Bloque 2, Tiempo 1.870
# Bloque 2, Tiempo 1.875
# Bloque 2, Tiempo 1.880
# Bloque 2, Tiempo 1.885
# Bloque 2, Tiempo 1.890
# Bloque 2, Tiempo 1.895
# Bloque 2, Tiempo 1.900
# Bloque 2, Tiempo 1.905
# Bloque 2, Tiempo 1.910
# Bloque 2, Tiempo 1.915
# Bloque 2, Tiempo 1.920
# Bloque 2, Tiempo 1.925
# Bloque 2, Tiempo 1.930
# Bloque 2, Tiempo 1.935
# Bloque 2, Tiempo 1.940
# Bloque 2, Tiempo 1.945
# Bloque 2, Tiempo 1.950
# Bloque 2, Tiempo 1.955
# Bloque 2, Tiempo 1.960
# Bloque 2, Tiempo 1.965
# Bloque 2, Tiempo 1.970
# Bloque 2, Tiempo 1.975
# Bloque 2, Tiempo 1.980
# Bloque 2, Tiempo 1.985
# Bloque 2, Tiempo 1.990
# Bloque 2, Tiempo 1.995
# Bloque 2, Tiempo 2.000
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# Bloque 3, Tiempo 0.000
# Bloque 3, Tiempo 0.005
# Bloque 3, Tiempo 0.010
# Bloque 3, Tiempo 0.015
# Bloque 3, Tiempo 0.020
# Bloque 3, Tiempo 0.025
# Bloque 3, Tiempo 0.030
# Bloque 3, Tiempo 0.035
# Bloque 3, Tiempo 0.040
# Bloque 3, Tiempo 0.045
# Bloque 3, Tiempo 0.050
# Bloque 3, Tiempo 0.055
# Bloque 3, Tiempo 0.060
# Bloque 3, Tiempo 0.065
# Bloque 3, Tiempo 0.070
# Bloque 3, Tiempo 0.075
# Bloque 3, Tiempo 0.080
# Bloque 3, Tiempo 0.085
# Bloque 3, Tiempo 0.090
# Bloque 3, Tiempo 0.095
# Bloque 3, Tiempo 0.100
# Bloque 3, Tiempo 0.105
# Bloque 3, Tiempo 0.110
# Bloque 3, Tiempo 0.115
# Bloque 3, Tiempo 0.120
# Bloque 3, Tiempo 0.125
# Bloque 3, Tiempo 0.130
# Bloque 3, Tiempo 0.135
# Bloque 3, Tiempo 0.140
# Bloque 3, Tiempo 0.145
# Bloque 3, Tiempo 0.150
# Bloque 3, Tiempo 0.155
# Bloque 3, Tiempo 0.160
# Bloque 3, Tiempo 0.165
# Bloque 3, Tiempo 0.170
# Bloque 3, Tiempo 0.175
# Bloque 3, Tiempo 0.180
# Bloque 3, Tiempo 0.185
# Bloque 3, Tiempo 0.190
# Bloque 3, Tiempo 0.195
# Bloque 3, Tiempo 0.200
# Bloque 3, Tiempo 0.205
# Bloque 3, Tiempo 0.210
# Bloque 3, Tiempo 0.215
# Bloque 3, Tiempo 0.220
# Bloque 3, Tiempo 0.225
# Bloque 3, Tiempo 0.230
# Bloque 3, Tiempo 0.235
# Bloque 3, Tiempo 0.240
# Bloque 3, Tiempo 0.245
# Bloque 3, Tiempo 0.250
# Bloque 3, Tiempo 0.255
# Bloque 3, Tiempo 0.260
# Bloque 3, Tiempo 0.265
# Bloque 3, Tiempo 0.270
# Bloque 3, Tiempo 0.275
# Bloque 3, Tiempo 0.280
# Bloque 3, Tiempo 0.285
# Bloque 3, Tiempo 0.290
# Bloque 3, Tiempo 0.295
# Bloque 3, Tiempo 0.300
# Bloque 3, Tiempo 0.305
# Bloque 3, Tiempo 0.310
# Bloque 3, Tiempo 0.315
# Bloque 3, Tiempo 0.320
# Bloque 3, Tiempo 0.325
# Bloque 3, Tiempo 0.330
# Bloque 3, Tiempo 0.335
# Bloque 3, Tiempo 0.340
# Bloque 3, Tiempo 0.345
# Bloque 3, Tiempo 0.350
# Bloque 3, Tiempo 0.355
# Bloque 3, Tiempo 0.360
# Bloque 3, Tiempo 0.365
# Bloque 3, Tiempo 0.370
# Bloque 3, Tiempo 0.375
# Bloque 3, Tiempo 0.380
# Bloque 3, Tiempo 0.385
# Bloque 3, Tiempo 0.390
# Bloque 3, Tiempo 0.395
# Bloque 3, Tiempo 0.400
# Bloque 3, Tiempo 0.405
# Bloque 3, Tiempo 0.410
# Bloque 3, Tiempo 0.415
# Bloque 3, Tiempo 0.420
# Bloque 3, Tiempo 0.425
# Bloque 3, Tiempo 0.430
# Bloque 3, Tiempo 0.435
# Bloque 3, Tiempo 0.440
# Bloque 3, Tiempo 0.445
# Bloque 3, Tiempo 0.450
# Bloque 3, Tiempo 0.455
# Bloque 3, Tiempo 0.460
# Bloque 3, Tiempo 0.465
# Bloque 3, Tiempo 0.470
# Bloque 3, Tiempo 0.475
# Bloque 3, Tiempo 0.480
# Bloque 3, Tiempo 0.485
# Bloque 3, Tiempo 0.490
# Bloque 3, Tiempo 0.495
# Bloque 3, Tiempo 0.500
# Bloque 3, Tiempo 0.505
# Bloque 3, Tiempo 0.510
# Bloque 3, Tiempo 0.515
# Bloque 3, Tiempo 0.520
# Bloque 3, Tiempo 0.525
# Bloque 3, Tiempo 0.530
# Bloque 3, Tiempo 0.535
# Bloque 3, Tiempo 0.540
# Bloque 3, Tiempo 0.545
# Bloque 3, Tiempo 0.550
# Bloque 3, Tiempo 0.555
# Bloque 3, Tiempo 0.560
# Bloque 3, Tiempo 0.565
# Bloque 3, Tiempo 0.570
# Bloque 3, Tiempo 0.575
# Bloque 3, Tiempo 0.580
# Bloque 3, Tiempo 0.585
# Bloque 3, Tiempo 0.590
# Bloque 3, Tiempo 0.595
# Bloque 3, Tiempo 0.600
# Bloque 3, Tiempo 0.605
# Bloque 3, Tiempo 0.610
# Bloque 3, Tiempo 0.615
# Bloque 3, Tiempo 0.620
# Bloque 3, Tiempo 0.625
# Bloque 3, Tiempo 0.630
# Bloque 3, Tiempo 0.635
# Bloque 3, Tiempo 0.640
# Bloque 3, Tiempo 0.645
# Bloque 3, Tiempo 0.650
# Bloque 3, Tiempo 0.655
# Bloque 3, Tiempo 0.660
# Bloque 3, Tiempo 0.665
# Bloque 3, Tiempo 0.670
# Bloque 3, Tiempo 0.675
# Bloque 3, Tiempo 0.680
# Bloque 3, Tiempo 0.685
# Bloque 3, Tiempo 0.690
# Bloque 3, Tiempo 0.695
# Bloque 3, Tiempo 0.700
# Bloque 3, Tiempo 0.705
# Bloque 3, Tiempo 0.710
# Bloque 3, Tiempo 0.715
# Bloque 3, Tiempo 0.720
# Bloque 3, Tiempo 0.725
# Bloque 3, Tiempo 0.730
# Bloque 3, Tiempo 0.735
# Bloque 3, Tiempo 0.740
# Bloque 3, Tiempo 0.745
# Bloque 3, Tiempo 0.750
# Bloque 3, Tiempo 0.755
# Bloque 3, Tiempo 0.760
# Bloque 3, Tiempo 0.765
# Bloque 3, Tiempo 0.770
# Bloque 3, Tiempo 0.775
# Bloque 3, Tiempo 0.780
# Bloque 3, Tiempo 0.785
# Bloque 3, Tiempo 0.790
# Bloque 3, Tiempo 0.795
# Bloque 3, Tiempo 0.800
# Bloque 3, Tiempo 0.805
# Bloque 3, Tiempo 0.810
# Bloque 3, Tiempo 0.815
# Bloque 3, Tiempo 0.820
# Bloque 3, Tiempo 0.825
# Bloque 3, Tiempo 0.830
# Bloque 3, Tiempo 0.835
# Bloque 3, Tiempo 0.840
# Bloque 3, Tiempo 0.845
# Bloque 3, Tiempo 0.850
# Bloque 3, Tiempo 0.855
# Bloque 3, Tiempo 0.860
# Bloque 3, Tiempo 0.865
# Bloque 3, Tiempo 0.870
# Bloque 3, Tiempo 0.875
# Bloque 3, Tiempo 0.880
# Bloque 3, Tiempo 0.885
# Bloque 3, Tiempo 0.890
# Bloque 3, Tiempo 0.895
# Bloque 3, Tiempo 0.900
# Bloque 3, Tiempo 0.905
# Bloque 3, Tiempo 0.910
# Bloque 3, Tiempo 0.915
# Bloque 3, Tiempo 0.920
# Bloque 3, Tiempo 0.925
# Bloque 3, Tiempo 0.930
# Bloque 3, Tiempo 0.935
# Bloque 3, Tiempo 0.940
# Bloque 3, Tiempo 0.945
# Bloque 3, Tiempo 0.950
# Bloque 3, Tiempo 0.955
# Bloque 3, Tiempo 0.960
# Bloque 3, Tiempo 0.965
# Bloque 3, Tiempo 0.970
# Bloque 3, Tiempo 0.975
# Bloque 3, Tiempo 0.980
# Bloque 3, Tiempo 0.985
# Bloque 3, Tiempo 0.990
# Bloque 3, Tiempo 0.995
# Bloque 3, Tiempo 1.000
# Bloque 3, Tiempo 1.005
# Bloque 3, Tiempo 1.010
# Bloque 3, Tiempo 1.015
# Bloque 3, Tiempo 1.020
# Bloque 3, Tiempo 1.025
# Bloque 3, Tiempo 1.030
# Bloque 3, Tiempo 1.035
# Bloque 3, Tiempo 1.040
# Bloque 3, Tiempo 1.045
# Bloque 3, Tiempo 1.050
# Bloque 3, Tiempo 1.055
# Bloque 3, Tiempo 1.060
# Bloque 3, Tiempo 1.065
# Bloque 3, Tiempo 1.070
# Bloque 3, Tiempo 1.075
# Bloque 3, Tiempo 1.080
# Bloque 3, Tiempo 1.085
# Bloque 3, Tiempo 1.090
# Bloque 3, Tiempo 1.095
# Bloque 3, Tiempo 1.100
# Bloque 3, Tiempo 1.105
# Bloque 3, Tiempo 1.110
# Bloque 3, Tiempo 1.115
# Bloque 3, Tiempo 1.120
# Bloque 3, Tiempo 1.125
# Bloque 3, Tiempo 1.130
# Bloque 3, Tiempo 1.135
# Bloque 3, Tiempo 1.140
# Bloque 3, Tiempo 1.145
# Bloque 3, Tiempo 1.150
# Bloque 3, Tiempo 1.155
# Bloque 3, Tiempo 1.160
# Bloque 3, Tiempo 1.165
# Bloque 3, Tiempo 1.170
# Bloque 3, Tiempo 1.175
# Bloque 3, Tiempo 1.180
# Bloque 3, Tiempo 1.185
# Bloque 3, Tiempo 1.190
# Bloque 3, Tiempo 1.195
# Bloque 3, Tiempo 1.200
# Bloque 3, Tiempo 1.205
# Bloque 3, Tiempo 1.210
# Bloque 3, Tiempo 1.215
# Bloque 3, Tiempo 1.220
# Bloque 3, Tiempo 1.225
# Bloque 3, Tiempo 1.230
# Bloque 3, Tiempo 1.235
# Bloque 3, Tiempo 1.240
# Bloque 3, Tiempo 1.245
# Bloque 3, Tiempo 1.250
# Bloque 3, Tiempo 1.255
# Bloque 3, Tiempo 1.260
# Bloque 3, Tiempo 1.265
# Bloque 3, Tiempo 1.270
# Bloque 3, Tiempo 1.275
# Bloque 3, Tiempo 1.280
# Bloque 3, Tiempo 1.285
# Bloque 3, Tiempo 1.290
# Bloque 3, Tiempo 1.295
# Bloque 3, Tiempo 1.300
# Bloque 3, Tiempo 1.305
# Bloque 3, Tiempo 1.310
# Bloque 3, Tiempo 1.315
# Bloque 3, Tiempo 1.320
# Bloque 3, Tiempo 1.325
# Bloque 3, Tiempo 1.330
# Bloque 3, Tiempo 1.335
# Bloque 3, Tiempo 1.340
# Bloque 3, Tiempo 1.345
# Bloque 3, Tiempo 1.350
# Bloque 3, Tiempo 1.355
# Bloque 3, Tiempo 1.360
# Bloque 3, Tiempo 1.365
# Bloque 3, Tiempo 1.370
# Bloque 3, Tiempo 1.375
# Bloque 3, Tiempo 1.380
# Bloque 3, Tiempo 1.385
# Bloque 3, Tiempo 1.390
# Bloque 3, Tiempo 1.395
# Bloque 3, Tiempo 1.400
# Bloque 3, Tiempo 1.405
# Bloque 3, Tiempo 1.410
# Bloque 3, Tiempo 1.415
# Bloque 3, Tiempo 1.420
# Bloque 3, Tiempo 1.425
# Bloque 3, Tiempo 1.430
# Bloque 3, Tiempo 1.435
# Bloque 3, Tiempo 1.440
# Bloque 3, Tiempo 1.445
# Bloque 3, Tiempo 1.450
# Bloque 3, Tiempo 1.455
# Bloque 3, Tiempo 1.460
# Bloque 3, Tiempo 1.465
# Bloque 3, Tiempo 1.470
# Bloque 3, Tiempo 1.475
# Bloque 3, Tiempo 1.480
# Bloque 3, Tiempo 1.485
# Bloque 3, Tiempo 1.490
# Bloque 3, Tiempo 1.495
# Bloque 3, Tiempo 1.500
# Bloque 3, Tiempo 1.505
# Bloque 3, Tiempo 1.510
# Bloque 3, Tiempo 1.515
# Bloque 3, Tiempo 1.520
# Bloque 3, Tiempo 1.525
# Bloque 3, Tiempo 1.530
# Bloque 3, Tiempo 1.535
# Bloque 3, Tiempo 1.540
# Bloque 3, Tiempo 1.545
# Bloque 3, Tiempo 1.550
# Bloque 3, Tiempo 1.555
# Bloque 3, Tiempo 1.560
# Bloque 3, Tiempo 1.565
# Bloque 3, Tiempo 1.570
# Bloque 3, Tiempo 1.575
# Bloque 3, Tiempo 1.580
# Bloque 3, Tiempo 1.585
# Bloque 3, Tiempo 1.590
# Bloque 3, Tiempo 1.595
# Bloque 3, Tiempo 1.600
# Bloque 3, Tiempo 1.605
# Bloque 3, Tiempo 1.610
# Bloque 3, Tiempo 1.615
# Bloque 3, Tiempo 1.620
# Bloque 3, Tiempo 1.625
# Bloque 3, Tiempo 1.630
# Bloque 3, Tiempo 1.635
# Bloque 3, Tiempo 1.640
# Bloque 3, Tiempo 1.645
# Bloque 3, Tiempo 1.650
# Bloque 3, Tiempo 1.655
# Bloque 3, Tiempo 1.660
# Bloque 3, Tiempo 1.665
# Bloque 3, Tiempo 1.670
# Bloque 3, Tiempo 1.675
# Bloque 3, Tiempo 1.680
# Bloque 3, Tiempo 1.685
# Bloque 3, Tiempo 1.690
# Bloque 3, Tiempo 1.695
# Bloque 3, Tiempo 1.700
# Bloque 3, Tiempo 1.705
# Bloque 3, Tiempo 1.710
# Bloque 3, Tiempo 1.715
# Bloque 3, Tiempo 1.720
# Bloque 3, Tiempo 1.725
# Bloque 3, Tiempo 1.730
# Bloque 3, Tiempo 1.735
# Bloque 3, Tiempo 1.740
# Bloque 3, Tiempo 1.745
# Bloque 3, Tiempo 1.750
# Bloque 3, Tiempo 1.755
# Bloque 3, Tiempo 1.760
# Bloque 3, Tiempo 1.765
# Bloque 3, Tiempo 1.770
# Bloque 3, Tiempo 1.775
# Bloque 3, Tiempo 1.780
# Bloque 3, Tiempo 1.785
# Bloque 3, Tiempo 1.790
# Bloque 3, Tiempo 1.795
# Bloque 3, Tiempo 1.800
# Bloque 3, Tiempo 1.805
# Bloque 3, Tiempo 1.810
# Bloque 3, Tiempo 1.815
# Bloque 3, Tiempo 1.820
# Bloque 3, Tiempo 1.825
# Bloque 3, Tiempo 1.830
# Bloque 3, Tiempo 1.835
# Bloque 3, Tiempo 1.840
# Bloque 3, Tiempo 1.845
# Bloque 3, Tiempo 1.850
# Bloque 3, Tiempo 1.855
# Bloque 3, Tiempo 1.860
# Bloque 3, Tiempo 1.865
# Bloque 3, Tiempo 1.870
# Bloque 3, Tiempo 1.875
# Bloque 3, Tiempo 1.880
# Bloque 3, Tiempo 1.885
# Bloque 3, Tiempo 1.890
# Bloque 3, Tiempo 1.895
# Bloque 3, Tiempo 1.900
# Bloque 3, Tiempo 1.905
# Bloque 3, Tiempo 1.910
# Bloque 3, Tiempo 1.915
# Bloque 3, Tiempo 1.920
# Bloque 3, Tiempo 1.925
# Bloque 3, Tiempo 1.930
# Bloque 3, Tiempo 1.935
# Bloque 3, Tiempo 1.940
# Bloque 3, Tiempo 1.945
# Bloque 3, Tiempo 1.950
# Bloque 3, Tiempo 1.955
# Bloque 3, Tiempo 1.960
# Bloque 3, Tiempo 1.965
# Bloque 3, Tiempo 1.970
# Bloque 3, Tiempo 1.975
# Bloque 3, Tiempo 1.980
# Bloque 3, Tiempo 1.985
# Bloque 3, Tiempo 1.990
# Bloque 3, Tiempo 1.995
# Bloque 3, Tiempo 2.000
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# Bloque 4, Tiempo 0.000
# Bloque 4, Tiempo 0.005
# Bloque 4, Tiempo 0.010
# Bloque 4, Tiempo 0.015
# Bloque 4, Tiempo 0.020
# Bloque 4, Tiempo 0.025
# Bloque 4, Tiempo 0.030
# Bloque 4, Tiempo 0.035
# Bloque 4, Tiempo 0.040
# Bloque 4, Tiempo 0.045
# Bloque 4, Tiempo 0.050
# Bloque 4, Tiempo 0.055
# Bloque 4, Tiempo 0.060
# Bloque 4, Tiempo 0.065
# Bloque 4, Tiempo 0.070
# Bloque 4, Tiempo 0.075
# Bloque 4, Tiempo 0.080
# Bloque 4, Tiempo 0.085
# Bloque 4, Tiempo 0.090
# Bloque 4, Tiempo 0.095
# Bloque 4, Tiempo 0.100
# Bloque 4, Tiempo 0.105
# Bloque 4, Tiempo 0.110
# Bloque 4, Tiempo 0.115
# Bloque 4, Tiempo 0.120
# Bloque 4, Tiempo 0.125
# Bloque 4, Tiempo 0.130
# Bloque 4, Tiempo 0.135
# Bloque 4, Tiempo 0.140
# Bloque 4, Tiempo 0.145
# Bloque 4, Tiempo 0.150
# Bloque 4, Tiempo 0.155
# Bloque 4, Tiempo 0.160
# Bloque 4, Tiempo 0.165
# Bloque 4, Tiempo 0.170
# Bloque 4, Tiempo 0.175
# Bloque 4, Tiempo 0.180
# Bloque 4, Tiempo 0.185
# Bloque 4, Tiempo 0.190
# Bloque 4, Tiempo 0.195
# Bloque 4, Tiempo 0.200
# Bloque 4, Tiempo 0.205
# Bloque 4, Tiempo 0.210
# Bloque 4, Tiempo 0.215
# Bloque 4, Tiempo 0.220
# Bloque 4, Tiempo 0.225
# Bloque 4, Tiempo 0.230
# Bloque 4, Tiempo 0.235
# Bloque 4, Tiempo 0.240
# Bloque 4, Tiempo 0.245
# Bloque 4, Tiempo 0.250
# Bloque 4, Tiempo 0.255
# Bloque 4, Tiempo 0.260
# Bloque 4, Tiempo 0.265
# Bloque 4, Tiempo 0.270
# Bloque 4, Tiempo 0.275
# Bloque 4, Tiempo 0.280
# Bloque 4, Tiempo 0.285
# Bloque 4, Tiempo 0.290
# Bloque 4, Tiempo 0.295
# Bloque 4, Tiempo 0.300
# Bloque 4, Tiempo 0.305
# Bloque 4, Tiempo 0.310
# Bloque 4, Tiempo 0.315
# Bloque 4, Tiempo 0.320
# Bloque 4, Tiempo 0.325
# Bloque 4, Tiempo 0.330
# Bloque 4, Tiempo 0.335
# Bloque 4, Tiempo 0.340
# Bloque 4, Tiempo 0.345
# Bloque 4, Tiempo 0.350
# Bloque 4, Tiempo 0.355
# Bloque 4, Tiempo 0.360
# Bloque 4, Tiempo 0.365
# Bloque 4, Tiempo 0.370
# Bloque 4, Tiempo 0.375
# Bloque 4, Tiempo 0.380
# Bloque 4, Tiempo 0.385
# Bloque 4, Tiempo 0.390
# Bloque 4, Tiempo 0.395
# Bloque 4, Tiempo 0.400
# Bloque 4, Tiempo 0.405
# Bloque 4, Tiempo 0.410
# Bloque 4, Tiempo 0.415
# Bloque 4, Tiempo 0.420
# Bloque 4, Tiempo 0.425
# Bloque 4, Tiempo 0.430
# Bloque 4, Tiempo 0.435
# Bloque 4, Tiempo 0.440
# Bloque 4, Tiempo 0.445
# Bloque 4, Tiempo 0.450
# Bloque 4, Tiempo 0.455
# Bloque 4, Tiempo 0.460
# Bloque 4, Tiempo 0.465
# Bloque 4, Tiempo 0.470
# Bloque 4, Tiempo 0.475
# Bloque 4, Tiempo 0.480
# Bloque 4, Tiempo 0.485
# Bloque 4, Tiempo 0.490
# Bloque 4, Tiempo 0.495
# Bloque 4, Tiempo 0.500
# Bloque 4, Tiempo 0.505
# Bloque 4, Tiempo 0.510
# Bloque 4, Tiempo 0.515
# Bloque 4, Tiempo 0.520
# Bloque 4, Tiempo 0.525
# Bloque 4, Tiempo 0.530
# Bloque 4, Tiempo 0.535
# Bloque 4, Tiempo 0.540
# Bloque 4, Tiempo 0.545
# Bloque 4, Tiempo 0.550
# Bloque 4, Tiempo 0.555
# Bloque 4, Tiempo 0.560
# Bloque 4, Tiempo 0.565
# Bloque 4, Tiempo 0.570
# Bloque 4, Tiempo 0.575
# Bloque 4, Tiempo 0.580
# Bloque 4, Tiempo 0.585
# Bloque 4, Tiempo 0.590
# Bloque 4, Tiempo 0.595
# Bloque 4, Tiempo 0.600
# Bloque 4, Tiempo 0.605
# Bloque 4, Tiempo 0.610
# Bloque 4, Tiempo 0.615
# Bloque 4, Tiempo 0.620
# Bloque 4, Tiempo 0.625
# Bloque 4, Tiempo 0.630
# Bloque 4, Tiempo 0.635
# Bloque 4, Tiempo 0.640
# Bloque 4, Tiempo 0.645
# Bloque 4, Tiempo 0.650
# Bloque 4, Tiempo 0.655
# Bloque 4, Tiempo 0.660
# Bloque 4, Tiempo 0.665
# Bloque 4, Tiempo 0.670
# Bloque 4, Tiempo 0.675
# Bloque 4, Tiempo 0.680
# Bloque 4, Tiempo 0.685
# Bloque 4, Tiempo 0.690
# Bloque 4, Tiempo 0.695
# Bloque 4, Tiempo 0.700
# Bloque 4, Tiempo 0.705
# Bloque 4, Tiempo 0.710
# Bloque 4, Tiempo 0.715
# Bloque 4, Tiempo 0.720
# Bloque 4, Tiempo 0.725
# Bloque 4, Tiempo 0.730
# Bloque 4, Tiempo 0.735
# Bloque 4, Tiempo 0.740
# Bloque 4, Tiempo 0.745
# Bloque 4, Tiempo 0.750
# Bloque 4, Tiempo 0.755
# Bloque 4, Tiempo 0.760
# Bloque 4, Tiempo 0.765
# Bloque 4, Tiempo 0.770
# Bloque 4, Tiempo 0.775
# Bloque 4, Tiempo 0.780
# Bloque 4, Tiempo 0.785
# Bloque 4, Tiempo 0.790
# Bloque 4, Tiempo 0.795
# Bloque 4, Tiempo 0.800
# Bloque 4, Tiempo 0.805
# Bloque 4, Tiempo 0.810
# Bloque 4, Tiempo 0.815
# Bloque 4, Tiempo 0.820
# Bloque 4, Tiempo 0.825
# Bloque 4, Tiempo 0.830
# Bloque 4, Tiempo 0.835
# Bloque 4, Tiempo 0.840
# Bloque 4, Tiempo 0.845
# Bloque 4, Tiempo 0.850
# Bloque 4, Tiempo 0.855
# Bloque 4, Tiempo 0.860
# Bloque 4, Tiempo 0.865
# Bloque 4, Tiempo 0.870
# Bloque 4, Tiempo 0.875
# Bloque 4, Tiempo 0.880
# Bloque 4, Tiempo 0.885
# Bloque 4, Tiempo 0.890
# Bloque 4, Tiempo 0.895
# Bloque 4, Tiempo 0.900
# Bloque 4, Tiempo 0.905
# Bloque 4, Tiempo 0.910
# Bloque 4, Tiempo 0.915
# Bloque 4, Tiempo 0.920
# Bloque 4, Tiempo 0.925
# Bloque 4, Tiempo 0.930
# Bloque 4, Tiempo 0.935
# Bloque 4, Tiempo 0.940
# Bloque 4, Tiempo 0.945
# Bloque 4, Tiempo 0.950
# Bloque 4, Tiempo 0.955
# Bloque 4, Tiempo 0.960
# Bloque 4, Tiempo 0.965
# Bloque 4, Tiempo 0.970
# Bloque 4, Tiempo 0.975
# Bloque 4, Tiempo 0.980
# Bloque 4, Tiempo 0.985
# Bloque 4, Tiempo 0.990
# Bloque 4, Tiempo 0.995
# Bloque 4, Tiempo 1.000
# Bloque 4, Tiempo 1.005
# Bloque 4, Tiempo 1.010
# Bloque 4, Tiempo 1.015
# Bloque 4, Tiempo 1.020
# Bloque 4, Tiempo 1.025
# Bloque 4, Tiempo 1.030
# Bloque 4, Tiempo 1.035
# Bloque 4, Tiempo 1.040
# Bloque 4, Tiempo 1.045
# Bloque 4, Tiempo 1.050
# Bloque 4, Tiempo 1.055
# Bloque 4, Tiempo 1.060
# Bloque 4, Tiempo 1.065
# Bloque 4, Tiempo 1.070
# Bloque 4, Tiempo 1.075
# Bloque 4, Tiempo 1.080
# Bloque 4, Tiempo 1.085
# Bloque 4, Tiempo 1.090
# Bloque 4, Tiempo 1.095
# Bloque 4, Tiempo 1.100
# Bloque 4, Tiempo 1.105
# Bloque 4, Tiempo 1.110
# Bloque 4, Tiempo 1.115
# Bloque 4, Tiempo 1.120
# Bloque 4, Tiempo 1.125
# Bloque 4, Tiempo 1.130
# Bloque 4, Tiempo 1.135
# Bloque 4, Tiempo 1.140
# Bloque 4, Tiempo 1.145
# Bloque 4, Tiempo 1.150
# Bloque 4, Tiempo 1.155
# Bloque 4, Tiempo 1.160
# Bloque 4, Tiempo 1.165
# Bloque 4, Tiempo 1.170
# Bloque 4, Tiempo 1.175
# Bloque 4, Tiempo 1.180
# Bloque 4, Tiempo 1.185
# Bloque 4, Tiempo 1.190
# Bloque 4, Tiempo 1.195
# Bloque 4, Tiempo 1.200
# Bloque 4, Tiempo 1.205
# Bloque 4, Tiempo 1.210
# Bloque 4, Tiempo 1.215
# Bloque 4, Tiempo 1.220
# Bloque 4, Tiempo 1.225
# Bloque 4, Tiempo 1.230
# Bloque 4, Tiempo 1.235
# Bloque 4, Tiempo 1.240
# Bloque 4, Tiempo 1.245
# Bloque 4, Tiempo 1.250
# Bloque 4, Tiempo 1.255
# Bloque 4, Tiempo 1.260
# Bloque 4, Tiempo 1.265
# Bloque 4, Tiempo 1.270
# Bloque 4, Tiempo 1.275
# Bloque 4, Tiempo 1.280
# Bloque 4, Tiempo 1.285
# Bloque 4, Tiempo 1.290
# Bloque 4, Tiempo 1.295
# Bloque 4, Tiempo 1.300
# Bloque 4, Tiempo 1.305
# Bloque 4, Tiempo 1.310
# Bloque 4, Tiempo 1.315
# Bloque 4, Tiempo 1.320
# Bloque 4, Tiempo 1.325
# Bloque 4, Tiempo 1.330
# Bloque 4, Tiempo 1.335
# Bloque 4, Tiempo 1.340
# Bloque 4, Tiempo 1.345
# Bloque 4, Tiempo 1.350
# Bloque 4, Tiempo 1.355
# Bloque 4, Tiempo 1.360
# Bloque 4, Tiempo 1.365
# Bloque 4, Tiempo 1.370
# Bloque 4, Tiempo 1.375
# Bloque 4, Tiempo 1.380
# Bloque 4, Tiempo 1.385
# Bloque 4, Tiempo 1.390
# Bloque 4, Tiempo 1.395
# Bloque 4, Tiempo 1.400
# Bloque 4, Tiempo 1.405
# Bloque 4, Tiempo 1.410
# Bloque 4, Tiempo 1.415
# Bloque 4, Tiempo 1.420
# Bloque 4, Tiempo 1.425
# Bloque 4, Tiempo 1.430
# Bloque 4, Tiempo 1.435
# Bloque 4, Tiempo 1.440
# Bloque 4, Tiempo 1.445
# Bloque 4, Tiempo 1.450
# Bloque 4, Tiempo 1.455
# Bloque 4, Tiempo 1.460
# Bloque 4, Tiempo 1.465
# Bloque 4, Tiempo 1.470
# Bloque 4, Tiempo 1.475
# Bloque 4, Tiempo 1.480
# Bloque 4, Tiempo 1.485
# Bloque 4, Tiempo 1.490
# Bloque 4, Tiempo 1.495
# Bloque 4, Tiempo 1.500
# Bloque 4, Tiempo 1.505
# Bloque 4, Tiempo 1.510
# Bloque 4, Tiempo 1.515
# Bloque 4, Tiempo 1.520
# Bloque 4, Tiempo 1.525
# Bloque 4, Tiempo 1.530
# Bloque 4, Tiempo 1.535
# Bloque 4, Tiempo 1.540
# Bloque 4, Tiempo 1.545
# Bloque 4, Tiempo 1.550
# Bloque 4, Tiempo 1.555
# Bloque 4, Tiempo 1.560
# Bloque 4, Tiempo 1.565
# Bloque 4, Tiempo 1.570
# Bloque 4, Tiempo 1.575
# Bloque 4, Tiempo 1.580
# Bloque 4, Tiempo 1.585
# Bloque 4, Tiempo 1.590
# Bloque 4, Tiempo 1.595
# Bloque 4, Tiempo 1.600
# Bloque 4, Tiempo 1.605
# Bloque 4, Tiempo 1.610
# Bloque 4, Tiempo 1.615
# Bloque 4, Tiempo 1.620
# Bloque 4, Tiempo 1.625
# Bloque 4, Tiempo 1.630
# Bloque 4, Tiempo 1.635
# Bloque 4, Tiempo 1.640
# Bloque 4, Tiempo 1.645
# Bloque 4, Tiempo 1.650
# Bloque 4, Tiempo 1.655
# Bloque 4, Tiempo 1.660
# Bloque 4, Tiempo 1.665
# Bloque 4, Tiempo 1.670
# Bloque 4, Tiempo 1.675
# Bloque 4, Tiempo 1.680
# Bloque 4, Tiempo 1.685
# Bloque 4, Tiempo 1.690
# Bloque 4, Tiempo 1.695
# Bloque 4, Tiempo 1.700
# Bloque 4, Tiempo 1.705
# Bloque 4, Tiempo 1.710
# Bloque 4, Tiempo 1.715
# Bloque 4, Tiempo 1.720
# Bloque 4, Tiempo 1.725
# Bloque 4, Tiempo 1.730
# Bloque 4, Tiempo 1.735
# Bloque 4, Tiempo 1.740
# Bloque 4, Tiempo 1.745
# Bloque 4, Tiempo 1.750
# Bloque 4, Tiempo 1.755
# Bloque 4, Tiempo 1.760
# Bloque 4, Tiempo 1.765
# Bloque 4, Tiempo 1.770
# Bloque 4, Tiempo 1.775
# Bloque 4, Tiempo 1.780
# Bloque 4, Tiempo 1.785
# Bloque 4, Tiempo 1.790
# Bloque 4, Tiempo 1.795
# Bloque 4, Tiempo 1.800
# Bloque 4, Tiempo 1.805
# Bloque 4, Tiempo 1.810
# Bloque 4, Tiempo 1.815
# Bloque 4, Tiempo 1.820
# Bloque 4, Tiempo 1.825
# Bloque 4, Tiempo 1.830
# Bloque 4, Tiempo 1.835
# Bloque 4, Tiempo 1.840
# Bloque 4, Tiempo 1.845
# Bloque 4, Tiempo 1.850
# Bloque 4, Tiempo 1.855
# Bloque 4, Tiempo 1.860
# Bloque 4, Tiempo 1.865
# Bloque 4, Tiempo 1.870
# Bloque 4, Tiempo 1.875
# Bloque 4, Tiempo 1.880
# Bloque 4, Tiempo 1.885
# Bloque 4, Tiempo 1.890
# Bloque 4, Tiempo 1.895
# Bloque 4, Tiempo 1.900
# Bloque 4, Tiempo 1.905
# Bloque 4, Tiempo 1.910
# Bloque 4, Tiempo 1.915
# Bloque 4, Tiempo 1.920
# Bloque 4, Tiempo 1.925
# Bloque 4, Tiempo 1.930
# Bloque 4, Tiempo 1.935
# Bloque 4, Tiempo 1.940
# Bloque 4, Tiempo 1.945
# Bloque 4, Tiempo 1.950
# Bloque 4, Tiempo 1.955
# Bloque 4, Tiempo 1.960
# Bloque 4, Tiempo 1.965
# Bloque 4, Tiempo 1.970
# Bloque 4, Tiempo 1.975
# Bloque 4, Tiempo 1.980
# Bloque 4, Tiempo 1.985
# Bloque 4, Tiempo 1.990
# Bloque 4, Tiempo 1.995
# Bloque 4, Tiempo 2.000
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# Bloque 5, Tiempo 0.000
# Bloque 5, Tiempo 0.005
# Bloque 5, Tiempo 0.010
# Bloque 5, Tiempo 0.015
# Bloque 5, Tiempo 0.020
# Bloque 5, Tiempo 0.025
# Bloque 5, Tiempo 0.030
# Bloque 5, Tiempo 0.035
# Bloque 5, Tiempo 0.040
# Bloque 5, Tiempo 0.045
# Bloque 5, Tiempo 0.050
# Bloque 5, Tiempo 0.055
# Bloque 5, Tiempo 0.060
# Bloque 5, Tiempo 0.065
# Bloque 5, Tiempo 0.070
# Bloque 5, Tiempo 0.075
# Bloque 5, Tiempo 0.080
# Bloque 5, Tiempo 0.085
# Bloque 5, Tiempo 0.090
# Bloque 5, Tiempo 0.095
# Bloque 5, Tiempo 0.100
# Bloque 5, Tiempo 0.105
# Bloque 5, Tiempo 0.110
# Bloque 5, Tiempo 0.115
# Bloque 5, Tiempo 0.120
# Bloque 5, Tiempo 0.125
# Bloque 5, Tiempo 0.130
# Bloque 5, Tiempo 0.135
# Bloque 5, Tiempo 0.140
# Bloque 5, Tiempo 0.145
# Bloque 5, Tiempo 0.150
# Bloque 5, Tiempo 0.155
# Bloque 5, Tiempo 0.160
# Bloque 5, Tiempo 0.165
# Bloque 5, Tiempo 0.170
# Bloque 5, Tiempo 0.175
# Bloque 5, Tiempo 0.180
# Bloque 5, Tiempo 0.185
# Bloque 5, Tiempo 0.190
# Bloque 5, Tiempo 0.195
# Bloque 5, Tiempo 0.200
# Bloque 5, Tiempo 0.205
# Bloque 5, Tiempo 0.210
# Bloque 5, Tiempo 0.215
# Bloque 5, Tiempo 0.220
# Bloque 5, Tiempo 0.225
# Bloque 5, Tiempo 0.230
# Bloque 5, Tiempo 0.235
# Bloque 5, Tiempo 0.240
# Bloque 5, Tiempo 0.245
# Bloque 5, Tiempo 0.250
# Bloque 5, Tiempo 0.255
# Bloque 5, Tiempo 0.260
# Bloque 5, Tiempo 0.265
# Bloque 5, Tiempo 0.270
# Bloque 5, Tiempo 0.275
# Bloque 5, Tiempo 0.280
# Bloque 5, Tiempo 0.285
# Bloque 5, Tiempo 0.290
# Bloque 5, Tiempo 0.295
# Bloque 5, Tiempo 0.300
# Bloque 5, Tiempo 0.305
# Bloque 5, Tiempo 0.310
# Bloque 5, Tiempo 0.315
# Bloque 5, Tiempo 0.320
# Bloque 5, Tiempo 0.325
# Bloque 5, Tiempo 0.330
# Bloque 5, Tiempo 0.335
# Bloque 5, Tiempo 0.340
# Bloque 5, Tiempo 0.345
# Bloque 5, Tiempo 0.350
# Bloque 5, Tiempo 0.355
# Bloque 5, Tiempo 0.360
# Bloque 5, Tiempo 0.365
# Bloque 5, Tiempo 0.370
# Bloque 5, Tiempo 0.375
# Bloque 5, Tiempo 0.380
# Bloque 5, Tiempo 0.385
# Bloque 5, Tiempo 0.390
# Bloque 5, Tiempo 0.395
# Bloque 5, Tiempo 0.400
# Bloque 5, Tiempo 0.405
# Bloque 5, Tiempo 0.410
# Bloque 5, Tiempo 0.415
# Bloque 5, Tiempo 0.420
# Bloque 5, Tiempo 0.425
# Bloque 5, Tiempo 0.430
# Bloque 5, Tiempo 0.435
# Bloque 5, Tiempo 0.440
# Bloque 5, Tiempo 0.445
# Bloque 5, Tiempo 0.450
# Bloque 5, Tiempo 0.455
# Bloque 5, Tiempo 0.460
# Bloque 5, Tiempo 0.465
# Bloque 5, Tiempo 0.470
# Bloque 5, Tiempo 0.475
# Bloque 5, Tiempo 0.480
# Bloque 5, Tiempo 0.485
# Bloque 5, Tiempo 0.490
# Bloque 5, Tiempo 0.495
# Bloque 5, Tiempo 0.500
# Bloque 5, Tiempo 0.505
# Bloque 5, Tiempo 0.510
# Bloque 5, Tiempo 0.515
# Bloque 5, Tiempo 0.520
# Bloque 5, Tiempo 0.525
# Bloque 5, Tiempo 0.530
# Bloque 5, Tiempo 0.535
# Bloque 5, Tiempo 0.540
# Bloque 5, Tiempo 0.545
# Bloque 5, Tiempo 0.550
# Bloque 5, Tiempo 0.555
# Bloque 5, Tiempo 0.560
# Bloque 5, Tiempo 0.565
# Bloque 5, Tiempo 0.570
# Bloque 5, Tiempo 0.575
# Bloque 5, Tiempo 0.580
# Bloque 5, Tiempo 0.585
# Bloque 5, Tiempo 0.590
# Bloque 5, Tiempo 0.595
# Bloque 5, Tiempo 0.600
# Bloque 5, Tiempo 0.605
# Bloque 5, Tiempo 0.610
# Bloque 5, Tiempo 0.615
# Bloque 5, Tiempo 0.620
# Bloque 5, Tiempo 0.625
# Bloque 5, Tiempo 0.630
# Bloque 5, Tiempo 0.635
# Bloque 5, Tiempo 0.640
# Bloque 5, Tiempo 0.645
# Bloque 5, Tiempo 0.650
# Bloque 5, Tiempo 0.655
# Bloque 5, Tiempo 0.660
# Bloque 5, Tiempo 0.665
# Bloque 5, Tiempo 0.670
# Bloque 5, Tiempo 0.675
# Bloque 5, Tiempo 0.680
# Bloque 5, Tiempo 0.685
# Bloque 5, Tiempo 0.690
# Bloque 5, Tiempo 0.695
# Bloque 5, Tiempo 0.700
# Bloque 5, Tiempo 0.705
# Bloque 5, Tiempo 0.710
# Bloque 5, Tiempo 0.715
# Bloque 5, Tiempo 0.720
# Bloque 5, Tiempo 0.725
# Bloque 5, Tiempo 0.730
# Bloque 5, Tiempo 0.735
# Bloque 5, Tiempo 0.740
# Bloque 5, Tiempo 0.745
# Bloque 5, Tiempo 0.750
# Bloque 5, Tiempo 0.755
# Bloque 5, Tiempo 0.760
# Bloque 5, Tiempo 0.765
# Bloque 5, Tiempo 0.770
# Bloque 5, Tiempo 0.775
# Bloque 5, Tiempo 0.780
# Bloque 5, Tiempo 0.785
# Bloque 5, Tiempo 0.790
# Bloque 5, Tiempo 0.795
# Bloque 5, Tiempo 0.800
# Bloque 5, Tiempo 0.805
# Bloque 5, Tiempo 0.810
# Bloque 5, Tiempo 0.815
# Bloque 5, Tiempo 0.820
# Bloque 5, Tiempo 0.825
# Bloque 5, Tiempo 0.830
# Bloque 5, Tiempo 0.835
# Bloque 5, Tiempo 0.840
# Bloque 5, Tiempo 0.845
# Bloque 5, Tiempo 0.850
# Bloque 5, Tiempo 0.855
# Bloque 5, Tiempo 0.860
# Bloque 5, Tiempo 0.865
# Bloque 5, Tiempo 0.870
# Bloque 5, Tiempo 0.875
# Bloque 5, Tiempo 0.880
# Bloque 5, Tiempo 0.885
# Bloque 5, Tiempo 0.890
# Bloque 5, Tiempo 0.895
# Bloque 5, Tiempo 0.900
# Bloque 5, Tiempo 0.905
# Bloque 5, Tiempo 0.910
# Bloque 5, Tiempo 0.915
# Bloque 5, Tiempo 0.920
# Bloque 5, Tiempo 0.925
# Bloque 5, Tiempo 0.930
# Bloque 5, Tiempo 0.935
# Bloque 5, Tiempo 0.940
# Bloque 5, Tiempo 0.945
# Bloque 5, Tiempo 0.950
# Bloque 5, Tiempo 0.955
# Bloque 5, Tiempo 0.960
# Bloque 5, Tiempo 0.965
# Bloque 5, Tiempo 0.970
# Bloque 5, Tiempo 0.975
# Bloque 5, Tiempo 0.980
# Bloque 5, Tiempo 0.985
# Bloque 5, Tiempo 0.990
# Bloque 5, Tiempo 0.995
# Bloque 5, Tiempo 1.000
# Bloque 5, Tiempo 1.005
# Bloque 5, Tiempo 1.010
# Bloque 5, Tiempo 1.015
# Bloque 5, Tiempo 1.020
# Bloque 5, Tiempo 1.025
# Bloque 5, Tiempo 1.030
# Bloque 5, Tiempo 1.035
# Bloque 5, Tiempo 1.040
# Bloque 5, Tiempo 1.045
# Bloque 5, Tiempo 1.050
# Bloque 5, Tiempo 1.055
# Bloque 5, Tiempo 1.060
# Bloque 5, Tiempo 1.065
# Bloque 5, Tiempo 1.070
# Bloque 5, Tiempo 1.075
# Bloque 5, Tiempo 1.080
# Bloque 5, Tiempo 1.085
# Bloque 5, Tiempo 1.090
# Bloque 5, Tiempo 1.095
# Bloque 5, Tiempo 1.100
# Bloque 5, Tiempo 1.105
# Bloque 5, Tiempo 1.110
# Bloque 5, Tiempo 1.115
# Bloque 5, Tiempo 1.120
# Bloque 5, Tiempo 1.125
# Bloque 5, Tiempo 1.130
# Bloque 5, Tiempo 1.135
# Bloque 5, Tiempo 1.140
# Bloque 5, Tiempo 1.145
# Bloque 5, Tiempo 1.150
# Bloque 5, Tiempo 1.155
# Bloque 5, Tiempo 1.160
# Bloque 5, Tiempo 1.165
# Bloque 5, Tiempo 1.170
# Bloque 5, Tiempo 1.175
# Bloque 5, Tiempo 1.180
# Bloque 5, Tiempo 1.185
# Bloque 5, Tiempo 1.190
# Bloque 5, Tiempo 1.195
# Bloque 5, Tiempo 1.200
# Bloque 5, Tiempo 1.205
# Bloque 5, Tiempo 1.210
# Bloque 5, Tiempo 1.215
# Bloque 5, Tiempo 1.220
# Bloque 5, Tiempo 1.225
# Bloque 5, Tiempo 1.230
# Bloque 5, Tiempo 1.235
# Bloque 5, Tiempo 1.240
# Bloque 5, Tiempo 1.245
# Bloque 5, Tiempo 1.250
# Bloque 5, Tiempo 1.255
# Bloque 5, Tiempo 1.260
# Bloque 5, Tiempo 1.265
# Bloque 5, Tiempo 1.270
# Bloque 5, Tiempo 1.275
# Bloque 5, Tiempo 1.280
# Bloque 5, Tiempo 1.285
# Bloque 5, Tiempo 1.290
# Bloque 5, Tiempo 1.295
# Bloque 5, Tiempo 1.300
# Bloque 5, Tiempo 1.305
# Bloque 5, Tiempo 1.310
# Bloque 5, Tiempo 1.315
# Bloque 5, Tiempo 1.320
# Bloque 5, Tiempo 1.325
# Bloque 5, Tiempo 1.330
# Bloque 5, Tiempo 1.335
# Bloque 5, Tiempo 1.340
# Bloque 5, Tiempo 1.345
# Bloque 5, Tiempo 1.350
# Bloque 5, Tiempo 1.355
# Bloque 5, Tiempo 1.360
# Bloque 5, Tiempo 1.365
# Bloque 5, Tiempo 1.370
# Bloque 5, Tiempo 1.375
# Bloque 5, Tiempo 1.380
# Bloque 5, Tiempo 1.385
# Bloque 5, Tiempo 1.390
# Bloque 5, Tiempo 1.395
# Bloque 5, Tiempo 1.400
# Bloque 5, Tiempo 1.405
# Bloque 5, Tiempo 1.410
# Bloque 5, Tiempo 1.415
# Bloque 5, Tiempo 1.420
# Bloque 5, Tiempo 1.425
# Bloque 5, Tiempo 1.430
# Bloque 5, Tiempo 1.435
# Bloque 5, Tiempo 1.440
# Bloque 5, Tiempo 1.445
# Bloque 5, Tiempo 1.450
# Bloque 5, Tiempo 1.455
# Bloque 5, Tiempo 1.460
# Bloque 5, Tiempo 1.465
# Bloque 5, Tiempo 1.470
# Bloque 5, Tiempo 1.475
# Bloque 5, Tiempo 1.480
# Bloque 5, Tiempo 1.485
# Bloque 5, Tiempo 1.490
# Bloque 5, Tiempo 1.495
# Bloque 5, Tiempo 1.500
# Bloque 5, Tiempo 1.505
# Bloque 5, Tiempo 1.510
# Bloque 5, Tiempo 1.515
# Bloque 5, Tiempo 1.520
# Bloque 5, Tiempo 1.525
# Bloque 5, Tiempo 1.530
# Bloque 5, Tiempo 1.535
# Bloque 5, Tiempo 1.540
# Bloque 5, Tiempo 1.545
# Bloque 5, Tiempo 1.550
# Bloque 5, Tiempo 1.555
# Bloque 5, Tiempo 1.560
# Bloque 5, Tiempo 1.565
# Bloque 5, Tiempo 1.570
# Bloque 5, Tiempo 1.575
# Bloque 5, Tiempo 1.580
# Bloque 5, Tiempo 1.585
# Bloque 5, Tiempo 1.590
# Bloque 5, Tiempo 1.595
# Bloque 5, Tiempo 1.600
# Bloque 5, Tiempo 1.605
# Bloque 5, Tiempo 1.610
# Bloque 5, Tiempo 1.615
# Bloque 5, Tiempo 1.620
# Bloque 5, Tiempo 1.625
# Bloque 5, Tiempo 1.630
# Bloque 5, Tiempo 1.635
# Bloque 5, Tiempo 1.640
# Bloque 5, Tiempo 1.645
# Bloque 5, Tiempo 1.650
# Bloque 5, Tiempo 1.655
# Bloque 5, Tiempo 1.660
# Bloque 5, Tiempo 1.665
# Bloque 5, Tiempo 1.670
# Bloque 5, Tiempo 1.675
# Bloque 5, Tiempo 1.680
# Bloque 5, Tiempo 1.685
# Bloque 5, Tiempo 1.690
# Bloque 5, Tiempo 1.695
# Bloque 5, Tiempo 1.700
# Bloque 5, Tiempo 1.705
# Bloque 5, Tiempo 1.710
# Bloque 5, Tiempo 1.715
# Bloque 5, Tiempo 1.720
# Bloque 5, Tiempo 1.725
# Bloque 5, Tiempo 1.730
# Bloque 5, Tiempo 1.735
# Bloque 5, Tiempo 1.740
# Bloque 5, Tiempo 1.745
# Bloque 5, Tiempo 1.750
# Bloque 5, Tiempo 1.755
# Bloque 5, Tiempo 1.760
# Bloque 5, Tiempo 1.765
# Bloque 5, Tiempo 1.770
# Bloque 5, Tiempo 1.775
# Bloque 5, Tiempo 1.780
# Bloque 5, Tiempo 1.785
# Bloque 5, Tiempo 1.790
# Bloque 5, Tiempo 1.795
# Bloque 5, Tiempo 1.800
# Bloque 5, Tiempo 1.805
# Bloque 5, Tiempo 1.810
# Bloque 5, Tiempo 1.815
# Bloque 5, Tiempo 1.820
# Bloque 5, Tiempo 1.825
# Bloque 5, Tiempo 1.830
# Bloque 5, Tiempo 1.835
# Bloque 5, Tiempo 1.840
# Bloque 5, Tiempo 1.845
# Bloque 5, Tiempo 1.850
# Bloque 5, Tiempo 1.855
# Bloque 5, Tiempo 1.860
# Bloque 5, Tiempo 1.865
# Bloque 5, Tiempo 1.870
# Bloque 5, Tiempo 1.875
# Bloque 5, Tiempo 1.880
# Bloque 5, Tiempo 1.885
# Bloque 5, Tiempo 1.890
# Bloque 5, Tiempo 1.895
# Bloque 5, Tiempo 1.900
# Bloque 5, Tiempo 1.905
# Bloque 5, Tiempo 1.910
# Bloque 5, Tiempo 1.915
# Bloque 5, Tiempo 1.920
# Bloque 5, Tiempo 1.925
# Bloque 5, Tiempo 1.930
# Bloque 5, Tiempo 1.935
# Bloque 5, Tiempo 1.940
# Bloque 5, Tiempo 1.945
# Bloque 5, Tiempo 1.950
# Bloque 5, Tiempo 1.955
# Bloque 5, Tiempo 1.960
# Bloque 5, Tiempo 1.965
# Bloque 5, Tiempo 1.970
# Bloque 5, Tiempo 1.975
# Bloque 5, Tiempo 1.980
# Bloque 5, Tiempo 1.985
# Bloque 5, Tiempo 1.990
# Bloque 5, Tiempo 1.995
# Bloque 5, Tiempo 2.000
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# Bloque 6, Tiempo 0.000
# Bloque 6, Tiempo 0.005
# ...
# Bloque 9, Tiempo 0.685
# Bloque 9, Tiempo 0.690
# Bloque 9, Tiempo 0.695
# Bloque 9, Tiempo 0.700
# Bloque 9, Tiempo 0.705
# Bloque 9, Tiempo 0.710
# Bloque 9, Tiempo 0.715
# Bloque 9, Tiempo 0.720
# Bloque 9, Tiempo 0.725
# Bloque 9, Tiempo 0.730
# Bloque 9, Tiempo 0.735
# Bloque 9, Tiempo 0.740
# Bloque 9, Tiempo 0.745
# Bloque 9, Tiempo 0.750
# Bloque 9, Tiempo 0.755
# Bloque 9, Tiempo 0.760
# Bloque 9, Tiempo 0.765
# Bloque 9, Tiempo 0.770
# Bloque 9, Tiempo 0.775
# Bloque 9, Tiempo 0.780
# Bloque 9, Tiempo 0.785
# Bloque 9, Tiempo 0.790
# Bloque 9, Tiempo 0.795
# Bloque 9, Tiempo 0.800
# Bloque 9, Tiempo 0.805
# Bloque 9, Tiempo 0.810
# Bloque 9, Tiempo 0.815
# Bloque 9, Tiempo 0.820
# Bloque 9, Tiempo 0.825
# Bloque 9, Tiempo 0.830
# Bloque 9, Tiempo 0.835
# Bloque 9, Tiempo 0.840
# Bloque 9, Tiempo 0.845
# Bloque 9, Tiempo 0.850
# Bloque 9, Tiempo 0.855
# Bloque 9, Tiempo 0.860
# Bloque 9, Tiempo 0.865
# Bloque 9, Tiempo 0.870
# Bloque 9, Tiempo 0.875
# Bloque 9, Tiempo 0.880
# Bloque 9, Tiempo 0.885
# Bloque 9, Tiempo 0.890
# Bloque 9, Tiempo 0.895
# Bloque 9, Tiempo 0.900
# Bloque 9, Tiempo 0.905
# Bloque 9, Tiempo 0.910
# Bloque 9, Tiempo 0.915
# Bloque 9, Tiempo 0.920
# Bloque 9, Tiempo 0.925
# Bloque 9, Tiempo 0.930
# Bloque 9, Tiempo 0.935
# Bloque 9, Tiempo 0.940
# Bloque 9, Tiempo 0.945
# Bloque 9, Tiempo 0.950
# Bloque 9, Tiempo 0.955
# Bloque 9, Tiempo 0.960
# Bloque 9, Tiempo 0.965
# Bloque 9, Tiempo 0.970
# Bloque 9, Tiempo 0.975
# Bloque 9, Tiempo 0.980
# Bloque 9, Tiempo 0.985
# Bloque 9, Tiempo 0.990
# Bloque 9, Tiempo 0.995
# Bloque 9, Tiempo 1.000
# Bloque 9, Tiempo 1.005
# Bloque 9, Tiempo 1.010
# Bloque 9, Tiempo 1.015
# Bloque 9, Tiempo 1.020
# Bloque 9, Tiempo 1.025
# Bloque 9, Tiempo 1.030
# Bloque 9, Tiempo 1.035
# Bloque 9, Tiempo 1.040
# Bloque 9, Tiempo 1.045
# Bloque 9, Tiempo 1.050
# Bloque 9, Tiempo 1.055
# Bloque 9, Tiempo 1.060
# Bloque 9, Tiempo 1.065
# Bloque 9, Tiempo 1.070
# Bloque 9, Tiempo 1.075
# Bloque 9, Tiempo 1.080
# Bloque 9, Tiempo 1.085
# Bloque 9, Tiempo 1.090
# Bloque 9, Tiempo 1.095
# Bloque 9, Tiempo 1.100
# Bloque 9, Tiempo 1.105
# Bloque 9, Tiempo 1.110
# Bloque 9, Tiempo 1.115
# Bloque 9, Tiempo 1.120
# Bloque 9, Tiempo 1.125
# Bloque 9, Tiempo 1.130
# Bloque 9, Tiempo 1.135
# Bloque 9, Tiempo 1.140
# Bloque 9, Tiempo 1.145
# Bloque 9, Tiempo 1.150
# Bloque 9, Tiempo 1.155
# Bloque 9, Tiempo 1.160
# Bloque 9, Tiempo 1.165
# Bloque 9, Tiempo 1.170
# Bloque 9, Tiempo 1.175
# Bloque 9, Tiempo 1.180
# Bloque 9, Tiempo 1.185
# Bloque 9, Tiempo 1.190
# Bloque 9, Tiempo 1.195
# Bloque 9, Tiempo 1.200
# Bloque 9, Tiempo 1.205
# Bloque 9, Tiempo 1.210
# Bloque 9, Tiempo 1.215
# Bloque 9, Tiempo 1.220
# Bloque 9, Tiempo 1.225
# Bloque 9, Tiempo 1.230
# Bloque 9, Tiempo 1.235
# Bloque 9, Tiempo 1.240
# Bloque 9, Tiempo 1.245
# Bloque 9, Tiempo 1.250
# Bloque 9, Tiempo 1.255
# Bloque 9, Tiempo 1.260
# Bloque 9, Tiempo 1.265
# Bloque 9, Tiempo 1.270
# Bloque 9, Tiempo 1.275
# Bloque 9, Tiempo 1.280
# Bloque 9, Tiempo 1.285
# Bloque 9, Tiempo 1.290
# Bloque 9, Tiempo 1.295
# Bloque 9, Tiempo 1.300
# Bloque 9, Tiempo 1.305
# Bloque 9, Tiempo 1.310
# Bloque 9, Tiempo 1.315
# Bloque 9, Tiempo 1.320
# Bloque 9, Tiempo 1.325
# Bloque 9, Tiempo 1.330
# Bloque 9, Tiempo 1.335
# Bloque 9, Tiempo 1.340
# Bloque 9, Tiempo 1.345
# Bloque 9, Tiempo 1.350
# Bloque 9, Tiempo 1.355
# Bloque 9, Tiempo 1.360
# Bloque 9, Tiempo 1.365
# Bloque 9, Tiempo 1.370
# Bloque 9, Tiempo 1.375
# Bloque 9, Tiempo 1.380
# Bloque 9, Tiempo 1.385
# Bloque 9, Tiempo 1.390
# Bloque 9, Tiempo 1.395
# Bloque 9, Tiempo 1.400
# Bloque 9, Tiempo 1.405
# Bloque 9, Tiempo 1.410
# Bloque 9, Tiempo 1.415
# Bloque 9, Tiempo 1.420
# Bloque 9, Tiempo 1.425
# Bloque 9, Tiempo 1.430
# Bloque 9, Tiempo 1.435
# Bloque 9, Tiempo 1.440
# Bloque 9, Tiempo 1.445
# Bloque 9, Tiempo 1.450
# Bloque 9, Tiempo 1.455
# Bloque 9, Tiempo 1.460
# Bloque 9, Tiempo 1.465
# Bloque 9, Tiempo 1.470
# Bloque 9, Tiempo 1.475
# Bloque 9, Tiempo 1.480
# Bloque 9, Tiempo 1.485
# Bloque 9, Tiempo 1.490
# Bloque 9, Tiempo 1.495
# Bloque 9, Tiempo 1.500
# Bloque 9, Tiempo 1.505
# Bloque 9, Tiempo 1.510
# Bloque 9, Tiempo 1.515
# Bloque 9, Tiempo 1.520
# Bloque 9, Tiempo 1.525
# Bloque 9, Tiempo 1.530
# Bloque 9, Tiempo 1.535
# Bloque 9, Tiempo 1.540
# Bloque 9, Tiempo 1.545
# Bloque 9, Tiempo 1.550
# Bloque 9, Tiempo 1.555
# Bloque 9, Tiempo 1.560
# Bloque 9, Tiempo 1.565
# Bloque 9, Tiempo 1.570
# Bloque 9, Tiempo 1.575
# Bloque 9, Tiempo 1.580
# Bloque 9, Tiempo 1.585
# Bloque 9, Tiempo 1.590
# Bloque 9, Tiempo 1.595
# Bloque 9, Tiempo 1.600
# Bloque 9, Tiempo 1.605
# Bloque 9, Tiempo 1.610
# Bloque 9, Tiempo 1.615
# Bloque 9, Tiempo 1.620
# Bloque 9, Tiempo 1.625
# Bloque 9, Tiempo 1.630
# Bloque 9, Tiempo 1.635
# Bloque 9, Tiempo 1.640
# Bloque 9, Tiempo 1.645
# Bloque 9, Tiempo 1.650
# Bloque 9, Tiempo 1.655
# Bloque 9, Tiempo 1.660
# Bloque 9, Tiempo 1.665
# Bloque 9, Tiempo 1.670
# Bloque 9, Tiempo 1.675
# Bloque 9, Tiempo 1.680
# Bloque 9, Tiempo 1.685
# Bloque 9, Tiempo 1.690
# Bloque 9, Tiempo 1.695
# Bloque 9, Tiempo 1.700
# Bloque 9, Tiempo 1.705
# Bloque 9, Tiempo 1.710
# Bloque 9, Tiempo 1.715
# Bloque 9, Tiempo 1.720
# Bloque 9, Tiempo 1.725
# Bloque 9, Tiempo 1.730
# Bloque 9, Tiempo 1.735
# Bloque 9, Tiempo 1.740
# Bloque 9, Tiempo 1.745
# Bloque 9, Tiempo 1.750
# Bloque 9, Tiempo 1.755
# Bloque 9, Tiempo 1.760
# Bloque 9, Tiempo 1.765
# Bloque 9, Tiempo 1.770
# Bloque 9, Tiempo 1.775
# Bloque 9, Tiempo 1.780
# Bloque 9, Tiempo 1.785
# Bloque 9, Tiempo 1.790
# Bloque 9, Tiempo 1.795
# Bloque 9, Tiempo 1.800
# Bloque 9, Tiempo 1.805
# Bloque 9, Tiempo 1.810
# Bloque 9, Tiempo 1.815
# Bloque 9, Tiempo 1.820
# Bloque 9, Tiempo 1.825
# Bloque 9, Tiempo 1.830
# Bloque 9, Tiempo 1.835
# Bloque 9, Tiempo 1.840
# Bloque 9, Tiempo 1.845
# Bloque 9, Tiempo 1.850
# Bloque 9, Tiempo 1.855
# Bloque 9, Tiempo 1.860
# Bloque 9, Tiempo 1.865
# Bloque 9, Tiempo 1.870
# Bloque 9, Tiempo 1.875
# Bloque 9, Tiempo 1.880
# Bloque 9, Tiempo 1.885
# Bloque 9, Tiempo 1.890
# Bloque 9, Tiempo 1.895
# Bloque 9, Tiempo 1.900
# Bloque 9, Tiempo 1.905
# Bloque 9, Tiempo 1.910
# Bloque 9, Tiempo 1.915
# Bloque 9, Tiempo 1.920
# Bloque 9, Tiempo 1.925
# Bloque 9, Tiempo 1.930
# Bloque 9, Tiempo 1.935
# Bloque 9, Tiempo 1.940
# Bloque 9, Tiempo 1.945
# Bloque 9, Tiempo 1.950
# Bloque 9, Tiempo 1.955
# Bloque 9, Tiempo 1.960
# Bloque 9, Tiempo 1.965
# Bloque 9, Tiempo 1.970
# Bloque 9, Tiempo 1.975
# Bloque 9, Tiempo 1.980
# Bloque 9, Tiempo 1.985
# Bloque 9, Tiempo 1.990
# Bloque 9, Tiempo 1.995
# Bloque 9, Tiempo 2.000
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# Bloque 10, Tiempo 0.000
# Bloque 10, Tiempo 0.005
# Bloque 10, Tiempo 0.010
# Bloque 10, Tiempo 0.015
# Bloque 10, Tiempo 0.020
# Bloque 10, Tiempo 0.025
# Bloque 10, Tiempo 0.030
# Bloque 10, Tiempo 0.035
# Bloque 10, Tiempo 0.040
# Bloque 10, Tiempo 0.045
# Bloque 10, Tiempo 0.050
# Bloque 10, Tiempo 0.055
# Bloque 10, Tiempo 0.060
# Bloque 10, Tiempo 0.065
# Bloque 10, Tiempo 0.070
# Bloque 10, Tiempo 0.075
# Bloque 10, Tiempo 0.080
# Bloque 10, Tiempo 0.085
# Bloque 10, Tiempo 0.090
# Bloque 10, Tiempo 0.095
# Bloque 10, Tiempo 0.100
# Bloque 10, Tiempo 0.105
# Bloque 10, Tiempo 0.110
# Bloque 10, Tiempo 0.115
# Bloque 10, Tiempo 0.120
# Bloque 10, Tiempo 0.125
# Bloque 10, Tiempo 0.130
# Bloque 10, Tiempo 0.135
# Bloque 10, Tiempo 0.140
# Bloque 10, Tiempo 0.145
# Bloque 10, Tiempo 0.150
# Bloque 10, Tiempo 0.155
# Bloque 10, Tiempo 0.160
# Bloque 10, Tiempo 0.165
# Bloque 10, Tiempo 0.170
# Bloque 10, Tiempo 0.175
# Bloque 10, Tiempo 0.180
# Bloque 10, Tiempo 0.185
# Bloque 10, Tiempo 0.190
# Bloque 10, Tiempo 0.195
# Bloque 10, Tiempo 0.200
# Bloque 10, Tiempo 0.205
# Bloque 10, Tiempo 0.210
# Bloque 10, Tiempo 0.215
# Bloque 10, Tiempo 0.220
# Bloque 10, Tiempo 0.225
# Bloque 10, Tiempo 0.230
# Bloque 10, Tiempo 0.235
# Bloque 10, Tiempo 0.240
# Bloque 10, Tiempo 0.245
# Bloque 10, Tiempo 0.250
# Bloque 10, Tiempo 0.255
# Bloque 10, Tiempo 0.260
# Bloque 10, Tiempo 0.265
# Bloque 10, Tiempo 0.270
# Bloque 10, Tiempo 0.275
# Bloque 10, Tiempo 0.280
# Bloque 10, Tiempo 0.285
# Bloque 10, Tiempo 0.290
# Bloque 10, Tiempo 0.295
# Bloque 10, Tiempo 0.300
# Bloque 10, Tiempo 0.305
# Bloque 10, Tiempo 0.310
# Bloque 10, Tiempo 0.315
# Bloque 10, Tiempo 0.320
# Bloque 10, Tiempo 0.325
# Bloque 10, Tiempo 0.330
# Bloque 10, Tiempo 0.335
# Bloque 10, Tiempo 0.340
# Bloque 10, Tiempo 0.345
# Bloque 10, Tiempo 0.350
# Bloque 10, Tiempo 0.355
# Bloque 10, Tiempo 0.360
# Bloque 10, Tiempo 0.365
# Bloque 10, Tiempo 0.370
# Bloque 10, Tiempo 0.375
# Bloque 10, Tiempo 0.380
# Bloque 10, Tiempo 0.385
# Bloque 10, Tiempo 0.390
# Bloque 10, Tiempo 0.395
# Bloque 10, Tiempo 0.400
# Bloque 10, Tiempo 0.405
# Bloque 10, Tiempo 0.410
# Bloque 10, Tiempo 0.415
# Bloque 10, Tiempo 0.420
# Bloque 10, Tiempo 0.425
# Bloque 10, Tiempo 0.430
# Bloque 10, Tiempo 0.435
# Bloque 10, Tiempo 0.440
# Bloque 10, Tiempo 0.445
# Bloque 10, Tiempo 0.450
# Bloque 10, Tiempo 0.455
# Bloque 10, Tiempo 0.460
# Bloque 10, Tiempo 0.465
# Bloque 10, Tiempo 0.470
# Bloque 10, Tiempo 0.475
# Bloque 10, Tiempo 0.480
# Bloque 10, Tiempo 0.485
# Bloque 10, Tiempo 0.490
# Bloque 10, Tiempo 0.495
# Bloque 10, Tiempo 0.500
# Bloque 10, Tiempo 0.505
# Bloque 10, Tiempo 0.510
# Bloque 10, Tiempo 0.515
# Bloque 10, Tiempo 0.520
# Bloque 10, Tiempo 0.525
# Bloque 10, Tiempo 0.530
# Bloque 10, Tiempo 0.535
# Bloque 10, Tiempo 0.540
# Bloque 10, Tiempo 0.545
# Bloque 10, Tiempo 0.550
# Bloque 10, Tiempo 0.555
# Bloque 10, Tiempo 0.560
# Bloque 10, Tiempo 0.565
# Bloque 10, Tiempo 0.570
# Bloque 10, Tiempo 0.575
# Bloque 10, Tiempo 0.580
# Bloque 10, Tiempo 0.585
# Bloque 10, Tiempo 0.590
# Bloque 10, Tiempo 0.595
# Bloque 10, Tiempo 0.600
# Bloque 10, Tiempo 0.605
# Bloque 10, Tiempo 0.610
# Bloque 10, Tiempo 0.615
# Bloque 10, Tiempo 0.620
# Bloque 10, Tiempo 0.625
# Bloque 10, Tiempo 0.630
# Bloque 10, Tiempo 0.635
# Bloque 10, Tiempo 0.640
# Bloque 10, Tiempo 0.645
# Bloque 10, Tiempo 0.650
# Bloque 10, Tiempo 0.655
# Bloque 10, Tiempo 0.660
# Bloque 10, Tiempo 0.665
# Bloque 10, Tiempo 0.670
# Bloque 10, Tiempo 0.675
# Bloque 10, Tiempo 0.680
# Bloque 10, Tiempo 0.685
# Bloque 10, Tiempo 0.690
# Bloque 10, Tiempo 0.695
# Bloque 10, Tiempo 0.700
# Bloque 10, Tiempo 0.705
# Bloque 10, Tiempo 0.710
# Bloque 10, Tiempo 0.715
# Bloque 10, Tiempo 0.720
# Bloque 10, Tiempo 0.725
# Bloque 10, Tiempo 0.730
# Bloque 10, Tiempo 0.735
# Bloque 10, Tiempo 0.740
# Bloque 10, Tiempo 0.745
# Bloque 10, Tiempo 0.750
# Bloque 10, Tiempo 0.755
# Bloque 10, Tiempo 0.760
# Bloque 10, Tiempo 0.765
# Bloque 10, Tiempo 0.770
# Bloque 10, Tiempo 0.775
# Bloque 10, Tiempo 0.780
# Bloque 10, Tiempo 0.785
# Bloque 10, Tiempo 0.790
# Bloque 10, Tiempo 0.795
# Bloque 10, Tiempo 0.800
# Bloque 10, Tiempo 0.805
# Bloque 10, Tiempo 0.810
# Bloque 10, Tiempo 0.815
# Bloque 10, Tiempo 0.820
# Bloque 10, Tiempo 0.825
# Bloque 10, Tiempo 0.830
# Bloque 10, Tiempo 0.835
# Bloque 10, Tiempo 0.840
# Bloque 10, Tiempo 0.845
# Bloque 10, Tiempo 0.850
# Bloque 10, Tiempo 0.855
# Bloque 10, Tiempo 0.860
# Bloque 10, Tiempo 0.865
# Bloque 10, Tiempo 0.870
# Bloque 10, Tiempo 0.875
# Bloque 10, Tiempo 0.880
# Bloque 10, Tiempo 0.885
# Bloque 10, Tiempo 0.890
# Bloque 10, Tiempo 0.895
# Bloque 10, Tiempo 0.900
# Bloque 10, Tiempo 0.905
# Bloque 10, Tiempo 0.910
# Bloque 10, Tiempo 0.915
# Bloque 10, Tiempo 0.920
# Bloque 10, Tiempo 0.925
# Bloque 10, Tiempo 0.930
# Bloque 10, Tiempo 0.935
# Bloque 10, Tiempo 0.940
# Bloque 10, Tiempo 0.945
# Bloque 10, Tiempo 0.950
# Bloque 10, Tiempo 0.955
# Bloque 10, Tiempo 0.960
# Bloque 10, Tiempo 0.965
# Bloque 10, Tiempo 0.970
# Bloque 10, Tiempo 0.975
# Bloque 10, Tiempo 0.980
# Bloque 10, Tiempo 0.985
# Bloque 10, Tiempo 0.990
# Bloque 10, Tiempo 0.995
# Bloque 10, Tiempo 1.000
# Bloque 10, Tiempo 1.005
# Bloque 10, Tiempo 1.010
# Bloque 10, Tiempo 1.015
# Bloque 10, Tiempo 1.020
# Bloque 10, Tiempo 1.025
# Bloque 10, Tiempo 1.030
# Bloque 10, Tiempo 1.035
# Bloque 10, Tiempo 1.040
# Bloque 10, Tiempo 1.045
# Bloque 10, Tiempo 1.050
# Bloque 10, Tiempo 1.055
# Bloque 10, Tiempo 1.060
# Bloque 10, Tiempo 1.065
# Bloque 10, Tiempo 1.070
# Bloque 10, Tiempo 1.075
# Bloque 10, Tiempo 1.080
# Bloque 10, Tiempo 1.085
# Bloque 10, Tiempo 1.090
# Bloque 10, Tiempo 1.095
# Bloque 10, Tiempo 1.100
# Bloque 10, Tiempo 1.105
# Bloque 10, Tiempo 1.110
# Bloque 10, Tiempo 1.115
# Bloque 10, Tiempo 1.120
# Bloque 10, Tiempo 1.125
# Bloque 10, Tiempo 1.130
# Bloque 10, Tiempo 1.135
# Bloque 10, Tiempo 1.140
# Bloque 10, Tiempo 1.145
# Bloque 10, Tiempo 1.150
# Bloque 10, Tiempo 1.155
# Bloque 10, Tiempo 1.160
# Bloque 10, Tiempo 1.165
# Bloque 10, Tiempo 1.170
# Bloque 10, Tiempo 1.175
# Bloque 10, Tiempo 1.180
# Bloque 10, Tiempo 1.185
# Bloque 10, Tiempo 1.190
# Bloque 10, Tiempo 1.195
# Bloque 10, Tiempo 1.200
# Bloque 10, Tiempo 1.205
# Bloque 10, Tiempo 1.210
# Bloque 10, Tiempo 1.215
# Bloque 10, Tiempo 1.220
# Bloque 10, Tiempo 1.225
# Bloque 10, Tiempo 1.230
# Bloque 10, Tiempo 1.235
# Bloque 10, Tiempo 1.240
# Bloque 10, Tiempo 1.245
# Bloque 10, Tiempo 1.250
# Bloque 10, Tiempo 1.255
# Bloque 10, Tiempo 1.260
# Bloque 10, Tiempo 1.265
# Bloque 10, Tiempo 1.270
# Bloque 10, Tiempo 1.275
# Bloque 10, Tiempo 1.280
# Bloque 10, Tiempo 1.285
# Bloque 10, Tiempo 1.290
# Bloque 10, Tiempo 1.295
# Bloque 10, Tiempo 1.300
# Bloque 10, Tiempo 1.305
# Bloque 10, Tiempo 1.310
# Bloque 10, Tiempo 1.315
# Bloque 10, Tiempo 1.320
# Bloque 10, Tiempo 1.325
# Bloque 10, Tiempo 1.330
# Bloque 10, Tiempo 1.335
# Bloque 10, Tiempo 1.340
# Bloque 10, Tiempo 1.345
# Bloque 10, Tiempo 1.350
# Bloque 10, Tiempo 1.355
# Bloque 10, Tiempo 1.360
# Bloque 10, Tiempo 1.365
# Bloque 10, Tiempo 1.370
# Bloque 10, Tiempo 1.375
# Bloque 10, Tiempo 1.380
# Bloque 10, Tiempo 1.385
# Bloque 10, Tiempo 1.390
# Bloque 10, Tiempo 1.395
# Bloque 10, Tiempo 1.400
# Bloque 10, Tiempo 1.405
# Bloque 10, Tiempo 1.410
# Bloque 10, Tiempo 1.415
# Bloque 10, Tiempo 1.420
# Bloque 10, Tiempo 1.425
# Bloque 10, Tiempo 1.430
# Bloque 10, Tiempo 1.435
# Bloque 10, Tiempo 1.440
# Bloque 10, Tiempo 1.445
# Bloque 10, Tiempo 1.450
# Bloque 10, Tiempo 1.455
# Bloque 10, Tiempo 1.460
# Bloque 10, Tiempo 1.465
# Bloque 10, Tiempo 1.470
# Bloque 10, Tiempo 1.475
# Bloque 10, Tiempo 1.480
# Bloque 10, Tiempo 1.485
# Bloque 10, Tiempo 1.490
# Bloque 10, Tiempo 1.495
# Bloque 10, Tiempo 1.500
# Bloque 10, Tiempo 1.505
# Bloque 10, Tiempo 1.510
# Bloque 10, Tiempo 1.515
# Bloque 10, Tiempo 1.520
# Bloque 10, Tiempo 1.525
# Bloque 10, Tiempo 1.530
# Bloque 10, Tiempo 1.535
# Bloque 10, Tiempo 1.540
# Bloque 10, Tiempo 1.545
# Bloque 10, Tiempo 1.550
# Bloque 10, Tiempo 1.555
# Bloque 10, Tiempo 1.560
# Bloque 10, Tiempo 1.565
# Bloque 10, Tiempo 1.570
# Bloque 10, Tiempo 1.575
# Bloque 10, Tiempo 1.580
# Bloque 10, Tiempo 1.585
# Bloque 10, Tiempo 1.590
# Bloque 10, Tiempo 1.595
# Bloque 10, Tiempo 1.600
# Bloque 10, Tiempo 1.605
# Bloque 10, Tiempo 1.610
# Bloque 10, Tiempo 1.615
# Bloque 10, Tiempo 1.620
# Bloque 10, Tiempo 1.625
# Bloque 10, Tiempo 1.630
# Bloque 10, Tiempo 1.635
# Bloque 10, Tiempo 1.640
# Bloque 10, Tiempo 1.645
# Bloque 10, Tiempo 1.650
# Bloque 10, Tiempo 1.655
# Bloque 10, Tiempo 1.660
# Bloque 10, Tiempo 1.665
# Bloque 10, Tiempo 1.670
# Bloque 10, Tiempo 1.675
# Bloque 10, Tiempo 1.680
# Bloque 10, Tiempo 1.685
# Bloque 10, Tiempo 1.690
# Bloque 10, Tiempo 1.695
# Bloque 10, Tiempo 1.700
# Bloque 10, Tiempo 1.705
# Bloque 10, Tiempo 1.710
# Bloque 10, Tiempo 1.715
# Bloque 10, Tiempo 1.720
# Bloque 10, Tiempo 1.725
# Bloque 10, Tiempo 1.730
# Bloque 10, Tiempo 1.735
# Bloque 10, Tiempo 1.740
# Bloque 10, Tiempo 1.745
# Bloque 10, Tiempo 1.750
# Bloque 10, Tiempo 1.755
# Bloque 10, Tiempo 1.760
# Bloque 10, Tiempo 1.765
# Bloque 10, Tiempo 1.770
# Bloque 10, Tiempo 1.775
# Bloque 10, Tiempo 1.780
# Bloque 10, Tiempo 1.785
# Bloque 10, Tiempo 1.790
# Bloque 10, Tiempo 1.795
# Bloque 10, Tiempo 1.800
# Bloque 10, Tiempo 1.805
# Bloque 10, Tiempo 1.810
# Bloque 10, Tiempo 1.815
# Bloque 10, Tiempo 1.820
# Bloque 10, Tiempo 1.825
# Bloque 10, Tiempo 1.830
# Bloque 10, Tiempo 1.835
# Bloque 10, Tiempo 1.840
# Bloque 10, Tiempo 1.845
# Bloque 10, Tiempo 1.850
# Bloque 10, Tiempo 1.855
# Bloque 10, Tiempo 1.860
# Bloque 10, Tiempo 1.865
# Bloque 10, Tiempo 1.870
# Bloque 10, Tiempo 1.875
# Bloque 10, Tiempo 1.880
# Bloque 10, Tiempo 1.885
# Bloque 10, Tiempo 1.890
# Bloque 10, Tiempo 1.895
# Bloque 10, Tiempo 1.900
# Bloque 10, Tiempo 1.905
# Bloque 10, Tiempo 1.910
# Bloque 10, Tiempo 1.915
# Bloque 10, Tiempo 1.920
# Bloque 10, Tiempo 1.925
# Bloque 10, Tiempo 1.930
# Bloque 10, Tiempo 1.935
# Bloque 10, Tiempo 1.940
# Bloque 10, Tiempo 1.945
# Bloque 10, Tiempo 1.950
# Bloque 10, Tiempo 1.955
# Bloque 10, Tiempo 1.960
# Bloque 10, Tiempo 1.965
# Bloque 10, Tiempo 1.970
# Bloque 10, Tiempo 1.975
# Bloque 10, Tiempo 1.980
# Bloque 10, Tiempo 1.985
# Bloque 10, Tiempo 1.990
# Bloque 10, Tiempo 1.995
# Bloque 10, Tiempo 2.000
