# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d.axes3d import get_test_data
from mpl_toolkits.mplot3d import Axes3D
from fenics import *
from mshr import *
import numpy as np
from dotenv import load_dotenv
from scipy.ndimage import zoom
from scipy.interpolate import interp1d
import os
set_log_level(30)
# Cargar las variables del archivo .env
load_dotenv()
# Out:
# True

# %%
nueva_ruta = '/media/erick/TOSHIBA EXT/results_06032025/strong_allee/mu_0'

# %%
# Define time parameters
T = float(os.getenv('T'))
dt = float(os.getenv('dt'))
# nb = int(os.getenv('nb'))
save_images = os.getenv('SAVE_IMAGES')
nb = 1


# Define mesh and space
nodes_in_xaxis=int(os.getenv('nodes_in_xaxis'))
nodes_in_yaxis=int(os.getenv('nodes_in_yaxis'))
space_size=int(os.getenv('space_size'))


os.chdir(nueva_ruta)

# %%
# Parámetros de entrada
field1_name = "s"  
field2_name = "s"

# %%
def power_spectrum(field_name, t, block):
    """
    Calcula el espectro de potencia 2D en el espacio de Fourier, lo guarda normalizado y lo grafica.
    """
    field_file = f"matrix_{field_name}_{t:.3f}_nb_{block}.txt"
    
    try:
        field = np.loadtxt(field_file, float)
    except Exception as e:
        print(f"Error al cargar el archivo {field_file}: {e}")
        return None, None

    # Transformada de Fourier 2D
    fft_field = np.fft.fft2(field)
    fft_field = np.fft.fftshift(fft_field)
    fft_magnitude = np.abs(fft_field)  # Magnitud de la transformada

    # Normalización del espectro de potencia
    # fft_magnitude /= np.max(fft_magnitude)

    # Guardar el espectro de potencia normalizado
    dft_file = f"matrix_{field_name}_dft_{t:.3f}_nb_{block}.txt"
    np.savetxt(dft_file, fft_magnitude, delimiter="\t")

#     # Graficar el espectro de potencia
#     plt.figure(figsize=(6, 6))
#     plt.imshow(np.log1p(fft_magnitude), cmap='inferno', origin='lower')
#     plt.colorbar(label="Log Magnitude")
#     plt.title(f"Power Spectrum of {field_name} at t={t:.3f}, block={block}")
#     plt.xlabel("Frequency X")
#     plt.ylabel("Frequency Y")
#     plt.show()

    return field_file, dft_file

# %%
def correlation_function_fourier(dft_field1, dft_field2, field1_name, field2_name, step, block):
    """
    Calcula la correlación cruzada en el espacio de Fourier, sin transformarla al espacio real.
    Anula el máximo antes de graficar para mejorar la visualización.
    """
    # Cargar los espectros de Fourier
    fft1 = np.loadtxt(dft_field1, delimiter="\t")
    fft2 = np.loadtxt(dft_field2, delimiter="\t")

    # Asegurar que tengan el mismo tamaño
    min_shape = (min(fft1.shape[0], fft2.shape[0]), min(fft1.shape[1], fft2.shape[1]))
    fft1 = fft1[:min_shape[0], :min_shape[1]]
    fft2 = fft2[:min_shape[0], :min_shape[1]]

    # Multiplicar en el dominio de Fourier
    correlation_fourier = fft1 * np.conjugate(fft2)

    # Anular el valor máximo
    max_value = np.max(correlation_fourier)
    correlation_fourier[correlation_fourier == max_value] = 0

    # # Graficar
    # plt.figure(figsize=(6, 5))
    # plt.imshow(np.log1p(np.abs(correlation_fourier)), cmap='viridis', origin='lower')
    # plt.colorbar(label='Log Magnitude')
    # plt.title(f'Correlación ({field1_name} vs {field2_name}) Fourier')
    # plt.xlabel('Frecuencia X')
    # plt.ylabel('Frecuencia Y')
    # plt.show()

    return correlation_fourier

# %%
def inverse_correlation_fft(centered_correlation, field1_name, field2_name, step, block):
    """
    Revierte el desplazamiento de la función de correlación en Fourier y la transforma de vuelta al espacio real.
    También grafica el campo centrado antes de la transformación inversa.

    Args:
        centered_correlation (np.ndarray): Función de correlación en el espacio de Fourier.
        field1_name (str): Nombre del primer campo.
        field2_name (str): Nombre del segundo campo.
        step (float): Paso de tiempo.
        block (int): Número de bloque.

    Returns:
        np.ndarray: Transformada inversa de la correlación en el espacio real.
    """
    # Aplicar la transformada inversa de Fourier y centrar el resultado
    inverse_fft = np.fft.ifft2(np.fft.ifftshift(centered_correlation)).real  # Obtener solo la parte real
    inverse_fft = np.fft.fftshift(inverse_fft)  # Recentrar la imagen en el dominio espacial

    # Verificar valores antes de normalizar
    min_val = np.min(inverse_fft)
    max_val = np.max(inverse_fft)
    
    # if max_val - min_val < 1e-8:
    #     raise ValueError("Los valores de la transformada inversa son demasiado pequeños para normalizar.")

    # Normalizar entre 0 y 1
    inverse_fft -= min_val  # Asegurar que el mínimo sea 0
    inverse_fft /= (max_val - min_val)  # Normalizar evitando división por 0

#     # Graficar la transformada inversa centrada
#     plt.figure(figsize=(6, 5))
#     plt.imshow(inverse_fft, cmap='viridis', origin='lower')
#     plt.colorbar(label='Amplitud Normalizada')
#     plt.title(f'Correlación ({field1_name} vs {field2_name}) en espacio real')
#     plt.xlabel('Índice X')
#     plt.ylabel('Índice Y')
#     plt.show()
    
    return inverse_fft

# %%
def compute_correlation_length(centered_inverse_fft, dx):
    """
    Calcula la longitud de correlación a partir de un promedio radial de la transformada inversa centrada.
    
    Args:
        centered_inverse_fft (np.ndarray): Transformada inversa de la correlación centrada.
        dx (float): Resolución espacial en unidades físicas.
    
    Returns:
        float: Longitud de correlación en unidades físicas.
    """
    ny, nx = centered_inverse_fft.shape
    x_center, y_center = nx // 2, ny // 2
    
    y, x = np.indices((ny, nx))
    r = np.sqrt((x - x_center)**2 + (y - y_center)**2).astype(int)
    
    r_max = r.max()
    radial_profile = np.zeros(r_max + 1)
    counts = np.zeros(r_max + 1)
    
    for i in range(ny):
        for j in range(nx):
            radial_profile[r[i, j]] += centered_inverse_fft[i, j]
            counts[r[i, j]] += 1
    
    radial_profile /= np.where(counts == 0, 1, counts)
    
    max_value = radial_profile[0]
    threshold = max_value / np.e
    correlation_length_pixels = np.argmax(radial_profile < threshold)
    
    correlation_length_real = correlation_length_pixels * dx  # Conversión a unidades físicas
    
    print('Longitud de correlación en píxeles:', correlation_length_pixels)
    print('Longitud de correlación en unidades reales:', correlation_length_real)
    
    return correlation_length_real

# %%
dx = space_size / nodes_in_xaxis  # Resolución espacial
length_corr = []

for block in range(1, nb + 1):
    t = 0
    while t <= T:
        print("block=", block, 'tiempo', t)
        # print('Espectro de potencias')
        field_c, dft_field_c = power_spectrum(field1_name, t, block)
        field_s, dft_field_s = power_spectrum(field2_name, t, block)
        
        # print('Función de correlación en espacio de fourier')
        correlation_func = correlation_function_fourier(dft_field_c, dft_field_s, field1_name, field2_name, t, block)
        # print('Función de correlación en espacio real')
        inverse_fft_real = inverse_correlation_fft(correlation_func, field1_name, field2_name, t, block)
        
        correlation_length = compute_correlation_length(inverse_fft_real, dx)
        length_corr.append([t, correlation_length])
        print('--------------------------------------------------------------------')
        
        t += dt
# Out:
# block= 1 tiempo 0
# Longitud de correlación en píxeles: 4
# Longitud de correlación en unidades reales: 1.4
# --------------------------------------------------------------------
# block= 1 tiempo 0.005
# Longitud de correlación en píxeles: 5
# Longitud de correlación en unidades reales: 1.75
# --------------------------------------------------------------------
# block= 1 tiempo 0.01
# Longitud de correlación en píxeles: 5
# Longitud de correlación en unidades reales: 1.75
# --------------------------------------------------------------------
# block= 1 tiempo 0.015
# Longitud de correlación en píxeles: 6
# Longitud de correlación en unidades reales: 2.0999999999999996
# --------------------------------------------------------------------
# block= 1 tiempo 0.02
# Longitud de correlación en píxeles: 6
# Longitud de correlación en unidades reales: 2.0999999999999996
# --------------------------------------------------------------------
# block= 1 tiempo 0.025
# Longitud de correlación en píxeles: 6
# Longitud de correlación en unidades reales: 2.0999999999999996
# --------------------------------------------------------------------
# block= 1 tiempo 0.030000000000000002
# Longitud de correlación en píxeles: 7
# Longitud de correlación en unidades reales: 2.4499999999999997
# --------------------------------------------------------------------
# block= 1 tiempo 0.035
# Longitud de correlación en píxeles: 7
# Longitud de correlación en unidades reales: 2.4499999999999997
# --------------------------------------------------------------------
# block= 1 tiempo 0.04
# Longitud de correlación en píxeles: 7
# Longitud de correlación en unidades reales: 2.4499999999999997
# --------------------------------------------------------------------
# block= 1 tiempo 0.045
# Longitud de correlación en píxeles: 8
# Longitud de correlación en unidades reales: 2.8
# --------------------------------------------------------------------
# block= 1 tiempo 0.049999999999999996
# Longitud de correlación en píxeles: 8
# Longitud de correlación en unidades reales: 2.8
# --------------------------------------------------------------------
# block= 1 tiempo 0.05499999999999999
# Longitud de correlación en píxeles: 8
# Longitud de correlación en unidades reales: 2.8
# --------------------------------------------------------------------
# block= 1 tiempo 0.05999999999999999
# Longitud de correlación en píxeles: 8
# Longitud de correlación en unidades reales: 2.8
# --------------------------------------------------------------------
# block= 1 tiempo 0.06499999999999999
# Longitud de correlación en píxeles: 9
# Longitud de correlación en unidades reales: 3.15
# --------------------------------------------------------------------
# block= 1 tiempo 0.06999999999999999
# Longitud de correlación en píxeles: 9
# Longitud de correlación en unidades reales: 3.15
# --------------------------------------------------------------------
# block= 1 tiempo 0.075
# Longitud de correlación en píxeles: 9
# Longitud de correlación en unidades reales: 3.15
# --------------------------------------------------------------------
# block= 1 tiempo 0.08
# Longitud de correlación en píxeles: 9
# Longitud de correlación en unidades reales: 3.15
# --------------------------------------------------------------------
# block= 1 tiempo 0.085
# Longitud de correlación en píxeles: 10
# Longitud de correlación en unidades reales: 3.5
# --------------------------------------------------------------------
# block= 1 tiempo 0.09000000000000001
# Longitud de correlación en píxeles: 10
# Longitud de correlación en unidades reales: 3.5
# --------------------------------------------------------------------
# block= 1 tiempo 0.09500000000000001
# Longitud de correlación en píxeles: 10
# Longitud de correlación en unidades reales: 3.5
# --------------------------------------------------------------------
# block= 1 tiempo 0.10000000000000002
# Longitud de correlación en píxeles: 10
# Longitud de correlación en unidades reales: 3.5
# --------------------------------------------------------------------
# block= 1 tiempo 0.10500000000000002
# Longitud de correlación en píxeles: 11
# Longitud de correlación en unidades reales: 3.8499999999999996
# --------------------------------------------------------------------
# block= 1 tiempo 0.11000000000000003
# Longitud de correlación en píxeles: 11
# Longitud de correlación en unidades reales: 3.8499999999999996
# --------------------------------------------------------------------
# block= 1 tiempo 0.11500000000000003
# Longitud de correlación en píxeles: 11
# Longitud de correlación en unidades reales: 3.8499999999999996
# --------------------------------------------------------------------
# block= 1 tiempo 0.12000000000000004
# Longitud de correlación en píxeles: 11
# Longitud de correlación en unidades reales: 3.8499999999999996
# --------------------------------------------------------------------
# block= 1 tiempo 0.12500000000000003
# Longitud de correlación en píxeles: 11
# Longitud de correlación en unidades reales: 3.8499999999999996
# --------------------------------------------------------------------
# block= 1 tiempo 0.13000000000000003
# Longitud de correlación en píxeles: 12
# Longitud de correlación en unidades reales: 4.199999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.13500000000000004
# Longitud de correlación en píxeles: 12
# Longitud de correlación en unidades reales: 4.199999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.14000000000000004
# Longitud de correlación en píxeles: 12
# Longitud de correlación en unidades reales: 4.199999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.14500000000000005
# Longitud de correlación en píxeles: 12
# Longitud de correlación en unidades reales: 4.199999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.15000000000000005
# Longitud de correlación en píxeles: 12
# Longitud de correlación en unidades reales: 4.199999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.15500000000000005
# Longitud de correlación en píxeles: 13
# Longitud de correlación en unidades reales: 4.55
# --------------------------------------------------------------------
# block= 1 tiempo 0.16000000000000006
# Longitud de correlación en píxeles: 13
# Longitud de correlación en unidades reales: 4.55
# --------------------------------------------------------------------
# block= 1 tiempo 0.16500000000000006
# Longitud de correlación en píxeles: 13
# Longitud de correlación en unidades reales: 4.55
# --------------------------------------------------------------------
# block= 1 tiempo 0.17000000000000007
# Longitud de correlación en píxeles: 13
# Longitud de correlación en unidades reales: 4.55
# --------------------------------------------------------------------
# block= 1 tiempo 0.17500000000000007
# Longitud de correlación en píxeles: 13
# Longitud de correlación en unidades reales: 4.55
# --------------------------------------------------------------------
# block= 1 tiempo 0.18000000000000008
# Longitud de correlación en píxeles: 13
# Longitud de correlación en unidades reales: 4.55
# --------------------------------------------------------------------
# block= 1 tiempo 0.18500000000000008
# Longitud de correlación en píxeles: 14
# Longitud de correlación en unidades reales: 4.8999999999999995
# --------------------------------------------------------------------
# block= 1 tiempo 0.19000000000000009
# Longitud de correlación en píxeles: 14
# Longitud de correlación en unidades reales: 4.8999999999999995
# --------------------------------------------------------------------
# block= 1 tiempo 0.1950000000000001
# Longitud de correlación en píxeles: 14
# Longitud de correlación en unidades reales: 4.8999999999999995
# --------------------------------------------------------------------
# block= 1 tiempo 0.2000000000000001
# Longitud de correlación en píxeles: 14
# Longitud de correlación en unidades reales: 4.8999999999999995
# --------------------------------------------------------------------
# block= 1 tiempo 0.2050000000000001
# Longitud de correlación en píxeles: 14
# Longitud de correlación en unidades reales: 4.8999999999999995
# --------------------------------------------------------------------
# block= 1 tiempo 0.2100000000000001
# Longitud de correlación en píxeles: 14
# Longitud de correlación en unidades reales: 4.8999999999999995
# --------------------------------------------------------------------
# block= 1 tiempo 0.2150000000000001
# Longitud de correlación en píxeles: 15
# Longitud de correlación en unidades reales: 5.25
# --------------------------------------------------------------------
# block= 1 tiempo 0.2200000000000001
# Longitud de correlación en píxeles: 15
# Longitud de correlación en unidades reales: 5.25
# --------------------------------------------------------------------
# block= 1 tiempo 0.22500000000000012
# Longitud de correlación en píxeles: 15
# Longitud de correlación en unidades reales: 5.25
# --------------------------------------------------------------------
# block= 1 tiempo 0.23000000000000012
# Longitud de correlación en píxeles: 15
# Longitud de correlación en unidades reales: 5.25
# --------------------------------------------------------------------
# block= 1 tiempo 0.23500000000000013
# Longitud de correlación en píxeles: 15
# Longitud de correlación en unidades reales: 5.25
# --------------------------------------------------------------------
# block= 1 tiempo 0.24000000000000013
# Longitud de correlación en píxeles: 15
# Longitud de correlación en unidades reales: 5.25
# --------------------------------------------------------------------
# block= 1 tiempo 0.24500000000000013
# Longitud de correlación en píxeles: 15
# Longitud de correlación en unidades reales: 5.25
# --------------------------------------------------------------------
# block= 1 tiempo 0.2500000000000001
# Longitud de correlación en píxeles: 16
# Longitud de correlación en unidades reales: 5.6
# --------------------------------------------------------------------
# block= 1 tiempo 0.2550000000000001
# Longitud de correlación en píxeles: 16
# Longitud de correlación en unidades reales: 5.6
# --------------------------------------------------------------------
# block= 1 tiempo 0.2600000000000001
# Longitud de correlación en píxeles: 16
# Longitud de correlación en unidades reales: 5.6
# --------------------------------------------------------------------
# block= 1 tiempo 0.2650000000000001
# Longitud de correlación en píxeles: 16
# Longitud de correlación en unidades reales: 5.6
# --------------------------------------------------------------------
# block= 1 tiempo 0.27000000000000013
# Longitud de correlación en píxeles: 16
# Longitud de correlación en unidades reales: 5.6
# --------------------------------------------------------------------
# block= 1 tiempo 0.27500000000000013
# Longitud de correlación en píxeles: 16
# Longitud de correlación en unidades reales: 5.6
# --------------------------------------------------------------------
# block= 1 tiempo 0.28000000000000014
# Longitud de correlación en píxeles: 16
# Longitud de correlación en unidades reales: 5.6
# --------------------------------------------------------------------
# block= 1 tiempo 0.28500000000000014
# Longitud de correlación en píxeles: 17
# Longitud de correlación en unidades reales: 5.949999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.29000000000000015
# Longitud de correlación en píxeles: 17
# Longitud de correlación en unidades reales: 5.949999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.29500000000000015
# Longitud de correlación en píxeles: 17
# Longitud de correlación en unidades reales: 5.949999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.30000000000000016
# Longitud de correlación en píxeles: 17
# Longitud de correlación en unidades reales: 5.949999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.30500000000000016
# Longitud de correlación en píxeles: 17
# Longitud de correlación en unidades reales: 5.949999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.31000000000000016
# Longitud de correlación en píxeles: 17
# Longitud de correlación en unidades reales: 5.949999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.31500000000000017
# Longitud de correlación en píxeles: 17
# Longitud de correlación en unidades reales: 5.949999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.3200000000000002
# Longitud de correlación en píxeles: 18
# Longitud de correlación en unidades reales: 6.3
# --------------------------------------------------------------------
# block= 1 tiempo 0.3250000000000002
# Longitud de correlación en píxeles: 18
# Longitud de correlación en unidades reales: 6.3
# --------------------------------------------------------------------
# block= 1 tiempo 0.3300000000000002
# Longitud de correlación en píxeles: 18
# Longitud de correlación en unidades reales: 6.3
# --------------------------------------------------------------------
# block= 1 tiempo 0.3350000000000002
# Longitud de correlación en píxeles: 18
# Longitud de correlación en unidades reales: 6.3
# --------------------------------------------------------------------
# block= 1 tiempo 0.3400000000000002
# Longitud de correlación en píxeles: 18
# Longitud de correlación en unidades reales: 6.3
# --------------------------------------------------------------------
# block= 1 tiempo 0.3450000000000002
# Longitud de correlación en píxeles: 18
# Longitud de correlación en unidades reales: 6.3
# --------------------------------------------------------------------
# block= 1 tiempo 0.3500000000000002
# Longitud de correlación en píxeles: 18
# Longitud de correlación en unidades reales: 6.3
# --------------------------------------------------------------------
# block= 1 tiempo 0.3550000000000002
# Longitud de correlación en píxeles: 18
# Longitud de correlación en unidades reales: 6.3
# --------------------------------------------------------------------
# block= 1 tiempo 0.3600000000000002
# Longitud de correlación en píxeles: 19
# Longitud de correlación en unidades reales: 6.6499999999999995
# --------------------------------------------------------------------
# block= 1 tiempo 0.3650000000000002
# Longitud de correlación en píxeles: 19
# Longitud de correlación en unidades reales: 6.6499999999999995
# --------------------------------------------------------------------
# block= 1 tiempo 0.3700000000000002
# Longitud de correlación en píxeles: 19
# Longitud de correlación en unidades reales: 6.6499999999999995
# --------------------------------------------------------------------
# block= 1 tiempo 0.3750000000000002
# Longitud de correlación en píxeles: 19
# Longitud de correlación en unidades reales: 6.6499999999999995
# --------------------------------------------------------------------
# block= 1 tiempo 0.3800000000000002
# Longitud de correlación en píxeles: 19
# Longitud de correlación en unidades reales: 6.6499999999999995
# --------------------------------------------------------------------
# block= 1 tiempo 0.38500000000000023
# Longitud de correlación en píxeles: 19
# Longitud de correlación en unidades reales: 6.6499999999999995
# --------------------------------------------------------------------
# block= 1 tiempo 0.39000000000000024
# Longitud de correlación en píxeles: 19
# Longitud de correlación en unidades reales: 6.6499999999999995
# --------------------------------------------------------------------
# block= 1 tiempo 0.39500000000000024
# Longitud de correlación en píxeles: 19
# Longitud de correlación en unidades reales: 6.6499999999999995
# --------------------------------------------------------------------
# block= 1 tiempo 0.40000000000000024
# Longitud de correlación en píxeles: 19
# Longitud de correlación en unidades reales: 6.6499999999999995
# --------------------------------------------------------------------
# block= 1 tiempo 0.40500000000000025
# Longitud de correlación en píxeles: 20
# Longitud de correlación en unidades reales: 7.0
# --------------------------------------------------------------------
# block= 1 tiempo 0.41000000000000025
# Longitud de correlación en píxeles: 20
# Longitud de correlación en unidades reales: 7.0
# --------------------------------------------------------------------
# block= 1 tiempo 0.41500000000000026
# Longitud de correlación en píxeles: 20
# Longitud de correlación en unidades reales: 7.0
# --------------------------------------------------------------------
# block= 1 tiempo 0.42000000000000026
# Longitud de correlación en píxeles: 20
# Longitud de correlación en unidades reales: 7.0
# --------------------------------------------------------------------
# block= 1 tiempo 0.42500000000000027
# Longitud de correlación en píxeles: 20
# Longitud de correlación en unidades reales: 7.0
# --------------------------------------------------------------------
# block= 1 tiempo 0.43000000000000027
# Longitud de correlación en píxeles: 20
# Longitud de correlación en unidades reales: 7.0
# --------------------------------------------------------------------
# block= 1 tiempo 0.4350000000000003
# Longitud de correlación en píxeles: 20
# Longitud de correlación en unidades reales: 7.0
# --------------------------------------------------------------------
# block= 1 tiempo 0.4400000000000003
# Longitud de correlación en píxeles: 20
# Longitud de correlación en unidades reales: 7.0
# --------------------------------------------------------------------
# block= 1 tiempo 0.4450000000000003
# Longitud de correlación en píxeles: 21
# Longitud de correlación en unidades reales: 7.35
# --------------------------------------------------------------------
# block= 1 tiempo 0.4500000000000003
# Longitud de correlación en píxeles: 21
# Longitud de correlación en unidades reales: 7.35
# --------------------------------------------------------------------
# block= 1 tiempo 0.4550000000000003
# Longitud de correlación en píxeles: 21
# Longitud de correlación en unidades reales: 7.35
# --------------------------------------------------------------------
# block= 1 tiempo 0.4600000000000003
# Longitud de correlación en píxeles: 21
# Longitud de correlación en unidades reales: 7.35
# --------------------------------------------------------------------
# block= 1 tiempo 0.4650000000000003
# Longitud de correlación en píxeles: 21
# Longitud de correlación en unidades reales: 7.35
# --------------------------------------------------------------------
# block= 1 tiempo 0.4700000000000003
# Longitud de correlación en píxeles: 21
# Longitud de correlación en unidades reales: 7.35
# --------------------------------------------------------------------
# block= 1 tiempo 0.4750000000000003
# Longitud de correlación en píxeles: 21
# Longitud de correlación en unidades reales: 7.35
# --------------------------------------------------------------------
# block= 1 tiempo 0.4800000000000003
# Longitud de correlación en píxeles: 21
# Longitud de correlación en unidades reales: 7.35
# --------------------------------------------------------------------
# block= 1 tiempo 0.4850000000000003
# Longitud de correlación en píxeles: 21
# Longitud de correlación en unidades reales: 7.35
# --------------------------------------------------------------------
# block= 1 tiempo 0.4900000000000003
# Longitud de correlación en píxeles: 22
# Longitud de correlación en unidades reales: 7.699999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.49500000000000033
# Longitud de correlación en píxeles: 22
# Longitud de correlación en unidades reales: 7.699999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5000000000000003
# Longitud de correlación en píxeles: 22
# Longitud de correlación en unidades reales: 7.699999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5050000000000003
# Longitud de correlación en píxeles: 22
# Longitud de correlación en unidades reales: 7.699999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5100000000000003
# Longitud de correlación en píxeles: 22
# Longitud de correlación en unidades reales: 7.699999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5150000000000003
# Longitud de correlación en píxeles: 22
# Longitud de correlación en unidades reales: 7.699999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5200000000000004
# Longitud de correlación en píxeles: 22
# Longitud de correlación en unidades reales: 7.699999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5250000000000004
# Longitud de correlación en píxeles: 22
# Longitud de correlación en unidades reales: 7.699999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5300000000000004
# Longitud de correlación en píxeles: 22
# Longitud de correlación en unidades reales: 7.699999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5350000000000004
# Longitud de correlación en píxeles: 23
# Longitud de correlación en unidades reales: 8.049999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5400000000000004
# Longitud de correlación en píxeles: 23
# Longitud de correlación en unidades reales: 8.049999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5450000000000004
# Longitud de correlación en píxeles: 23
# Longitud de correlación en unidades reales: 8.049999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5500000000000004
# Longitud de correlación en píxeles: 23
# Longitud de correlación en unidades reales: 8.049999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5550000000000004
# Longitud de correlación en píxeles: 23
# Longitud de correlación en unidades reales: 8.049999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5600000000000004
# Longitud de correlación en píxeles: 23
# Longitud de correlación en unidades reales: 8.049999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5650000000000004
# Longitud de correlación en píxeles: 23
# Longitud de correlación en unidades reales: 8.049999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5700000000000004
# Longitud de correlación en píxeles: 23
# Longitud de correlación en unidades reales: 8.049999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5750000000000004
# Longitud de correlación en píxeles: 24
# Longitud de correlación en unidades reales: 8.399999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5800000000000004
# Longitud de correlación en píxeles: 24
# Longitud de correlación en unidades reales: 8.399999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5850000000000004
# Longitud de correlación en píxeles: 24
# Longitud de correlación en unidades reales: 8.399999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5900000000000004
# Longitud de correlación en píxeles: 24
# Longitud de correlación en unidades reales: 8.399999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.5950000000000004
# Longitud de correlación en píxeles: 24
# Longitud de correlación en unidades reales: 8.399999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.6000000000000004
# Longitud de correlación en píxeles: 24
# Longitud de correlación en unidades reales: 8.399999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.6050000000000004
# Longitud de correlación en píxeles: 24
# Longitud de correlación en unidades reales: 8.399999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.6100000000000004
# Longitud de correlación en píxeles: 24
# Longitud de correlación en unidades reales: 8.399999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.6150000000000004
# Longitud de correlación en píxeles: 24
# Longitud de correlación en unidades reales: 8.399999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.6200000000000004
# Longitud de correlación en píxeles: 25
# Longitud de correlación en unidades reales: 8.75
# --------------------------------------------------------------------
# block= 1 tiempo 0.6250000000000004
# Longitud de correlación en píxeles: 25
# Longitud de correlación en unidades reales: 8.75
# --------------------------------------------------------------------
# block= 1 tiempo 0.6300000000000004
# Longitud de correlación en píxeles: 25
# Longitud de correlación en unidades reales: 8.75
# --------------------------------------------------------------------
# block= 1 tiempo 0.6350000000000005
# Longitud de correlación en píxeles: 25
# Longitud de correlación en unidades reales: 8.75
# --------------------------------------------------------------------
# block= 1 tiempo 0.6400000000000005
# Longitud de correlación en píxeles: 25
# Longitud de correlación en unidades reales: 8.75
# --------------------------------------------------------------------
# block= 1 tiempo 0.6450000000000005
# Longitud de correlación en píxeles: 25
# Longitud de correlación en unidades reales: 8.75
# --------------------------------------------------------------------
# block= 1 tiempo 0.6500000000000005
# Longitud de correlación en píxeles: 25
# Longitud de correlación en unidades reales: 8.75
# --------------------------------------------------------------------
# block= 1 tiempo 0.6550000000000005
# Longitud de correlación en píxeles: 25
# Longitud de correlación en unidades reales: 8.75
# --------------------------------------------------------------------
# block= 1 tiempo 0.6600000000000005
# Longitud de correlación en píxeles: 25
# Longitud de correlación en unidades reales: 8.75
# --------------------------------------------------------------------
# block= 1 tiempo 0.6650000000000005
# Longitud de correlación en píxeles: 25
# Longitud de correlación en unidades reales: 8.75
# --------------------------------------------------------------------
# block= 1 tiempo 0.6700000000000005
# Longitud de correlación en píxeles: 26
# Longitud de correlación en unidades reales: 9.1
# --------------------------------------------------------------------
# block= 1 tiempo 0.6750000000000005
# Longitud de correlación en píxeles: 26
# Longitud de correlación en unidades reales: 9.1
# --------------------------------------------------------------------
# block= 1 tiempo 0.6800000000000005
# Longitud de correlación en píxeles: 26
# Longitud de correlación en unidades reales: 9.1
# --------------------------------------------------------------------
# block= 1 tiempo 0.6850000000000005
# Longitud de correlación en píxeles: 26
# Longitud de correlación en unidades reales: 9.1
# --------------------------------------------------------------------
# block= 1 tiempo 0.6900000000000005
# Longitud de correlación en píxeles: 26
# Longitud de correlación en unidades reales: 9.1
# --------------------------------------------------------------------
# block= 1 tiempo 0.6950000000000005
# Longitud de correlación en píxeles: 26
# Longitud de correlación en unidades reales: 9.1
# --------------------------------------------------------------------
# block= 1 tiempo 0.7000000000000005
# Longitud de correlación en píxeles: 26
# Longitud de correlación en unidades reales: 9.1
# --------------------------------------------------------------------
# block= 1 tiempo 0.7050000000000005
# Longitud de correlación en píxeles: 26
# Longitud de correlación en unidades reales: 9.1
# --------------------------------------------------------------------
# block= 1 tiempo 0.7100000000000005
# Longitud de correlación en píxeles: 26
# Longitud de correlación en unidades reales: 9.1
# --------------------------------------------------------------------
# block= 1 tiempo 0.7150000000000005
# Longitud de correlación en píxeles: 26
# Longitud de correlación en unidades reales: 9.1
# --------------------------------------------------------------------
# block= 1 tiempo 0.7200000000000005
# Longitud de correlación en píxeles: 27
# Longitud de correlación en unidades reales: 9.45
# --------------------------------------------------------------------
# block= 1 tiempo 0.7250000000000005
# Longitud de correlación en píxeles: 27
# Longitud de correlación en unidades reales: 9.45
# --------------------------------------------------------------------
# block= 1 tiempo 0.7300000000000005
# Longitud de correlación en píxeles: 27
# Longitud de correlación en unidades reales: 9.45
# --------------------------------------------------------------------
# block= 1 tiempo 0.7350000000000005
# Longitud de correlación en píxeles: 27
# Longitud de correlación en unidades reales: 9.45
# --------------------------------------------------------------------
# block= 1 tiempo 0.7400000000000005
# Longitud de correlación en píxeles: 27
# Longitud de correlación en unidades reales: 9.45
# --------------------------------------------------------------------
# block= 1 tiempo 0.7450000000000006
# Longitud de correlación en píxeles: 27
# Longitud de correlación en unidades reales: 9.45
# --------------------------------------------------------------------
# block= 1 tiempo 0.7500000000000006
# Longitud de correlación en píxeles: 27
# Longitud de correlación en unidades reales: 9.45
# --------------------------------------------------------------------
# block= 1 tiempo 0.7550000000000006
# Longitud de correlación en píxeles: 27
# Longitud de correlación en unidades reales: 9.45
# --------------------------------------------------------------------
# block= 1 tiempo 0.7600000000000006
# Longitud de correlación en píxeles: 27
# Longitud de correlación en unidades reales: 9.45
# --------------------------------------------------------------------
# block= 1 tiempo 0.7650000000000006
# Longitud de correlación en píxeles: 27
# Longitud de correlación en unidades reales: 9.45
# --------------------------------------------------------------------
# block= 1 tiempo 0.7700000000000006
# Longitud de correlación en píxeles: 28
# Longitud de correlación en unidades reales: 9.799999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.7750000000000006
# Longitud de correlación en píxeles: 28
# Longitud de correlación en unidades reales: 9.799999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.7800000000000006
# Longitud de correlación en píxeles: 28
# Longitud de correlación en unidades reales: 9.799999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.7850000000000006
# Longitud de correlación en píxeles: 28
# Longitud de correlación en unidades reales: 9.799999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.7900000000000006
# Longitud de correlación en píxeles: 28
# Longitud de correlación en unidades reales: 9.799999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.7950000000000006
# Longitud de correlación en píxeles: 28
# Longitud de correlación en unidades reales: 9.799999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8000000000000006
# Longitud de correlación en píxeles: 28
# Longitud de correlación en unidades reales: 9.799999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8050000000000006
# Longitud de correlación en píxeles: 28
# Longitud de correlación en unidades reales: 9.799999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8100000000000006
# Longitud de correlación en píxeles: 28
# Longitud de correlación en unidades reales: 9.799999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8150000000000006
# Longitud de correlación en píxeles: 28
# Longitud de correlación en unidades reales: 9.799999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8200000000000006
# Longitud de correlación en píxeles: 29
# Longitud de correlación en unidades reales: 10.149999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8250000000000006
# Longitud de correlación en píxeles: 29
# Longitud de correlación en unidades reales: 10.149999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8300000000000006
# Longitud de correlación en píxeles: 29
# Longitud de correlación en unidades reales: 10.149999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8350000000000006
# Longitud de correlación en píxeles: 29
# Longitud de correlación en unidades reales: 10.149999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8400000000000006
# Longitud de correlación en píxeles: 29
# Longitud de correlación en unidades reales: 10.149999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8450000000000006
# Longitud de correlación en píxeles: 29
# Longitud de correlación en unidades reales: 10.149999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8500000000000006
# Longitud de correlación en píxeles: 29
# Longitud de correlación en unidades reales: 10.149999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8550000000000006
# Longitud de correlación en píxeles: 29
# Longitud de correlación en unidades reales: 10.149999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8600000000000007
# Longitud de correlación en píxeles: 29
# Longitud de correlación en unidades reales: 10.149999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8650000000000007
# Longitud de correlación en píxeles: 29
# Longitud de correlación en unidades reales: 10.149999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8700000000000007
# Longitud de correlación en píxeles: 29
# Longitud de correlación en unidades reales: 10.149999999999999
# --------------------------------------------------------------------
# block= 1 tiempo 0.8750000000000007
# Longitud de correlación en píxeles: 30
# Longitud de correlación en unidades reales: 10.5
# --------------------------------------------------------------------
# block= 1 tiempo 0.8800000000000007
# Longitud de correlación en píxeles: 30
# Longitud de correlación en unidades reales: 10.5
# --------------------------------------------------------------------
# block= 1 tiempo 0.8850000000000007
# Longitud de correlación en píxeles: 30
# Longitud de correlación en unidades reales: 10.5
# --------------------------------------------------------------------
# block= 1 tiempo 0.8900000000000007
# Longitud de correlación en píxeles: 30
# Longitud de correlación en unidades reales: 10.5
# --------------------------------------------------------------------
# block= 1 tiempo 0.8950000000000007
# Longitud de correlación en píxeles: 30
# Longitud de correlación en unidades reales: 10.5
# --------------------------------------------------------------------
# block= 1 tiempo 0.9000000000000007
# Longitud de correlación en píxeles: 30
# Longitud de correlación en unidades reales: 10.5
# --------------------------------------------------------------------
# block= 1 tiempo 0.9050000000000007
# Longitud de correlación en píxeles: 30
# Longitud de correlación en unidades reales: 10.5
# --------------------------------------------------------------------
# block= 1 tiempo 0.9100000000000007
# Longitud de correlación en píxeles: 30
# Longitud de correlación en unidades reales: 10.5
# --------------------------------------------------------------------
# block= 1 tiempo 0.9150000000000007
# Longitud de correlación en píxeles: 30
# Longitud de correlación en unidades reales: 10.5
# --------------------------------------------------------------------
# block= 1 tiempo 0.9200000000000007
# Longitud de correlación en píxeles: 30
# Longitud de correlación en unidades reales: 10.5
# --------------------------------------------------------------------
# block= 1 tiempo 0.9250000000000007
# Longitud de correlación en píxeles: 30
# Longitud de correlación en unidades reales: 10.5
# --------------------------------------------------------------------
# block= 1 tiempo 0.9300000000000007
# Longitud de correlación en píxeles: 31
# Longitud de correlación en unidades reales: 10.85
# --------------------------------------------------------------------
# block= 1 tiempo 0.9350000000000007
# Longitud de correlación en píxeles: 31
# Longitud de correlación en unidades reales: 10.85
# --------------------------------------------------------------------
# block= 1 tiempo 0.9400000000000007
# Longitud de correlación en píxeles: 31
# Longitud de correlación en unidades reales: 10.85
# --------------------------------------------------------------------
# block= 1 tiempo 0.9450000000000007
# Longitud de correlación en píxeles: 31
# Longitud de correlación en unidades reales: 10.85
# --------------------------------------------------------------------
# block= 1 tiempo 0.9500000000000007
# Longitud de correlación en píxeles: 31
# Longitud de correlación en unidades reales: 10.85
# --------------------------------------------------------------------
# block= 1 tiempo 0.9550000000000007
# Longitud de correlación en píxeles: 31
# Longitud de correlación en unidades reales: 10.85
# --------------------------------------------------------------------
# block= 1 tiempo 0.9600000000000007
# Longitud de correlación en píxeles: 31
# Longitud de correlación en unidades reales: 10.85
# --------------------------------------------------------------------
# block= 1 tiempo 0.9650000000000007
# Longitud de correlación en píxeles: 31
# Longitud de correlación en unidades reales: 10.85
# --------------------------------------------------------------------
# block= 1 tiempo 0.9700000000000008
# Longitud de correlación en píxeles: 31
# Longitud de correlación en unidades reales: 10.85
# --------------------------------------------------------------------
# block= 1 tiempo 0.9750000000000008
# Longitud de correlación en píxeles: 31
# Longitud de correlación en unidades reales: 10.85
# --------------------------------------------------------------------
# block= 1 tiempo 0.9800000000000008
# Longitud de correlación en píxeles: 31
# Longitud de correlación en unidades reales: 10.85
# --------------------------------------------------------------------
# block= 1 tiempo 0.9850000000000008
# Longitud de correlación en píxeles: 32
# Longitud de correlación en unidades reales: 11.2
# --------------------------------------------------------------------
# block= 1 tiempo 0.9900000000000008
# Longitud de correlación en píxeles: 32
# Longitud de correlación en unidades reales: 11.2
# --------------------------------------------------------------------
# block= 1 tiempo 0.9950000000000008
# Longitud de correlación en píxeles: 32
# Longitud de correlación en unidades reales: 11.2
# --------------------------------------------------------------------

# %%
length_corr = np.array(length_corr)
np.savetxt(
    f'corr_length_real_inverse_{field1_name}_{field2_name}.txt',
    length_corr,
    fmt="%.5f",  # Mayor precisión
    delimiter="\t",
    header="Tiempo\tLongitud_Correlacion"
)
