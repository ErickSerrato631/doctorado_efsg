# %%
import matplotlib.pyplot as plt
from fenics import *
from scipy.signal import correlate2d
from scipy.ndimage import gaussian_filter
from mshr import *
import numpy as np
from dotenv import load_dotenv
import os
from scipy.stats import linregress
from scipy.interpolate import interp1d
set_log_level(30)
# Cargar las variables del archivo .env
load_dotenv()
# Out:
# True

# %%
nueva_ruta = os.path.expanduser('~/Drive/Doctorado Erick Serrato/25-I/weak_allee/mu_0')

# %%
# Define time parameters
T = float(os.getenv('T'))
dt = float(os.getenv('dt'))
nb = int(os.getenv('nb'))
save_images = os.getenv('SAVE_IMAGES')

# Define mesh and space
nodes_in_xaxis=int(os.getenv('nodes_in_xaxis'))
nodes_in_yaxis=int(os.getenv('nodes_in_yaxis'))
space_size=int(os.getenv('space_size'))

os.chdir(nueva_ruta)

# %%
def calculate_correlation(field1, field2, field1_name, field2_name, step, nodes_in_xaxis, nodes_in_yaxis, space_size, sigma=1):
    """
    Calcula la correlación cruzada normalizada entre dos campos 2D considerando la malla espacial,
    asegurando que la correlación esté correctamente normalizada en el rango [-1,1].
    Aplica un suavizado con un filtro gaussiano para reducir ruido en la visualización.
    """

    # Calcular media y desviación estándar de cada campo
    mean1, std1 = np.mean(field1), np.std(field1)
    mean2, std2 = np.mean(field2), np.std(field2)

    print(f'Correlación de {field1_name} con {field2_name} al tiempo {step} considerando la malla espacial.')

    # Evitar divisiones por cero
    if std1 == 0 or std2 == 0:
        print("Advertencia: Desviación estándar cero detectada. Devolviendo matriz de ceros.")
        correlation = np.zeros((2 * field1.shape[0] - 1, 2 * field1.shape[1] - 1))
        return correlation

    # Normalizar los campos
    field1 = (field1 - mean1) / std1
    field2 = (field2 - mean2) / std2

    # Dimensiones de los campos
    rows, cols = field1.shape
    max_shift = rows - 1

    # Definir la resolución espacial
    dx = space_size / nodes_in_xaxis
    dy = space_size / nodes_in_yaxis

    # Inicializar matriz para almacenar la correlación cruzada
    correlation = np.zeros((2 * rows - 1, 2 * cols - 1))
    
    # Crear matrices de coordenadas espaciales con la escala correcta
    x_positions = np.linspace(-space_size / 2, space_size / 2, correlation.shape[1])
    y_positions = np.linspace(-space_size / 2, space_size / 2, correlation.shape[0])

    # Calcular la correlación cruzada normalizada
    for i in range(-max_shift, max_shift + 1):
        for j in range(-max_shift, max_shift + 1):
            overlap1 = field1[max(0, i):rows + min(0, i), max(0, j):cols + min(0, j)]
            overlap2 = field2[max(0, -i):rows + min(0, -i), max(0, -j):cols + min(0, -j)]
            if overlap1.size > 0:
                C_xy = np.mean(overlap1 * overlap2)
                correlation[i + max_shift, j + max_shift] = np.clip(C_xy, -1, 1)  # Asegurar normalización

    # Aplicar suavizado con filtro gaussiano
    correlation_smoothed = gaussian_filter(correlation, sigma=sigma)

    # Guardar la matriz de correlación en un archivo
    f_save = f"correlacion_{field1_name}_{field2_name}_{step:.3f}.txt"
    np.savetxt(f_save, correlation_smoothed, delimiter="\t")

    print(f'Correlación suavizada de {field1_name} con {field2_name} al tiempo {step} guardada en {f_save}')

    # Graficar la correlación en unidades físicas
    plt.figure(figsize=(8, 6))
    plt.imshow(correlation_smoothed, extent=[x_positions[0], x_positions[-1], y_positions[0], y_positions[-1]], 
               origin='lower', cmap='seismic', aspect='auto', vmin=-1, vmax=1)
    plt.colorbar(label="Correlación Normalizada (Suavizada)")
    plt.xlabel("Desplazamiento en X (unidades físicas)")
    plt.ylabel("Desplazamiento en Y (unidades físicas)")
    plt.title(f"Correlación Suavizada de {field1_name} con {field2_name} (Tiempo {step})")
    plt.show()

    return correlation_smoothed

# %%
def load_field(field1_name, field2_name, step, nb):
    """
    Procesa campos guardados por field_to_numpy_array y calcula correlaciones.

    Args:
        field_name1 (str): Nombre del primer campo (e.g., "c").
        field_name2 (str): Nombre del segundo campo (e.g., "s").
        step (str): Paso de tiempo formateado (e.g., "0.000").
        nb (int): Bloque a procesar.

    Returns:
        dict: Correlación cruzada entre los dos campos.
    """
    file1 = f"matrix_{field1_name}_{step:.3f}_nb_{int(nb)}.txt"
    file2 = f"matrix_{field2_name}_{step:.3f}_nb_{int(nb)}.txt"

    # Cargar los campos
    field1 = np.loadtxt(file1, delimiter="\t")
    field2 = np.loadtxt(file2, delimiter="\t") 

    return field1, field2

# %%
def compute_correlation_length(correlation, nodes_in_xaxis, space_size):
    """
    Calcula la longitud de correlación en el eje X basado en la matriz de correlación cruzada.
    Se define como la distancia en la que la correlación cae por debajo de e^{-1}.
    """
    # Parámetros de la malla
    dx = space_size / nodes_in_xaxis  # Espaciado en x

    # Centro de la matriz de correlación
    center = correlation.shape[0] // 2

    # Extraer la fila central (correlación a lo largo del eje x)
    correlation_x = correlation[center, :]

    # Crear vector de posiciones en el eje X con la escala correcta
    x_positions = np.linspace(-space_size / 2, space_size / 2, len(correlation_x))

    # Buscar la longitud de correlación donde cae por debajo de e^{-1}
    threshold = np.exp(-1)
    correlation_x_abs = np.abs(correlation_x)  # Considerar valores absolutos
    idx = np.where(correlation_x_abs < threshold)[0]

    if len(idx) > 0:
        correlation_length_x = np.abs(x_positions[idx[0]])
    else:
        correlation_length_x = np.max(np.abs(x_positions))  # Si no cae, tomamos el máximo

    # Graficar la correlación
    plt.figure(figsize=(8, 5))
    plt.plot(x_positions, correlation_x, label="Correlación en X")
    plt.axhline(y=threshold, color='r', linestyle='--', label="e^{-1} Umbral")
    plt.axvline(x=correlation_length_x, color='g', linestyle='--', label=f"Longitud de Correlación ≈ {correlation_length_x:.2f}")
    plt.xlabel("Distancia en X (unidades físicas)")
    plt.ylabel("Correlación Normalizada")
    plt.title("Longitud de Correlación en el Eje X")
    plt.legend()
    plt.grid()
    plt.show()

    return correlation_length_x

# %%
# Parámetros de entrada
field1_name = "c"  # Campo c (cáncer)
field2_name = "s"  # Campo s (células sanas)

# %%
t = 0
while t <= T:
    # Cargar campos
    field1, field2 = load_field(field1_name, field2_name, t, nb)
    calculate_correlation(field1, field2, field1_name, field2_name, t, nodes_in_xaxis, nodes_in_yaxis, space_size)
    t += dt
# Out:
# Correlación de c con s al tiempo 0 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0 guardada en correlacion_c_s_0.000.txt
# Correlación de c con s al tiempo 0.005 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.005 guardada en correlacion_c_s_0.005.txt
# Correlación de c con s al tiempo 0.01 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.01 guardada en correlacion_c_s_0.010.txt
# Correlación de c con s al tiempo 0.015 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.015 guardada en correlacion_c_s_0.015.txt
# Correlación de c con s al tiempo 0.02 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.02 guardada en correlacion_c_s_0.020.txt
# Correlación de c con s al tiempo 0.025 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.025 guardada en correlacion_c_s_0.025.txt
# Correlación de c con s al tiempo 0.030000000000000002 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.030000000000000002 guardada en correlacion_c_s_0.030.txt
# Correlación de c con s al tiempo 0.035 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.035 guardada en correlacion_c_s_0.035.txt
# Correlación de c con s al tiempo 0.04 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.04 guardada en correlacion_c_s_0.040.txt
# Correlación de c con s al tiempo 0.045 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.045 guardada en correlacion_c_s_0.045.txt
# Correlación de c con s al tiempo 0.049999999999999996 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.049999999999999996 guardada en correlacion_c_s_0.050.txt
# Correlación de c con s al tiempo 0.05499999999999999 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.05499999999999999 guardada en correlacion_c_s_0.055.txt
# Correlación de c con s al tiempo 0.05999999999999999 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.05999999999999999 guardada en correlacion_c_s_0.060.txt
# Correlación de c con s al tiempo 0.06499999999999999 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.06499999999999999 guardada en correlacion_c_s_0.065.txt
# Correlación de c con s al tiempo 0.06999999999999999 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.06999999999999999 guardada en correlacion_c_s_0.070.txt
# Correlación de c con s al tiempo 0.075 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.075 guardada en correlacion_c_s_0.075.txt
# Correlación de c con s al tiempo 0.08 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.08 guardada en correlacion_c_s_0.080.txt
# Correlación de c con s al tiempo 0.085 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.085 guardada en correlacion_c_s_0.085.txt
# Correlación de c con s al tiempo 0.09000000000000001 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.09000000000000001 guardada en correlacion_c_s_0.090.txt
# Correlación de c con s al tiempo 0.09500000000000001 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.09500000000000001 guardada en correlacion_c_s_0.095.txt
# Correlación de c con s al tiempo 0.10000000000000002 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.10000000000000002 guardada en correlacion_c_s_0.100.txt
# Correlación de c con s al tiempo 0.10500000000000002 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.10500000000000002 guardada en correlacion_c_s_0.105.txt
# Correlación de c con s al tiempo 0.11000000000000003 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.11000000000000003 guardada en correlacion_c_s_0.110.txt
# Correlación de c con s al tiempo 0.11500000000000003 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.11500000000000003 guardada en correlacion_c_s_0.115.txt
# Correlación de c con s al tiempo 0.12000000000000004 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.12000000000000004 guardada en correlacion_c_s_0.120.txt
# Correlación de c con s al tiempo 0.12500000000000003 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.12500000000000003 guardada en correlacion_c_s_0.125.txt
# Correlación de c con s al tiempo 0.13000000000000003 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.13000000000000003 guardada en correlacion_c_s_0.130.txt
# Correlación de c con s al tiempo 0.13500000000000004 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.13500000000000004 guardada en correlacion_c_s_0.135.txt
# Correlación de c con s al tiempo 0.14000000000000004 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.14000000000000004 guardada en correlacion_c_s_0.140.txt
# Correlación de c con s al tiempo 0.14500000000000005 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.14500000000000005 guardada en correlacion_c_s_0.145.txt
# Correlación de c con s al tiempo 0.15000000000000005 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.15000000000000005 guardada en correlacion_c_s_0.150.txt
# Correlación de c con s al tiempo 0.15500000000000005 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.15500000000000005 guardada en correlacion_c_s_0.155.txt
# Correlación de c con s al tiempo 0.16000000000000006 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.16000000000000006 guardada en correlacion_c_s_0.160.txt
# Correlación de c con s al tiempo 0.16500000000000006 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.16500000000000006 guardada en correlacion_c_s_0.165.txt
# Correlación de c con s al tiempo 0.17000000000000007 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.17000000000000007 guardada en correlacion_c_s_0.170.txt
# Correlación de c con s al tiempo 0.17500000000000007 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.17500000000000007 guardada en correlacion_c_s_0.175.txt
# Correlación de c con s al tiempo 0.18000000000000008 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.18000000000000008 guardada en correlacion_c_s_0.180.txt
# Correlación de c con s al tiempo 0.18500000000000008 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.18500000000000008 guardada en correlacion_c_s_0.185.txt
# Correlación de c con s al tiempo 0.19000000000000009 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.19000000000000009 guardada en correlacion_c_s_0.190.txt
# Correlación de c con s al tiempo 0.1950000000000001 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.1950000000000001 guardada en correlacion_c_s_0.195.txt
# Correlación de c con s al tiempo 0.2000000000000001 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.2000000000000001 guardada en correlacion_c_s_0.200.txt
# Correlación de c con s al tiempo 0.2050000000000001 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.2050000000000001 guardada en correlacion_c_s_0.205.txt
# Correlación de c con s al tiempo 0.2100000000000001 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.2100000000000001 guardada en correlacion_c_s_0.210.txt
# Correlación de c con s al tiempo 0.2150000000000001 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.2150000000000001 guardada en correlacion_c_s_0.215.txt
# Correlación de c con s al tiempo 0.2200000000000001 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.2200000000000001 guardada en correlacion_c_s_0.220.txt
# Correlación de c con s al tiempo 0.22500000000000012 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.22500000000000012 guardada en correlacion_c_s_0.225.txt
# Correlación de c con s al tiempo 0.23000000000000012 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.23000000000000012 guardada en correlacion_c_s_0.230.txt
# Correlación de c con s al tiempo 0.23500000000000013 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.23500000000000013 guardada en correlacion_c_s_0.235.txt
# Correlación de c con s al tiempo 0.24000000000000013 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.24000000000000013 guardada en correlacion_c_s_0.240.txt
# Correlación de c con s al tiempo 0.24500000000000013 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.24500000000000013 guardada en correlacion_c_s_0.245.txt
# Correlación de c con s al tiempo 0.2500000000000001 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.2500000000000001 guardada en correlacion_c_s_0.250.txt
# Correlación de c con s al tiempo 0.2550000000000001 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.2550000000000001 guardada en correlacion_c_s_0.255.txt
# Correlación de c con s al tiempo 0.2600000000000001 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.2600000000000001 guardada en correlacion_c_s_0.260.txt
# Correlación de c con s al tiempo 0.2650000000000001 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.2650000000000001 guardada en correlacion_c_s_0.265.txt
# Correlación de c con s al tiempo 0.27000000000000013 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.27000000000000013 guardada en correlacion_c_s_0.270.txt
# Correlación de c con s al tiempo 0.27500000000000013 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.27500000000000013 guardada en correlacion_c_s_0.275.txt
# Correlación de c con s al tiempo 0.28000000000000014 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.28000000000000014 guardada en correlacion_c_s_0.280.txt
# Correlación de c con s al tiempo 0.28500000000000014 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.28500000000000014 guardada en correlacion_c_s_0.285.txt
# Correlación de c con s al tiempo 0.29000000000000015 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.29000000000000015 guardada en correlacion_c_s_0.290.txt
# Correlación de c con s al tiempo 0.29500000000000015 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.29500000000000015 guardada en correlacion_c_s_0.295.txt
# Correlación de c con s al tiempo 0.30000000000000016 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.30000000000000016 guardada en correlacion_c_s_0.300.txt
# Correlación de c con s al tiempo 0.30500000000000016 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.30500000000000016 guardada en correlacion_c_s_0.305.txt
# Correlación de c con s al tiempo 0.31000000000000016 considerando la malla espacial.
# Correlación suavizada de c con s al tiempo 0.31000000000000016 guardada en correlacion_c_s_0.310.txt
# Correlación de c con s al tiempo 0.31500000000000017 considerando la malla espacial.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/fenicsproject/lib/python3.9/site-packages/numpy/core/fromnumeric.py in ndim(a)
#    3159     try:
# -> 3160         return a.ndim
#    3161     except AttributeError:
#
# AttributeError: 'int' object has no attribute 'ndim'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_15291/3126081894.py in <module>
#       3     # Cargar campos
#       4     field1, field2 = load_field(field1_name, field2_name, t, nb)
# ----> 5     calculate_correlation(field1, field2, field1_name, field2_name, t, nodes_in_xaxis, nodes_in_yaxis, space_size)
#       6     t += dt
#
# /tmp/ipykernel_15291/1287774770.py in calculate_correlation(field1, field2, field1_name, field2_name, step, nodes_in_xaxis, nodes_in_yaxis, space_size, sigma)
#      44             if overlap1.size > 0:
#      45                 C_xy = np.mean(overlap1 * overlap2)
# ---> 46                 correlation[i + max_shift, j + max_shift] = np.clip(C_xy, -1, 1)  # Asegurar normalización
#      47
#      48     # Aplicar suavizado con filtro gaussiano
#
# <__array_function__ internals> in clip(*args, **kwargs)
#
# ~/anaconda3/envs/fenicsproject/lib/python3.9/site-packages/numpy/core/fromnumeric.py in clip(a, a_min, a_max, out, **kwargs)
#    2113
#    2114     """
# -> 2115     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#    2116
#    2117
#
# ~/anaconda3/envs/fenicsproject/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# ~/anaconda3/envs/fenicsproject/lib/python3.9/site-packages/numpy/core/_methods.py in _clip(a, min, max, out, casting, **kwargs)
#     135             min = -float('inf')
#     136             using_deprecated_nan = True
# --> 137         if _clip_dep_is_scalar_nan(max):
#     138             max = float('inf')
#     139             using_deprecated_nan = True
#
# ~/anaconda3/envs/fenicsproject/lib/python3.9/site-packages/numpy/core/_methods.py in _clip_dep_is_scalar_nan(a)
#      92     # guarded to protect circular imports
#      93     from numpy.core.fromnumeric import ndim
# ---> 94     if ndim(a) != 0:
#      95         return False
#      96     try:
#
# <__array_function__ internals> in ndim(*args, **kwargs)
#
# ~/anaconda3/envs/fenicsproject/lib/python3.9/site-packages/numpy/core/fromnumeric.py in ndim(a)
#    3160         return a.ndim
#    3161     except AttributeError:
# -> 3162         return asarray(a).ndim
#    3163
#    3164
#
# KeyboardInterrupt:

# %%
t = 0
length_corr = []
while t <= T:
    print(t)
    file1 = f'correlacion_{field1_name}{field2_name}_{t:.3f}.txt'
    corr = np.loadtxt(file1, delimiter="\t")
    corr = np.fft.fftshift(corr)


#     # Escalar los valores para mantener la estructura de la matriz
#     corr = corr / np.abs(np.min(corr)) if np.min(corr) != 0 else corr

    # Graficar
    print('Correlación')
    plt.figure(figsize=(6, 5))
    plt.imshow(corr, cmap='viridis', origin='lower')
    plt.colorbar(label='Log Magnitude')
    plt.title(f'Correlación ({field1_name} vs {field2_name}) Fourier')
    plt.xlabel('Frecuencia X')
    plt.ylabel('Frecuencia Y')
    plt.show()

    compute_correlation_length(corr, nodes_in_xaxis, space_size)
    
    # corr_function = directional_correlation_function(corr, nodes_in_xaxis, nodes_in_yaxis, space_size)
    # correlation_length = compute_correlation_length(corr_function, nodes_in_xaxis, nodes_in_yaxis, space_size)
    # print('Correlación', correlation_length)

    
    # unique_distances, radial_means, correlation_length = radial_correlation_function(corr, field1_name, field2_name, t, title="Curva del promedio radial")
    # plot_correlation(corr, field1_name, field2_name, t)
    # length_corr.append([t, correlation_length])
    
    t += dt

# %%
length_corr = np.array(length_corr)
np.savetxt(
    f'corr_length_time_{field1_name}_{field2_name}.txt',   # Nombre del archivo
    length_corr,                # Array a guardar
    fmt="%.2f",                # Formato de los valores (dos decimales)
    delimiter="\t",            # Separador (tabulación en este caso)
    header="Col1\tCol2"        # Encabezados de las columnas
)

# %%
# !ls
# Out:
# corr_length_real_inverse_mean_c_c.txt
# corr_length_real_inverse_mean_c_i.txt
# corr_length_real_inverse_mean_c_s.txt
# corr_length_real_inverse_mean_i_i.txt
# corr_length_real_inverse_mean_s_i.txt
# corr_length_real_inverse_mean_s_s.txt
# corr_length_real_inverse_nb_10_c_c.txt
# corr_length_real_inverse_nb_10_c_i.txt
# corr_length_real_inverse_nb_10_c_s.txt
# corr_length_real_inverse_nb_10_i_i.txt
# corr_length_real_inverse_nb_10_s_i.txt
# corr_length_real_inverse_nb_10_s_s.txt
# corr_length_real_inverse_nb_1_c_c.txt
# corr_length_real_inverse_nb_1_c_i.txt
# corr_length_real_inverse_nb_1_c_s.txt
# corr_length_real_inverse_nb_1_i_i.txt
# corr_length_real_inverse_nb_1_s_i.txt
# corr_length_real_inverse_nb_1_s_s.txt
# corr_length_real_inverse_nb_2_c_c.txt
# corr_length_real_inverse_nb_2_c_i.txt
# corr_length_real_inverse_nb_2_c_s.txt
# corr_length_real_inverse_nb_2_i_i.txt
# corr_length_real_inverse_nb_2_s_i.txt
# corr_length_real_inverse_nb_2_s_s.txt
# corr_length_real_inverse_nb_3_c_c.txt
# corr_length_real_inverse_nb_3_c_i.txt
# corr_length_real_inverse_nb_3_c_s.txt
# corr_length_real_inverse_nb_3_i_i.txt
# corr_length_real_inverse_nb_3_s_i.txt
# corr_length_real_inverse_nb_3_s_s.txt
# corr_length_real_inverse_nb_4_c_c.txt
# corr_length_real_inverse_nb_4_c_i.txt
# corr_length_real_inverse_nb_4_c_s.txt
# corr_length_real_inverse_nb_4_i_i.txt
# corr_length_real_inverse_nb_4_s_i.txt
# corr_length_real_inverse_nb_4_s_s.txt
# corr_length_real_inverse_nb_5_c_c.txt
# corr_length_real_inverse_nb_5_c_i.txt
# corr_length_real_inverse_nb_5_c_s.txt
# corr_length_real_inverse_nb_5_i_i.txt
# corr_length_real_inverse_nb_5_s_i.txt
# corr_length_real_inverse_nb_5_s_s.txt
# corr_length_real_inverse_nb_6_c_c.txt
# corr_length_real_inverse_nb_6_c_i.txt
# corr_length_real_inverse_nb_6_c_s.txt
# corr_length_real_inverse_nb_6_i_i.txt
# corr_length_real_inverse_nb_6_s_i.txt
# corr_length_real_inverse_nb_6_s_s.txt
# corr_length_real_inverse_nb_7_c_c.txt
# corr_length_real_inverse_nb_7_c_i.txt
# corr_length_real_inverse_nb_7_c_s.txt
# corr_length_real_inverse_nb_7_i_i.txt
# corr_length_real_inverse_nb_7_s_i.txt
# corr_length_real_inverse_nb_7_s_s.txt
# corr_length_real_inverse_nb_8_c_c.txt
# corr_length_real_inverse_nb_8_c_i.txt
# corr_length_real_inverse_nb_8_c_s.txt
# corr_length_real_inverse_nb_8_i_i.txt
# corr_length_real_inverse_nb_8_s_i.txt
# corr_length_real_inverse_nb_8_s_s.txt
# corr_length_real_inverse_nb_9_c_c.txt
# corr_length_real_inverse_nb_9_c_i.txt
# corr_length_real_inverse_nb_9_c_s.txt
# corr_length_real_inverse_nb_9_i_i.txt
# corr_length_real_inverse_nb_9_s_i.txt
# corr_length_real_inverse_nb_9_s_s.txt
# fields_block_1._step_0.000.png
# fields_block_1._step_0.005.png
# fields_block_1._step_0.010.png
# fields_block_1._step_0.015.png
# fields_block_1._step_0.020.png
# fields_block_1._step_0.025.png
# fields_block_1._step_0.030.png
# fields_block_1._step_0.035.png
# fields_block_1._step_0.040.png
# fields_block_1._step_0.045.png
# fields_block_1._step_0.050.png
# fields_block_1._step_0.055.png
# fields_block_1._step_0.060.png
# fields_block_1._step_0.065.png
# fields_block_1._step_0.070.png
# fields_block_1._step_0.075.png
# fields_block_1._step_0.080.png
# fields_block_1._step_0.085.png
# fields_block_1._step_0.090.png
# fields_block_1._step_0.095.png
# fields_block_1._step_0.100.png
# fields_block_1._step_0.105.png
# fields_block_1._step_0.110.png
# fields_block_1._step_0.115.png
# fields_block_1._step_0.120.png
# fields_block_1._step_0.125.png
# fields_block_1._step_0.130.png
# fields_block_1._step_0.135.png
# fields_block_1._step_0.140.png
# fields_block_1._step_0.145.png
# fields_block_1._step_0.150.png
# fields_block_1._step_0.155.png
# fields_block_1._step_0.160.png
# fields_block_1._step_0.165.png
# fields_block_1._step_0.170.png
# fields_block_1._step_0.175.png
# fields_block_1._step_0.180.png
# fields_block_1._step_0.185.png
# fields_block_1._step_0.190.png
# fields_block_1._step_0.195.png
# fields_block_1._step_0.200.png
# fields_block_1._step_0.205.png
# fields_block_1._step_0.210.png
# fields_block_1._step_0.215.png
# fields_block_1._step_0.220.png
# fields_block_1._step_0.225.png
# fields_block_1._step_0.230.png
# fields_block_1._step_0.235.png
# fields_block_1._step_0.240.png
# fields_block_1._step_0.245.png
# fields_block_1._step_0.250.png
# fields_block_1._step_0.255.png
# fields_block_1._step_0.260.png
# fields_block_1._step_0.265.png
# fields_block_1._step_0.270.png
# fields_block_1._step_0.275.png
# fields_block_1._step_0.280.png
# fields_block_1._step_0.285.png
# fields_block_1._step_0.290.png
# fields_block_1._step_0.295.png
# fields_block_1._step_0.300.png
# fields_block_1._step_0.305.png
# fields_block_1._step_0.310.png
# fields_block_1._step_0.315.png
# fields_block_1._step_0.320.png
# fields_block_1._step_0.325.png
# fields_block_1._step_0.330.png
# fields_block_1._step_0.335.png
# fields_block_1._step_0.340.png
# fields_block_1._step_0.345.png
# fields_block_1._step_0.350.png
# fields_block_1._step_0.355.png
# fields_block_1._step_0.360.png
# fields_block_1._step_0.365.png
# fields_block_1._step_0.370.png
# fields_block_1._step_0.375.png
# fields_block_1._step_0.380.png
# fields_block_1._step_0.385.png
# fields_block_1._step_0.390.png
# fields_block_1._step_0.395.png
# fields_block_1._step_0.400.png
# fields_block_1._step_0.405.png
# fields_block_1._step_0.410.png
# fields_block_1._step_0.415.png
# fields_block_1._step_0.420.png
# fields_block_1._step_0.425.png
# fields_block_1._step_0.430.png
# fields_block_1._step_0.435.png
# fields_block_1._step_0.440.png
# fields_block_1._step_0.445.png
# fields_block_1._step_0.450.png
# fields_block_1._step_0.455.png
# fields_block_1._step_0.460.png
# fields_block_1._step_0.465.png
# fields_block_1._step_0.470.png
# fields_block_1._step_0.475.png
# fields_block_1._step_0.480.png
# fields_block_1._step_0.485.png
# fields_block_1._step_0.490.png
# fields_block_1._step_0.495.png
# fields_block_1._step_0.500.png
# fields_block_1._step_0.505.png
# fields_block_1._step_0.510.png
# fields_block_1._step_0.515.png
# fields_block_1._step_0.520.png
# fields_block_1._step_0.525.png
# fields_block_1._step_0.530.png
# fields_block_1._step_0.535.png
# fields_block_1._step_0.540.png
# fields_block_1._step_0.545.png
# fields_block_1._step_0.550.png
# fields_block_1._step_0.555.png
# fields_block_1._step_0.560.png
# fields_block_1._step_0.565.png
# fields_block_1._step_0.570.png
# fields_block_1._step_0.575.png
# fields_block_1._step_0.580.png
# fields_block_1._step_0.585.png
# fields_block_1._step_0.590.png
# fields_block_1._step_0.595.png
# fields_block_1._step_0.600.png
# fields_block_1._step_0.605.png
# fields_block_1._step_0.610.png
# fields_block_1._step_0.615.png
# fields_block_1._step_0.620.png
# fields_block_1._step_0.625.png
# fields_block_1._step_0.630.png
# fields_block_1._step_0.635.png
# fields_block_1._step_0.640.png
# fields_block_1._step_0.645.png
# fields_block_1._step_0.650.png
# fields_block_1._step_0.655.png
# fields_block_1._step_0.660.png
# fields_block_1._step_0.665.png
# fields_block_1._step_0.670.png
# fields_block_1._step_0.675.png
# fields_block_1._step_0.680.png
# fields_block_1._step_0.685.png
# fields_block_1._step_0.690.png
# fields_block_1._step_0.695.png
# fields_block_1._step_0.700.png
# fields_block_1._step_0.705.png
# fields_block_1._step_0.710.png
# fields_block_1._step_0.715.png
# fields_block_1._step_0.720.png
# fields_block_1._step_0.725.png
# fields_block_1._step_0.730.png
# fields_block_1._step_0.735.png
# fields_block_1._step_0.740.png
# fields_block_1._step_0.745.png
# fields_block_1._step_0.750.png
# fields_block_1._step_0.755.png
# fields_block_1._step_0.760.png
# fields_block_1._step_0.765.png
# fields_block_1._step_0.770.png
# fields_block_1._step_0.775.png
# fields_block_1._step_0.780.png
# fields_block_1._step_0.785.png
# fields_block_1._step_0.790.png
# fields_block_1._step_0.795.png
# fields_block_1._step_0.800.png
# fields_block_1._step_0.805.png
# fields_block_1._step_0.810.png
# fields_block_1._step_0.815.png
# fields_block_1._step_0.820.png
# fields_block_1._step_0.825.png
# fields_block_1._step_0.830.png
# fields_block_1._step_0.835.png
# fields_block_1._step_0.840.png
# fields_block_1._step_0.845.png
# fields_block_1._step_0.850.png
# fields_block_1._step_0.855.png
# fields_block_1._step_0.860.png
# fields_block_1._step_0.865.png
# fields_block_1._step_0.870.png
# fields_block_1._step_0.875.png
# fields_block_1._step_0.880.png
# fields_block_1._step_0.885.png
# fields_block_1._step_0.890.png
# fields_block_1._step_0.895.png
# fields_block_1._step_0.900.png
# fields_block_1._step_0.905.png
# fields_block_1._step_0.910.png
# fields_block_1._step_0.915.png
# fields_block_1._step_0.920.png
# fields_block_1._step_0.925.png
# fields_block_1._step_0.930.png
# fields_block_1._step_0.935.png
# fields_block_1._step_0.940.png
# fields_block_1._step_0.945.png
# fields_block_1._step_0.950.png
# fields_block_1._step_0.955.png
# fields_block_1._step_0.960.png
# fields_block_1._step_0.965.png
# fields_block_1._step_0.970.png
# fields_block_1._step_0.975.png
# fields_block_1._step_0.980.png
# fields_block_1._step_0.985.png
# fields_block_1._step_0.990.png
# fields_block_1._step_0.995.png
# fields_block_1._step_1.000.png
# fields_block_1._step_1.005.png
# fields_block_1._step_1.010.png
# fields_block_1._step_1.015.png
# fields_block_1._step_1.020.png
# fields_block_1._step_1.025.png
# fields_block_1._step_1.030.png
# fields_block_1._step_1.035.png
# fields_block_1._step_1.040.png
# fields_block_1._step_1.045.png
# fields_block_1._step_1.050.png
# fields_block_1._step_1.055.png
# fields_block_1._step_1.060.png
# fields_block_1._step_1.065.png
# fields_block_1._step_1.070.png
# fields_block_1._step_1.075.png
# fields_block_1._step_1.080.png
# fields_block_1._step_1.085.png
# fields_block_1._step_1.090.png
# fields_block_1._step_1.095.png
# fields_block_1._step_1.100.png
# fields_block_1._step_1.105.png
# fields_block_1._step_1.110.png
# fields_block_1._step_1.115.png
# fields_block_1._step_1.120.png
# fields_block_1._step_1.125.png
# fields_block_1._step_1.130.png
# fields_block_1._step_1.135.png
# fields_block_1._step_1.140.png
# fields_block_1._step_1.145.png
# fields_block_1._step_1.150.png
# fields_block_1._step_1.155.png
# fields_block_1._step_1.160.png
# fields_block_1._step_1.165.png
# fields_block_1._step_1.170.png
# fields_block_1._step_1.175.png
# fields_block_1._step_1.180.png
# fields_block_1._step_1.185.png
# fields_block_1._step_1.190.png
# fields_block_1._step_1.195.png
# fields_block_1._step_1.200.png
# fields_block_1._step_1.205.png
# fields_block_1._step_1.210.png
# fields_block_1._step_1.215.png
# fields_block_1._step_1.220.png
# fields_block_1._step_1.225.png
# fields_block_1._step_1.230.png
# fields_block_1._step_1.235.png
# fields_block_1._step_1.240.png
# fields_block_1._step_1.245.png
# fields_block_1._step_1.250.png
# fields_block_1._step_1.255.png
# fields_block_1._step_1.260.png
# fields_block_1._step_1.265.png
# fields_block_1._step_1.270.png
# fields_block_1._step_1.275.png
# fields_block_1._step_1.280.png
# fields_block_1._step_1.285.png
# fields_block_1._step_1.290.png
# fields_block_1._step_1.295.png
# fields_block_1._step_1.300.png
# fields_block_1._step_1.305.png
# fields_block_1._step_1.310.png
# fields_block_1._step_1.315.png
# fields_block_1._step_1.320.png
# fields_block_1._step_1.325.png
# fields_block_1._step_1.330.png
# fields_block_1._step_1.335.png
# fields_block_1._step_1.340.png
# fields_block_1._step_1.345.png
# fields_block_1._step_1.350.png
# fields_block_1._step_1.355.png
# fields_block_1._step_1.360.png
# fields_block_1._step_1.365.png
# fields_block_1._step_1.370.png
# fields_block_1._step_1.375.png
# fields_block_1._step_1.380.png
# fields_block_1._step_1.385.png
# fields_block_1._step_1.390.png
# fields_block_1._step_1.395.png
# fields_block_1._step_1.400.png
# fields_block_1._step_1.405.png
# fields_block_1._step_1.410.png
# fields_block_1._step_1.415.png
# fields_block_1._step_1.420.png
# fields_block_1._step_1.425.png
# fields_block_1._step_1.430.png
# fields_block_1._step_1.435.png
# fields_block_1._step_1.440.png
# fields_block_1._step_1.445.png
# fields_block_1._step_1.450.png
# fields_block_1._step_1.455.png
# fields_block_1._step_1.460.png
# fields_block_1._step_1.465.png
# fields_block_1._step_1.470.png
# fields_block_1._step_1.475.png
# fields_block_1._step_1.480.png
# fields_block_1._step_1.485.png
# fields_block_1._step_1.490.png
# fields_block_1._step_1.495.png
# fields_block_1._step_1.500.png
# fields_block_1._step_1.505.png
# fields_block_1._step_1.510.png
# fields_block_1._step_1.515.png
# fields_block_1._step_1.520.png
# fields_block_1._step_1.525.png
# fields_block_1._step_1.530.png
# fields_block_1._step_1.535.png
# fields_block_1._step_1.540.png
# fields_block_1._step_1.545.png
# fields_block_1._step_1.550.png
# fields_block_1._step_1.555.png
# fields_block_1._step_1.560.png
# fields_block_1._step_1.565.png
# fields_block_1._step_1.570.png
# fields_block_1._step_1.575.png
# fields_block_1._step_1.580.png
# fields_block_1._step_1.585.png
# fields_block_1._step_1.590.png
# fields_block_1._step_1.595.png
# fields_block_1._step_1.600.png
# fields_block_1._step_1.605.png
# fields_block_1._step_1.610.png
# fields_block_1._step_1.615.png
# fields_block_1._step_1.620.png
# fields_block_1._step_1.625.png
# fields_block_1._step_1.630.png
# fields_block_1._step_1.635.png
# fields_block_1._step_1.640.png
# fields_block_1._step_1.645.png
# fields_block_1._step_1.650.png
# fields_block_1._step_1.655.png
# fields_block_1._step_1.660.png
# fields_block_1._step_1.665.png
# fields_block_1._step_1.670.png
# fields_block_1._step_1.675.png
# fields_block_1._step_1.680.png
# fields_block_1._step_1.685.png
# fields_block_1._step_1.690.png
# fields_block_1._step_1.695.png
# fields_block_1._step_1.700.png
# fields_block_1._step_1.705.png
# fields_block_1._step_1.710.png
# fields_block_1._step_1.715.png
# fields_block_1._step_1.720.png
# fields_block_1._step_1.725.png
# fields_block_1._step_1.730.png
# fields_block_1._step_1.735.png
# fields_block_1._step_1.740.png
# fields_block_1._step_1.745.png
# fields_block_1._step_1.750.png
# fields_block_1._step_1.755.png
# fields_block_1._step_1.760.png
# fields_block_1._step_1.765.png
# fields_block_1._step_1.770.png
# fields_block_1._step_1.775.png
# fields_block_1._step_1.780.png
# fields_block_1._step_1.785.png
# fields_block_1._step_1.790.png
# fields_block_1._step_1.795.png
# fields_block_1._step_1.800.png
# fields_block_1._step_1.805.png
# fields_block_1._step_1.810.png
# fields_block_1._step_1.815.png
# fields_block_1._step_1.820.png
# fields_block_1._step_1.825.png
# fields_block_1._step_1.830.png
# fields_block_1._step_1.835.png
# fields_block_1._step_1.840.png
# fields_block_1._step_1.845.png
# fields_block_1._step_1.850.png
# fields_block_1._step_1.855.png
# fields_block_1._step_1.860.png
# fields_block_1._step_1.865.png
# fields_block_1._step_1.870.png
# fields_block_1._step_1.875.png
# fields_block_1._step_1.880.png
# fields_block_1._step_1.885.png
# fields_block_1._step_1.890.png
# fields_block_1._step_1.895.png
# fields_block_1._step_1.900.png
# fields_block_1._step_1.905.png
# fields_block_1._step_1.910.png
# fields_block_1._step_1.915.png
# fields_block_1._step_1.920.png
# fields_block_1._step_1.925.png
# fields_block_1._step_1.930.png
# fields_block_1._step_1.935.png
# fields_block_1._step_1.940.png
# fields_block_1._step_1.945.png
# fields_block_1._step_1.950.png
# fields_block_1._step_1.955.png
# fields_block_1._step_1.960.png
# fields_block_1._step_1.965.png
# fields_block_1._step_1.970.png
# fields_block_1._step_1.975.png
# fields_block_1._step_1.980.png
# fields_block_1._step_1.985.png
# fields_block_1._step_1.990.png
# fields_block_1._step_1.995.png
# fields_block_1._step_2.000.png
# matrix_c_0.000_nb_10.txt
# matrix_c_0.000_nb_1.txt
# matrix_c_0.000_nb_2.txt
# matrix_c_0.000_nb_3.txt
# matrix_c_0.000_nb_4.txt
# matrix_c_0.000_nb_5.txt
# matrix_c_0.000_nb_6.txt
# matrix_c_0.000_nb_7.txt
# matrix_c_0.000_nb_8.txt
# matrix_c_0.000_nb_9.txt
# matrix_c_0.005_nb_10.txt
# matrix_c_0.005_nb_1.txt
# matrix_c_0.005_nb_2.txt
# matrix_c_0.005_nb_3.txt
# matrix_c_0.005_nb_4.txt
# matrix_c_0.005_nb_5.txt
# matrix_c_0.005_nb_6.txt
# matrix_c_0.005_nb_7.txt
# matrix_c_0.005_nb_8.txt
# matrix_c_0.005_nb_9.txt
# matrix_c_0.010_nb_10.txt
# matrix_c_0.010_nb_1.txt
# matrix_c_0.010_nb_2.txt
# matrix_c_0.010_nb_3.txt
# matrix_c_0.010_nb_4.txt
# matrix_c_0.010_nb_5.txt
# matrix_c_0.010_nb_6.txt
# matrix_c_0.010_nb_7.txt
# matrix_c_0.010_nb_8.txt
# matrix_c_0.010_nb_9.txt
# matrix_c_0.650_nb_4.txt
# matrix_c_0.650_nb_5.txt
# matrix_c_0.650_nb_6.txt
# matrix_c_0.650_nb_7.txt
# matrix_c_0.650_nb_8.txt
# matrix_c_0.650_nb_9.txt
# matrix_c_0.655_nb_10.txt
# matrix_c_0.655_nb_1.txt
# matrix_c_0.655_nb_2.txt
# matrix_c_0.655_nb_3.txt
# matrix_c_0.655_nb_4.txt
# matrix_c_0.655_nb_5.txt
# matrix_c_0.655_nb_6.txt
# matrix_c_0.655_nb_7.txt
# matrix_c_0.655_nb_8.txt
# matrix_c_0.655_nb_9.txt
# matrix_c_0.660_nb_10.txt
# matrix_c_0.660_nb_1.txt
# matrix_c_0.660_nb_2.txt
# matrix_c_0.660_nb_3.txt
# matrix_c_0.660_nb_4.txt
# matrix_c_0.660_nb_5.txt
# matrix_c_0.660_nb_6.txt
# matrix_c_0.660_nb_7.txt
# matrix_c_0.660_nb_8.txt
# matrix_c_0.660_nb_9.txt
# matrix_c_0.665_nb_10.txt
# matrix_c_0.665_nb_1.txt
# matrix_c_0.665_nb_2.txt
# matrix_c_0.665_nb_3.txt
# matrix_c_0.665_nb_4.txt
# matrix_c_0.665_nb_5.txt
# matrix_c_0.665_nb_6.txt
# matrix_c_0.665_nb_7.txt
# matrix_c_0.665_nb_8.txt
# matrix_c_0.665_nb_9.txt
# matrix_c_0.670_nb_10.txt
# matrix_c_0.670_nb_1.txt
# matrix_c_0.670_nb_2.txt
# matrix_c_0.670_nb_3.txt
# matrix_c_0.670_nb_4.txt
# matrix_c_0.670_nb_5.txt
# matrix_c_0.670_nb_6.txt
# matrix_c_0.670_nb_7.txt
# matrix_c_0.670_nb_8.txt
# matrix_c_0.670_nb_9.txt
# matrix_c_0.675_nb_10.txt
# matrix_c_0.675_nb_1.txt
# matrix_c_0.675_nb_2.txt
# matrix_c_0.675_nb_3.txt
# matrix_c_0.675_nb_4.txt
# matrix_c_0.675_nb_5.txt
# matrix_c_0.675_nb_6.txt
# matrix_c_0.675_nb_7.txt
# matrix_c_0.675_nb_8.txt
# matrix_c_0.675_nb_9.txt
# matrix_c_0.680_nb_10.txt
# matrix_c_0.680_nb_1.txt
# matrix_c_0.680_nb_2.txt
# matrix_c_0.680_nb_3.txt
# matrix_c_0.680_nb_4.txt
# matrix_c_0.680_nb_5.txt
# matrix_c_0.680_nb_6.txt
# matrix_c_0.680_nb_7.txt
# matrix_c_0.680_nb_8.txt
# matrix_c_0.680_nb_9.txt
# matrix_c_0.685_nb_10.txt
# ...
# power_spectrum_i_1.445.png
# power_spectrum_i_1.450.png
# power_spectrum_i_1.455.png
# power_spectrum_i_1.460.png
# power_spectrum_i_1.465.png
# power_spectrum_i_1.470.png
# power_spectrum_i_1.475.png
# power_spectrum_i_1.480.png
# power_spectrum_i_1.485.png
# power_spectrum_i_1.490.png
# power_spectrum_i_1.495.png
# power_spectrum_i_1.500.png
# power_spectrum_i_1.505.png
# power_spectrum_i_1.510.png
# power_spectrum_i_1.515.png
# power_spectrum_i_1.520.png
# power_spectrum_i_1.525.png
# power_spectrum_i_1.530.png
# power_spectrum_i_1.535.png
# power_spectrum_i_1.540.png
# power_spectrum_i_1.545.png
# power_spectrum_i_1.550.png
# power_spectrum_i_1.555.png
# power_spectrum_i_1.560.png
# power_spectrum_i_1.565.png
# power_spectrum_i_1.570.png
# power_spectrum_i_1.575.png
# power_spectrum_i_1.580.png
# power_spectrum_i_1.585.png
# power_spectrum_i_1.590.png
# power_spectrum_i_1.595.png
# power_spectrum_i_1.600.png
# power_spectrum_i_1.605.png
# power_spectrum_i_1.610.png
# power_spectrum_i_1.615.png
# power_spectrum_i_1.620.png
# power_spectrum_i_1.625.png
# power_spectrum_i_1.630.png
# power_spectrum_i_1.635.png
# power_spectrum_i_1.640.png
# power_spectrum_i_1.645.png
# power_spectrum_i_1.650.png
# power_spectrum_i_1.655.png
# power_spectrum_i_1.660.png
# power_spectrum_i_1.665.png
# power_spectrum_i_1.670.png
# power_spectrum_i_1.675.png
# power_spectrum_i_1.680.png
# power_spectrum_i_1.685.png
# power_spectrum_i_1.690.png
# power_spectrum_i_1.695.png
# power_spectrum_i_1.700.png
# power_spectrum_i_1.705.png
# power_spectrum_i_1.710.png
# power_spectrum_i_1.715.png
# power_spectrum_i_1.720.png
# power_spectrum_i_1.725.png
# power_spectrum_i_1.730.png
# power_spectrum_i_1.735.png
# power_spectrum_i_1.740.png
# power_spectrum_i_1.745.png
# power_spectrum_i_1.750.png
# power_spectrum_i_1.755.png
# power_spectrum_i_1.760.png
# power_spectrum_i_1.765.png
# power_spectrum_i_1.770.png
# power_spectrum_i_1.775.png
# power_spectrum_i_1.780.png
# power_spectrum_i_1.785.png
# power_spectrum_i_1.790.png
# power_spectrum_i_1.795.png
# power_spectrum_i_1.800.png
# power_spectrum_i_1.805.png
# power_spectrum_i_1.810.png
# power_spectrum_i_1.815.png
# power_spectrum_i_1.820.png
# power_spectrum_i_1.825.png
# power_spectrum_i_1.830.png
# power_spectrum_i_1.835.png
# power_spectrum_i_1.840.png
# power_spectrum_i_1.845.png
# power_spectrum_i_1.850.png
# power_spectrum_i_1.855.png
# power_spectrum_i_1.860.png
# power_spectrum_i_1.865.png
# power_spectrum_i_1.870.png
# power_spectrum_i_1.875.png
# power_spectrum_i_1.880.png
# power_spectrum_i_1.885.png
# power_spectrum_i_1.890.png
# power_spectrum_i_1.895.png
# power_spectrum_i_1.900.png
# power_spectrum_i_1.905.png
# power_spectrum_i_1.910.png
# power_spectrum_i_1.915.png
# power_spectrum_i_1.920.png
# power_spectrum_i_1.925.png
# power_spectrum_i_1.930.png
# power_spectrum_i_1.935.png
# power_spectrum_i_1.940.png
# power_spectrum_i_1.945.png
# power_spectrum_i_1.950.png
# power_spectrum_i_1.955.png
# power_spectrum_i_1.960.png
# power_spectrum_i_1.965.png
# power_spectrum_i_1.970.png
# power_spectrum_i_1.975.png
# power_spectrum_i_1.980.png
# power_spectrum_i_1.985.png
# power_spectrum_i_1.990.png
# power_spectrum_i_1.995.png
# power_spectrum_i_2.000.png
# power_spectrum_s_0.000.png
# power_spectrum_s_0.005.png
# power_spectrum_s_0.005._step_0.005.png
# power_spectrum_s_0.010.png
# power_spectrum_s_0.015.png
# power_spectrum_s_0.015._step_0.015.png
# power_spectrum_s_0.01._step_0.010.png
# power_spectrum_s_0.020.png
# power_spectrum_s_0.025.png
# power_spectrum_s_0.025._step_0.025.png
# power_spectrum_s_0.02._step_0.020.png
# power_spectrum_s_0.030000000000000002._step_0.030.png
# power_spectrum_s_0.030.png
# power_spectrum_s_0.035.png
# power_spectrum_s_0.035._step_0.035.png
# power_spectrum_s_0.040.png
# power_spectrum_s_0.045.png
# power_spectrum_s_0.045._step_0.045.png
# power_spectrum_s_0.049999999999999996._step_0.050.png
# power_spectrum_s_0.04._step_0.040.png
# power_spectrum_s_0.050.png
# power_spectrum_s_0.05499999999999999._step_0.055.png
# power_spectrum_s_0.055.png
# power_spectrum_s_0.05999999999999999._step_0.060.png
# power_spectrum_s_0.060.png
# power_spectrum_s_0.06499999999999999._step_0.065.png
# power_spectrum_s_0.065.png
# power_spectrum_s_0.06999999999999999._step_0.070.png
# power_spectrum_s_0.070.png
# power_spectrum_s_0.075.png
# power_spectrum_s_0.075._step_0.075.png
# power_spectrum_s_0.080.png
# power_spectrum_s_0.085.png
# power_spectrum_s_0.085._step_0.085.png
# power_spectrum_s_0.08._step_0.080.png
# power_spectrum_s_0.09000000000000001._step_0.090.png
# power_spectrum_s_0.090.png
# power_spectrum_s_0.09500000000000001._step_0.095.png
# power_spectrum_s_0.095.png
# power_spectrum_s_0.10000000000000002._step_0.100.png
# power_spectrum_s_0.100.png
# power_spectrum_s_0.10500000000000002._step_0.105.png
# power_spectrum_s_0.105.png
# power_spectrum_s_0.11000000000000003._step_0.110.png
# power_spectrum_s_0.110.png
# power_spectrum_s_0.11500000000000003._step_0.115.png
# power_spectrum_s_0.115.png
# power_spectrum_s_0.12000000000000004._step_0.120.png
# power_spectrum_s_0.120.png
# power_spectrum_s_0.12500000000000003._step_0.125.png
# power_spectrum_s_0.125.png
# power_spectrum_s_0.13000000000000003._step_0.130.png
# power_spectrum_s_0.130.png
# power_spectrum_s_0.13500000000000004._step_0.135.png
# power_spectrum_s_0.135.png
# power_spectrum_s_0.14000000000000004._step_0.140.png
# power_spectrum_s_0.140.png
# power_spectrum_s_0.14500000000000005._step_0.145.png
# power_spectrum_s_0.145.png
# power_spectrum_s_0.15000000000000005._step_0.150.png
# power_spectrum_s_0.150.png
# power_spectrum_s_0.15500000000000005._step_0.155.png
# power_spectrum_s_0.155.png
# power_spectrum_s_0.16000000000000006._step_0.160.png
# power_spectrum_s_0.160.png
# power_spectrum_s_0.16500000000000006._step_0.165.png
# power_spectrum_s_0.165.png
# power_spectrum_s_0.17000000000000007._step_0.170.png
# power_spectrum_s_0.170.png
# power_spectrum_s_0.17500000000000007._step_0.175.png
# power_spectrum_s_0.175.png
# power_spectrum_s_0.18000000000000008._step_0.180.png
